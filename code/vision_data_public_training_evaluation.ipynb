# %% [markdown]
# **1**

# %%
# ==========================================
# CELLULE 1 : MONTAGE GOOGLE DRIVE
# ==========================================

from google.colab import drive
import os

print("="*70)
print("💾 MONTAGE GOOGLE DRIVE")
print("="*70)

if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')
    print("✅ Google Drive monté")
else:
    print("✅ Google Drive déjà monté")

print("="*70)
# Out:
# ======================================================================
# 💾 MONTAGE GOOGLE DRIVE
# ======================================================================
# Mounted at /content/drive
# ✅ Google Drive monté
# ======================================================================

# %% [markdown]
# **2**

# %%
# ==========================================
# CELLULE 2 : INSTALLATION BARF
# ==========================================

import os
import sys

print("="*70)
print("🔧 INSTALLATION DE L'ENVIRONNEMENT BARF")
print("="*70)

# 1. Créer workspace et cloner BARF
WORKSPACE = '/content/barf_workspace'
BARF_DIR = os.path.join(WORKSPACE, 'bundle-adjusting-NeRF')

os.makedirs(WORKSPACE, exist_ok=True)

if not os.path.exists(BARF_DIR):
    print("\n📥 Clonage du dépôt BARF...")
    os.chdir(WORKSPACE)
    # !git clone https://github.com/chenhsuanlin/bundle-adjusting-NeRF.git
    print("✅ Dépôt cloné")
else:
    print("✅ Dépôt BARF déjà présent")

os.chdir(BARF_DIR)
print(f"📂 Répertoire : {os.getcwd()}")

# 2. Installer les dépendances
print("\n📦 Installation des dépendances...")
# !pip install -q numpy matplotlib pillow tqdm tensorboard easydict pyyaml opencv-python lpips

# 3. Créer le module SSIM manquant
print("\n🔧 Configuration module SSIM...")
os.makedirs('external', exist_ok=True)

ssim_code = '''"""SSIM implementation"""
import torch
import torch.nn.functional as F
from math import exp

def gaussian(window_size, sigma):
    gauss = torch.Tensor([exp(-(x - window_size//2)**2/float(2*sigma**2)) for x in range(window_size)])
    return gauss/gauss.sum()

def create_window(window_size, channel):
    _1D_window = gaussian(window_size, 1.5).unsqueeze(1)
    _2D_window = _1D_window.mm(_1D_window.t()).float().unsqueeze(0).unsqueeze(0)
    window = _2D_window.expand(channel, 1, window_size, window_size).contiguous()
    return window

def pytorch_ssim(img1, img2, window_size=11, size_average=True):
    channel = img1.size()[1]
    window = create_window(window_size, channel)
    if img1.is_cuda:
        window = window.cuda(img1.get_device())
    window = window.type_as(img1)

    mu1 = F.conv2d(img1, window, padding=window_size//2, groups=channel)
    mu2 = F.conv2d(img2, window, padding=window_size//2, groups=channel)
    mu1_sq = mu1.pow(2)
    mu2_sq = mu2.pow(2)
    mu1_mu2 = mu1*mu2

    sigma1_sq = F.conv2d(img1*img1, window, padding=window_size//2, groups=channel) - mu1_sq
    sigma2_sq = F.conv2d(img2*img2, window, padding=window_size//2, groups=channel) - mu2_sq
    sigma12 = F.conv2d(img1*img2, window, padding=window_size//2, groups=channel) - mu1_mu2

    C1 = 0.01**2
    C2 = 0.03**2
    ssim_map = ((2*mu1_mu2 + C1)*(2*sigma12 + C2))/((mu1_sq + mu2_sq + C1)*(sigma1_sq + sigma2_sq + C2))

    if size_average:
        return ssim_map.mean()
    else:
        return ssim_map.mean(1).mean(1).mean(1)
'''

with open('external/pohsun_ssim.py', 'w') as f:
    f.write(ssim_code)
with open('external/__init__.py', 'w') as f:
    f.write('')

print("✅ Module SSIM créé")

# 4. Patcher options.py pour éviter les input() interactifs
print("\n🔧 Patch de options.py...")

with open('options.py', 'r') as f:
    content = f.read()

# Supprimer les input() interactifs
content = content.replace(
    'override = input("override? (y/n) ")',
    'override = "y"  # Auto-patched for Colab'
)
content = content.replace(
    'retry = input("visdom port ({}) not open, retry? (y/n) ".format(opt.visdom.port))',
    'retry = "n"  # Auto-patched for Colab'
)

with open('options.py', 'w') as f:
    f.write(content)

print("✅ options.py patché")

# 5. Modifier le fichier YAML pour barf_c2f
print("\n📝 Configuration YAML...")

import yaml

yaml_path = 'options/barf_blender.yaml'
with open(yaml_path, 'r') as f:
    config_yaml = yaml.safe_load(f)

config_yaml['barf_c2f'] = [0.1, 0.5]
config_yaml['visdom'] = False

with open(yaml_path, 'w') as f:
    yaml.dump(config_yaml, f, default_flow_style=False)

print("✅ YAML configuré")

print("\n" + "="*70)
print("✅ INSTALLATION TERMINÉE")
print("="*70)
# Out:
# ======================================================================
# 🔧 INSTALLATION DE L'ENVIRONNEMENT BARF
# ======================================================================
#
# 📥 Clonage du dépôt BARF...
# Cloning into 'bundle-adjusting-NeRF'...
# remote: Enumerating objects: 102, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 102 (delta 34), reused 19 (delta 19), pack-reused 46 (from 1)
# Receiving objects: 100% (102/102), 191.81 KiB | 880.00 KiB/s, done.
# Resolving deltas: 100% (52/52), done.
# ✅ Dépôt cloné
# 📂 Répertoire : /content/barf_workspace/bundle-adjusting-NeRF
#
# 📦 Installation des dépendances...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 3.3 MB/s eta 0:00:00
#
# 🔧 Configuration module SSIM...
# ✅ Module SSIM créé
#
# 🔧 Patch de options.py...
# ✅ options.py patché
#
# 📝 Configuration YAML...
# ✅ YAML configuré
#
# ======================================================================
# ✅ INSTALLATION TERMINÉE
# ======================================================================

# %% [markdown]
# **3**

# %%
# ==========================================
# CELLULE 3 : GESTIONNAIRE DE DATASETS
# ==========================================

import os
import glob
import shutil
import zipfile

print("="*70)
print("📦 GESTIONNAIRE DE DATASETS")
print("="*70)

# Détection des datasets dans Google Drive
datasets_info = {
    'synthetic': {
        'names': ['nerf_synthetic.zip'],
        'description': 'Dataset synthétique Blender',
        'found': False,
        'path': None
    }
}

search_paths = [
    '/content/drive/MyDrive/NeRF_Data',
    '/content/drive/MyDrive',
]

# Chercher les datasets
for dataset_type, info in datasets_info.items():
    for search_path in search_paths:
        if os.path.exists(search_path):
            for name_pattern in info['names']:
                matches = glob.glob(os.path.join(search_path, name_pattern))
                if matches:
                    info['found'] = True
                    info['path'] = matches[0]
                    break
        if info['found']:
            break

# Afficher résumé
for dataset_type, info in datasets_info.items():
    status = "✅ TROUVÉ" if info['found'] else "❌ NON TROUVÉ"
    print(f"\n{dataset_type.upper()} : {status}")
    if info['found']:
        size_mb = os.path.getsize(info['path']) / (1024 * 1024)
        print(f"   Taille : {size_mb:.1f} MB")

# Fonction d'extraction
def extract_dataset(zip_path, destination):
    print(f"\n📦 Extraction vers {destination}...")
    os.makedirs(destination, exist_ok=True)
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(destination)
    print("✅ Extraction terminée")
    return destination

# Extraire si demandé
if datasets_info['synthetic']['found']:
    choice = input("\nExtraire le dataset synthétique ? (y/n) : ").strip().lower()
    if choice == 'y':
        extract_dataset(
            datasets_info['synthetic']['path'],
            '/content/data'
        )

print("\n" + "="*70)
print("✅ GESTIONNAIRE PRÊT")
print("="*70)
# Out:
# ======================================================================
# 📦 GESTIONNAIRE DE DATASETS
# ======================================================================
#
# SYNTHETIC : ✅ TROUVÉ
#    Taille : 1208.1 MB
#
# Extraire le dataset synthétique ? (y/n) : y
#
# 📦 Extraction vers /content/data...
# ✅ Extraction terminée
#
# ======================================================================
# ✅ GESTIONNAIRE PRÊT
# ======================================================================

# %% [markdown]
# code d'entrainement avec les checkpoints

# %%
# ==========================================
# EXPÉRIMENTATION 1 : DATASET LEGO (AVEC CHECKPOINTS AMÉLIORÉS)
# ==========================================

print("="*70)
print("🧪 EXPÉRIMENTATION 1 : DATASET LEGO - Système de Checkpoints Automatiques")
print("="*70)

import os
import json
import shutil
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from mpl_toolkits.mplot3d import Axes3D
import subprocess
import sys
import time
import threading
from datetime import datetime

# Variable de contrôle pour l'interruption
TRAINING_INTERRUPTED = False

# ==========================================
# INSTALLATION DES DÉPENDANCES MANQUANTES
# ==========================================
print("\n[Installation] 📦 VÉRIFICATION DES DÉPENDANCES")
print("-"*70)

try:
    import ipdb
    print("✅ ipdb déjà installé")
except ImportError:
    print("⚙️ Installation de ipdb...")
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "ipdb"])
    print("✅ ipdb installé")

missing_packages = []
try:
    import tensorboard
except ImportError:
    missing_packages.append("tensorboard")

try:
    import visdom
except ImportError:
    missing_packages.append("visdom")

if missing_packages:
    print(f"⚙️ Installation de packages supplémentaires: {', '.join(missing_packages)}")
    for pkg in missing_packages:
        subprocess.run([sys.executable, "-m", "pip", "install", "-q", pkg])
    print("✅ Tous les packages installés")

# ==========================================
# CONFIGURATION GOOGLE DRIVE
# ==========================================
print("\n[Configuration] 📁 GOOGLE DRIVE")
print("-"*70)

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

DRIVE_ROOT = '/content/drive/MyDrive/projet_nerf_barf'
DRIVE_CHECKPOINTS = os.path.join(DRIVE_ROOT, 'checkpoints')
DRIVE_RESULTS = os.path.join(DRIVE_ROOT, 'results')
DRIVE_LOGS = os.path.join(DRIVE_ROOT, 'logs')

os.makedirs(DRIVE_CHECKPOINTS, exist_ok=True)
os.makedirs(DRIVE_RESULTS, exist_ok=True)
os.makedirs(DRIVE_LOGS, exist_ok=True)

print(f"✅ Dossiers Google Drive créés :")
print(f"   Checkpoints : {DRIVE_CHECKPOINTS}")
print(f"   Résultats   : {DRIVE_RESULTS}")
print(f"   Logs        : {DRIVE_LOGS}")

BARF_PATH = '/content/barf_workspace/bundle-adjusting-NeRF'
os.chdir(BARF_PATH)

DATASET_ROOT = '/content/data/nerf_synthetic'
SCENE = 'lego'
SCENE_PATH = os.path.join(DATASET_ROOT, SCENE)

if not os.path.exists(SCENE_PATH):
    print(f"❌ Dataset non trouvé : {SCENE_PATH}")
    raise FileNotFoundError(f"Dataset non trouvé : {SCENE_PATH}")

print(f"✅ Dataset trouvé : {SCENE_PATH}")

# ==========================================
# FONCTIONS UTILITAIRES
# ==========================================

def save_checkpoint_to_drive(checkpoint_path, iteration=None):
    """Sauvegarde un checkpoint vers Google Drive"""
    if os.path.exists(checkpoint_path):
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        if iteration:
            filename = f"checkpoint_iter_{iteration}_{timestamp}.ckpt"
        else:
            filename = f"checkpoint_latest_{timestamp}.ckpt"

        dest_path = os.path.join(DRIVE_CHECKPOINTS, filename)

        try:
            shutil.copy2(checkpoint_path, dest_path)
            latest_path = os.path.join(DRIVE_CHECKPOINTS, "checkpoint_latest.ckpt")
            shutil.copy2(checkpoint_path, latest_path)
            print(f"✅ Checkpoint sauvegardé : {filename}")
            return dest_path
        except Exception as e:
            print(f"⚠️ Erreur lors de la sauvegarde du checkpoint : {e}")
            return None
    else:
        print(f"⚠️ Checkpoint non trouvé : {checkpoint_path}")
        return None

def load_checkpoint_from_drive():
    """Charge le dernier checkpoint depuis Google Drive"""
    import glob

    checkpoint_pattern = os.path.join(DRIVE_CHECKPOINTS, "*.ckpt")
    checkpoints = glob.glob(checkpoint_pattern)

    if checkpoints:
        def get_iter_num(path):
            filename = os.path.basename(path)
            try:
                return int(filename.replace('.ckpt', ''))
            except:
                return 0

        latest_checkpoint = max(checkpoints, key=get_iter_num)
        iter_num = get_iter_num(latest_checkpoint)

        local_model_dir = 'output/barf_lego/debug/model'
        os.makedirs(local_model_dir, exist_ok=True)

        local_path = os.path.join(local_model_dir, os.path.basename(latest_checkpoint))
        shutil.copy2(latest_checkpoint, local_path)

        model_ckpt_path = 'output/barf_lego/debug/model.ckpt'
        shutil.copy2(latest_checkpoint, model_ckpt_path)

        print(f"✅ Checkpoint récupéré depuis Google Drive")
        print(f"   Iteration : {iter_num}")
        print(f"   Source : {latest_checkpoint}")
        return True
    else:
        print("ℹ️ Aucun checkpoint trouvé sur Google Drive")
        print("   Démarrage d'un nouvel entraînement")
        return False

def save_results_to_drive():
    """Sauvegarde tous les résultats vers Google Drive"""
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    results_dir = os.path.join(DRIVE_RESULTS, f"results_{timestamp}")
    os.makedirs(results_dir, exist_ok=True)

    files_to_save = [
        ('output/barf_lego/debug/results.json', 'results.json'),
        ('output/barf_lego/debug/latest.ckpt', 'final_checkpoint.ckpt'),
        ('poses_gt_lego.png', 'poses_gt_lego.png'),
    ]

    saved_files = []
    for src, dest_name in files_to_save:
        if os.path.exists(src):
            dest = os.path.join(results_dir, dest_name)
            shutil.copy2(src, dest)
            saved_files.append(dest_name)

    vis_dir = 'output/barf_lego/debug/vis'
    if os.path.exists(vis_dir):
        dest_vis_dir = os.path.join(results_dir, 'visualizations')
        shutil.copytree(vis_dir, dest_vis_dir, dirs_exist_ok=True)
        saved_files.append('visualizations/')

    print(f"✅ Résultats sauvegardés dans : {results_dir}")
    for f in saved_files:
        print(f"   - {f}")

    return results_dir

def create_training_log(message, log_type="INFO"):
    """Crée un log d'entraînement"""
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    log_file = os.path.join(DRIVE_LOGS, "training_log.txt")

    with open(log_file, 'a') as f:
        f.write(f"[{timestamp}] [{log_type}] {message}\n")

def monitor_checkpoints(checkpoint_dir, stop_event, checkpoint_interval=1000):
    """Thread qui surveille et sauvegarde automatiquement les checkpoints"""
    checkpoint_path = os.path.join(checkpoint_dir, 'latest.ckpt')
    last_mtime = 0
    last_saved_iteration = 0

    print(f"🔍 Surveillance des checkpoints activée (intervalle: {checkpoint_interval} it)")

    while not stop_event.is_set():
        try:
            if os.path.exists(checkpoint_path):
                current_mtime = os.path.getmtime(checkpoint_path)

                if current_mtime > last_mtime:
                    last_mtime = current_mtime

                    try:
                        import torch
                        checkpoint_data = torch.load(checkpoint_path, map_location='cpu')
                        current_iter = checkpoint_data.get('iter', 0)

                        if current_iter // checkpoint_interval > last_saved_iteration // checkpoint_interval:
                            print(f"\n💾 Sauvegarde automatique du checkpoint (iter {current_iter})...")
                            save_checkpoint_to_drive(checkpoint_path, current_iter)
                            create_training_log(f"Checkpoint auto-sauvegardé - Iteration {current_iter}", "CHECKPOINT")
                            last_saved_iteration = current_iter
                    except Exception as e:
                        print(f"⚠️ Erreur lors de la lecture du checkpoint : {e}")

        except Exception as e:
            print(f"⚠️ Erreur dans le monitoring : {e}")

        time.sleep(30)

# ==========================================
# ÉTAPE 1 : Analyse du Dataset
# ==========================================
print("\n[Étape 1/6] 📊 ANALYSE DU DATASET")
print("-"*70)

with open(os.path.join(SCENE_PATH, 'transforms_train.json'), 'r') as f:
    train_data = json.load(f)

num_train = len(train_data['frames'])
camera_angle_x = train_data.get('camera_angle_x', 0.6911)

print(f"📐 Configuration :")
print(f"   Images train : {num_train}")
print(f"   FOV caméra   : {camera_angle_x:.4f} rad")

poses_gt = np.array([np.array(f['transform_matrix']) for f in train_data['frames']])
positions_gt = poses_gt[:, :3, 3]

print(f"\n📍 Poses ground truth :")
print(f"   Étendue X : [{positions_gt[:, 0].min():.3f}, {positions_gt[:, 0].max():.3f}]")
print(f"   Étendue Y : [{positions_gt[:, 1].min():.3f}, {positions_gt[:, 1].max():.3f}]")
print(f"   Étendue Z : [{positions_gt[:, 2].min():.3f}, {positions_gt[:, 2].max():.3f}]")

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(positions_gt[:, 0], positions_gt[:, 1], positions_gt[:, 2],
                    c=range(len(positions_gt)), cmap='viridis', s=80, alpha=0.7)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Poses Ground Truth - Lego')
plt.colorbar(scatter, label='Numéro de vue')
plt.savefig('poses_gt_lego.png', dpi=120)
print("\n✅ Visualisation : poses_gt_lego.png")
plt.show()

create_training_log("Analyse du dataset terminée")

# ==========================================
# ÉTAPE 2 : Vérification Checkpoint
# ==========================================
print("\n[Étape 2/6] 🔍 VÉRIFICATION CHECKPOINT")
print("-"*70)

resume_training = load_checkpoint_from_drive()

if resume_training:
    create_training_log("Reprise de l'entraînement depuis checkpoint", "INFO")
else:
    create_training_log("Démarrage d'un nouvel entraînement", "INFO")

# ==========================================
# ÉTAPE 3 : Configuration
# ==========================================
print("\n[Étape 3/6] ⚙️ CONFIGURATION BARF")
print("-"*70)

# PROFIL 2 : ENTRAÎNEMENT STANDARD (recommandé)
MAX_ITER = 100000

CHECKPOINT_FREQ = 1000

config = {
    'group': 'barf_lego',
    'max_iter': MAX_ITER,
    'batch_size': 4096,
    'checkpoint_freq': CHECKPOINT_FREQ,
}

print(f"📊 Configuration choisie :")
print(f"   Max iterations : {MAX_ITER:,}")
print(f"   Batch size     : {config['batch_size']}")
print(f"   Checkpoint tous les : {CHECKPOINT_FREQ:,} itérations")

time_estimates = {
    50000: "10-15 minutes",
    100000: "25-30 minutes",
    150000: "35-40 minutes",
    200000: "45-60 minutes",
}
estimated_time = time_estimates.get(MAX_ITER, "Variable")
print(f"   ⏱️ Temps estimé : {estimated_time} sur GPU T4")

num_checkpoints = MAX_ITER // CHECKPOINT_FREQ
print(f"   💾 Checkpoints attendus : ~{num_checkpoints}")

if resume_training:
    print(f"   ℹ️ Reprise depuis checkpoint existant")

# ==========================================
# ÉTAPE 4 : Entraînement avec Checkpoints
# ==========================================
print("\n[Étape 4/6] 🚀 ENTRAÎNEMENT")
print("="*70)

cmd = [
    "python", "train.py",
    "--group=barf_lego",
    "--model=barf",
    "--yaml=barf_blender",
    "--data.scene=lego",
    f"--data.root={DATASET_ROOT}",
    f"--max_iter={MAX_ITER}",
    "--batch_size=4096",
    "--optim.lr=0.0005",
    "--optim.lr_pose=0.001",
    "--freq.scalar=200",
    "--freq.vis=2000",
    "--freq.val=5000",
    f"--freq.ckpt={CHECKPOINT_FREQ}",
    "--data.num_workers=2"
]

if resume_training:
    cmd.append("--resume")

print("🔧 Lancement de l'entraînement...")
if resume_training:
    print("🔄 Mode : REPRISE depuis checkpoint")
else:
    print("🆕 Mode : NOUVEL entraînement")
print("="*70 + "\n")

stop_monitoring = threading.Event()
checkpoint_dir = 'output/barf_lego/debug'
monitor_thread = threading.Thread(
    target=monitor_checkpoints,
    args=(checkpoint_dir, stop_monitoring, CHECKPOINT_FREQ),
    daemon=True
)
monitor_thread.start()

process = None

try:
    process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT,
                              text=True, bufsize=1)

    for line in process.stdout:
        print(line, end='')

    process.wait()

    stop_monitoring.set()
    monitor_thread.join(timeout=5)

    print("\n💾 Sauvegarde finale du checkpoint...")
    final_checkpoint = os.path.join(checkpoint_dir, 'latest.ckpt')
    save_checkpoint_to_drive(final_checkpoint)

    if process.returncode == 0:
        print("\n" + "="*70)
        print("✅ ENTRAÎNEMENT TERMINÉ AVEC SUCCÈS")
        print("="*70)
        create_training_log("Entraînement terminé avec succès", "SUCCESS")
    else:
        print(f"\n⚠️ Code retour : {process.returncode}")
        create_training_log(f"Entraînement terminé avec code {process.returncode}", "WARNING")

except KeyboardInterrupt:
    print("\n" + "="*70)
    print("⚠️ ENTRAÎNEMENT INTERROMPU PAR L'UTILISATEUR")
    print("="*70)
    print("💾 Sauvegarde du checkpoint en cours...")

    TRAINING_INTERRUPTED = True
    stop_monitoring.set()

    if process is not None:
        try:
            process.terminate()
            process.wait(timeout=10)
        except:
            try:
                process.kill()
            except:
                pass

    current_checkpoint = os.path.join(checkpoint_dir, 'latest.ckpt')
    if os.path.exists(current_checkpoint):
        save_checkpoint_to_drive(current_checkpoint)
        print("✅ Checkpoint d'interruption sauvegardé")
        create_training_log("Entraînement interrompu - Checkpoint sauvegardé", "INTERRUPT")
    else:
        print("⚠️ Aucun checkpoint trouvé à sauvegarder")

    print("\n💡 Pour reprendre l'entraînement, relancez ce script !")
    print("="*70)

except Exception as e:
    print(f"\n❌ Erreur : {e}")
    TRAINING_INTERRUPTED = True
    stop_monitoring.set()
    create_training_log(f"Erreur : {e}", "ERROR")

# ==========================================
# ÉTAPE 5 : Évaluation (si non interrompu)
# ==========================================
if not TRAINING_INTERRUPTED:
    print("\n[Étape 5/6] 📈 ÉVALUATION")
    print("-"*70)

    eval_cmd = [
        "python", "evaluate.py",
        "--group=barf_lego",
        "--model=barf",
        "--yaml=barf_blender",
        "--data.scene=lego",
        f"--data.root={DATASET_ROOT}",
        "--resume"
    ]

    print("🧪 Évaluation sur le test set...")
    subprocess.run(eval_cmd)

    results_file = 'output/barf_lego/debug/results.json'
    if os.path.exists(results_file):
        with open(results_file, 'r') as f:
            results = json.load(f)

        print("\n📊 RÉSULTATS QUANTITATIFS :")
        print("-"*70)
        psnr = results.get('psnr', 0)
        ssim = results.get('ssim', 0)
        lpips = results.get('lpips', 0)

        print(f"   PSNR  : {psnr:.2f} dB")
        print(f"   SSIM  : {ssim:.4f}")
        print(f"   LPIPS : {lpips:.4f}")
        print("-"*70)

        create_training_log(f"PSNR: {psnr:.2f}, SSIM: {ssim:.4f}, LPIPS: {lpips:.4f}", "RESULTS")

        if psnr > 30:
            print("   🎉 EXCELLENT ! Reconstruction de haute qualité")
        elif psnr > 28:
            print("   ✅ BON ! Résultats satisfaisants")
        else:
            print("   ⚠️ Résultats moyens")
    else:
        print("⚠️ Fichier de résultats non trouvé")

    # ==========================================
    # ÉTAPE 6 : Sauvegarde Finale
    # ==========================================
    print("\n[Étape 6/6] 💾 SAUVEGARDE FINALE")
    print("-"*70)

    results_dir = save_results_to_drive()

    summary_file = os.path.join(results_dir, "summary.txt")
    with open(summary_file, 'w') as f:
        f.write("="*70 + "\n")
        f.write("RÉSUMÉ DE L'EXPÉRIMENTATION - LEGO\n")
        f.write("="*70 + "\n\n")
        f.write(f"Date : {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
        f.write(f"Dataset : {SCENE}\n")
        f.write(f"Itérations : {MAX_ITER:,}\n")
        f.write(f"Temps estimé : {estimated_time}\n\n")

        if os.path.exists(results_file):
            f.write("MÉTRIQUES :\n")
            f.write(f"  PSNR  : {psnr:.2f} dB\n")
            f.write(f"  SSIM  : {ssim:.4f}\n")
            f.write(f"  LPIPS : {lpips:.4f}\n\n")

        f.write("FICHIERS SAUVEGARDÉS :\n")
        f.write(f"  - Checkpoint final\n")
        f.write(f"  - Résultats JSON\n")
        f.write(f"  - Visualisations\n")
        f.write(f"  - Poses ground truth\n")

    print(f"✅ Résumé créé : summary.txt")

    print("\n" + "="*70)
    print("🎉 EXPÉRIMENTATION TERMINÉE AVEC SUCCÈS")
    print("="*70)
    print(f"\n📁 TOUS LES FICHIERS SONT SAUVEGARDÉS :")
    print(f"   Résultats  : {results_dir}")
    print(f"   Checkpoints: {DRIVE_CHECKPOINTS}")
    print(f"   Logs       : {DRIVE_LOGS}")
    print("\n💡 Pour reprendre l'entraînement, relancez simplement ce script !")
    print("="*70)

    create_training_log("Expérimentation terminée - Tous les fichiers sauvegardés", "COMPLETE")

else:
    # Message de fin en cas d'interruption
    print("\n" + "="*70)
    print("📋 RÉCAPITULATIF APRÈS INTERRUPTION")
    print("="*70)
    print(f"   Checkpoints sauvegardés : {DRIVE_CHECKPOINTS}")
    print(f"   Logs : {DRIVE_LOGS}")
    print("\n💡 Pour reprendre l'entraînement, relancez simplement ce script !")
    print("   Le script détectera automatiquement le dernier checkpoint.")
    print("="*70)
# Out:
# ======================================================================
# 🧪 EXPÉRIMENTATION 1 : DATASET LEGO - Système de Checkpoints Automatiques
# ======================================================================
#
# [Installation] 📦 VÉRIFICATION DES DÉPENDANCES
# ----------------------------------------------------------------------
# ✅ ipdb déjà installé
#
# [Configuration] 📁 GOOGLE DRIVE
# ----------------------------------------------------------------------
# Mounted at /content/drive
# ✅ Dossiers Google Drive créés :
#    Checkpoints : /content/drive/MyDrive/projet_nerf_barf/checkpoints
#    Résultats   : /content/drive/MyDrive/projet_nerf_barf/results
#    Logs        : /content/drive/MyDrive/projet_nerf_barf/logs
# ✅ Dataset trouvé : /content/data/nerf_synthetic/lego
#
# [Étape 1/6] 📊 ANALYSE DU DATASET
# ----------------------------------------------------------------------
# 📐 Configuration :
#    Images train : 100
#    FOV caméra   : 0.6911 rad
#
# 📍 Poses ground truth :
#    Étendue X : [-3.940, 3.724]
#    Étendue Y : [-3.927, 3.950]
#    Étendue Z : [0.510, 4.031]
#
# ✅ Visualisation : poses_gt_lego.png
# [Étape 2/6] 🔍 VÉRIFICATION CHECKPOINT
# ----------------------------------------------------------------------
# ✅ Checkpoint récupéré depuis Google Drive
#    Iteration : 100000
#    Source : /content/drive/MyDrive/projet_nerf_barf/checkpoints/100000.ckpt
#
# [Étape 3/6] ⚙️ CONFIGURATION BARF
# ----------------------------------------------------------------------
# 📊 Configuration choisie :
#    Max iterations : 100,000
#    Batch size     : 4096
#    Checkpoint tous les : 1,000 itérations
#    ⏱️ Temps estimé : 25-30 minutes sur GPU T4
#    💾 Checkpoints attendus : ~100
#    ℹ️ Reprise depuis checkpoint existant
#
# [Étape 4/6] 🚀 ENTRAÎNEMENT
# ======================================================================
# 🔧 Lancement de l'entraînement...
# 🔄 Mode : REPRISE depuis checkpoint
# ======================================================================
#
# 🔍 Surveillance des checkpoints activée (intervalle: 1000 it)
# 2025-11-30 15:50:40.244424: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764517840.264266    5073 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764517840.270242    5073 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764517840.285169    5073 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764517840.285192    5073 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764517840.285195    5073 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764517840.285197    5073 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-30 15:50:40.289730: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# ======================================================================
# ⚠️ ENTRAÎNEMENT INTERROMPU PAR L'UTILISATEUR
# ======================================================================
# 💾 Sauvegarde du checkpoint en cours...
# ⚠️ Aucun checkpoint trouvé à sauvegarder
#
# 💡 Pour reprendre l'entraînement, relancez ce script !
# ======================================================================
#
# ======================================================================
# 📋 RÉCAPITULATIF APRÈS INTERRUPTION
# ======================================================================
#    Checkpoints sauvegardés : /content/drive/MyDrive/projet_nerf_barf/checkpoints
#    Logs : /content/drive/MyDrive/projet_nerf_barf/logs
#
# 💡 Pour reprendre l'entraînement, relancez simplement ce script !
#    Le script détectera automatiquement le dernier checkpoint.
# ======================================================================

# %% [markdown]
# # Avant de lancer l'entrainement il faut dabord lancer les deux scriptes ci dessous

# %%
# %%writefile /content/monitor_checkpoints.py
import time
import shutil
import os

LOCAL_CHECKPOINTS = 'output/barf_lego/debug/model'
DRIVE_CHECKPOINTS = '/content/drive/MyDrive/projet_nerf_barf/checkpoints'
saved_files = set()

print("🔄 Surveillance automatique des checkpoints démarrée")

while True:
    if os.path.exists(LOCAL_CHECKPOINTS):
        current_files = set(os.listdir(LOCAL_CHECKPOINTS))
        new_files = current_files - saved_files

        for f in new_files:
            src = os.path.join(LOCAL_CHECKPOINTS, f)
            dst = os.path.join(DRIVE_CHECKPOINTS, f)
            shutil.copy2(src, dst)
            print(f"💾 Sauvegardé : {f}")
            saved_files.add(f)

    time.sleep(60)
# Out:
# Writing /content/monitor_checkpoints.py

# %%
# Lancer en arrière-plan
import subprocess
process = subprocess.Popen(['python', '/content/monitor_checkpoints.py'])
print(f"✅ Monitoring lancé (PID: {process.pid})")
# Out:
# ✅ Monitoring lancé (PID: 1052)

# %%
# Exécutez ce code pour explorer ce qui a été créé
import os
import glob

print("🔍 Recherche de tous les fichiers créés...\n")

# Chercher tous les .ckpt
checkpoints = glob.glob("/content/**/*.ckpt", recursive=True)
print(f"📦 Checkpoints trouvés ({len(checkpoints)}):")
for ckpt in checkpoints:
    size = os.path.getsize(ckpt) / (1024*1024)  # MB
    print(f"   {ckpt} ({size:.1f} MB)")

print("\n" + "="*70)

# Chercher tous les fichiers dans output/
if os.path.exists("output"):
    print("\n📁 Contenu de output/:")
    for root, dirs, files in os.walk("output"):
        level = root.replace("output", "").count(os.sep)
        indent = "   " * level
        print(f"{indent}{os.path.basename(root)}/")
        subindent = "   " * (level + 1)
        for file in files:
            filepath = os.path.join(root, file)
            size = os.path.getsize(filepath) / (1024*1024)
            print(f"{subindent}{file} ({size:.1f} MB)")

# Chercher results.json
results_files = glob.glob("/content/**/results.json", recursive=True)
print(f"\n📊 Fichiers results.json trouvés ({len(results_files)}):")
for f in results_files:
    print(f"   {f}")
# Out:
# 🔍 Recherche de tous les fichiers créés...
#
# 📦 Checkpoints trouvés (204):
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/20000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/21000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/22000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/23000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/24000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/25000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/26000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/27000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/28000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/29000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/30000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/31000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/32000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/33000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/34000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/35000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/36000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/37000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/38000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/39000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/40000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/41000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/42000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/43000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/44000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/45000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/46000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/47000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/48000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/49000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/50000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/51000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/52000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/53000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/54000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/55000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/56000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/57000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/58000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/59000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/60000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/61000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/62000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/63000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/64000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/65000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/66000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/67000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/68000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/69000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/70000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/71000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/72000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/73000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/74000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/75000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/76000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/checkpoint_latest_20251123_155430.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/checkpoint_latest_20251123_154531.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/checkpoint_iter_100000_20251123_154804.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/checkpoint_latest_20251123_153851.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/checkpoint_latest_20251123_161738.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/checkpoint_latest_20251123_154825.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/checkpoint_latest.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/77000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/78000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/79000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/80000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/81000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/82000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/83000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/84000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/85000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/86000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/87000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/88000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/89000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/90000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/91000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/92000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/93000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/94000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/95000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/96000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/97000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/98000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/99000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/checkpoints/100000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/results/results_20251123_153909/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/results/results_20251123_154842/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/results/results_20251123_155523/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/results/results_20251123_155759/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/results/results_20251123_160014/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/results/results_20251123_160040/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/results/results_20251123_160151/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/results/results_20251123_160527/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/results/results_20251123_161140/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/results/results_20251123_161835/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/results/evaluation_cpu_lego_20251123_164221/checkpoint_used.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/results/evaluation_cpu_lego_20251123_164517/checkpoint_used.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/results/evaluation_cpu_lego_20251123_164933/checkpoint_used.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf (1)/results/evaluation_cpu_lego_20251123_172355/checkpoint_used.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/20000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/21000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/22000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/23000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/24000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/25000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/26000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/27000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/28000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/29000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/30000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/31000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/32000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/33000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/34000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/35000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/36000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/37000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/38000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/39000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/40000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/41000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/42000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/43000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/44000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/45000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/46000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/47000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/48000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/49000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/50000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/51000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/52000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/53000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/54000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/55000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/56000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/57000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/58000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/59000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/60000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/61000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/62000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/63000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/64000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/65000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/66000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/67000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/68000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/69000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/70000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/71000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/72000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/73000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/74000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/75000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/76000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/checkpoint_latest_20251123_155430.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/checkpoint_latest_20251123_154531.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/checkpoint_iter_100000_20251123_154804.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/checkpoint_latest_20251123_153851.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/checkpoint_latest_20251123_161738.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/checkpoint_latest_20251123_154825.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/checkpoint_latest.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/77000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/78000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/79000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/80000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/81000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/82000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/83000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/84000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/85000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/86000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/87000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/88000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/89000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/90000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/91000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/92000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/93000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/94000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/95000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/96000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/97000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/98000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/99000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/checkpoints/100000.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_153909/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_154842/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_155523/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_155759/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_160014/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_160040/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_160151/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_160527/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_161140/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_161835/final_checkpoint.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/results/evaluation_cpu_lego_20251123_164221/checkpoint_used.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/results/evaluation_cpu_lego_20251123_164517/checkpoint_used.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/results/evaluation_cpu_lego_20251123_164933/checkpoint_used.ckpt (6.1 MB)
#    /content/drive/MyDrive/projet_nerf_barf/results/evaluation_cpu_lego_20251123_172355/checkpoint_used.ckpt (6.1 MB)
#
# ======================================================================
#
# 📊 Fichiers results.json trouvés (0):

# %%
CHECKPOINT_PATH = "/content/drive/MyDrive/projet_nerf_barf/checkpoints/20000.ckpt"
OUTPUT_DIR = "/content/barf_workspace/bundle-adjusting-NeRF/output/barf_lego/debug"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
# 2. Exécuter l'évaluation
# !python /content/barf_workspace/bundle-adjusting-NeRF/evaluate.py \
    --group=barf_lego \
    --model=barf \
    --yaml=barf_blender \
    --data.scene=lego \
    --data.root=/content/data/nerf_synthetic \
    --load=/content/drive/MyDrive/projet_nerf_barf/checkpoints/20000.ckpt
# Out:
# Process ID: 4978
# [/content/barf_workspace/bundle-adjusting-NeRF/evaluate.py] (PyTorch code for evaluating NeRF/BARF)
# setting configurations...
# loading options/base.yaml...
# loading options/nerf_blender.yaml...
# loading options/barf_blender.yaml...
# * H: 400
# * W: 400
# * arch:
#    * density_activ: softplus
#    * layers_feat: [None, 256, 256, 256, 256, 256, 256, 256, 256]
#    * layers_rgb: [None, 128, 3]
#    * posenc:
#       * L_3D: 10
#       * L_view: 4
#    * skip: [4]
#    * tf_init: True
# * barf_c2f: [0.1, 0.5]
# * batch_size: None
# * camera:
#    * model: perspective
#    * ndc: False
#    * noise: 0.15
# * cpu: False
# * data:
#    * augment:
#    * bgcolor: 1
#    * center_crop: None
#    * dataset: blender
#    * image_size: [400, 400]
#    * num_workers: 4
#    * preload: True
#    * root: /content/data/nerf_synthetic
#    * scene: lego
#    * train_sub: None
#    * val_on_test: False
#    * val_sub: 4
# * device: cuda:0
# * freq:
#    * ckpt: 5000
#    * scalar: 200
#    * val: 2000
#    * vis: 1000
# * gpu: 0
# * group: barf_lego
# * load: /content/drive/MyDrive/projet_nerf_barf/checkpoints/20000.ckpt
# * loss_weight:
#    * render: 0
#    * render_fine: None
# * max_epoch: None
# * max_iter: 200000
# * model: barf
# * name: debug
# * nerf:
#    * density_noise_reg: None
#    * depth:
#       * param: metric
#       * range: [2, 6]
#    * fine_sampling: False
#    * rand_rays: 1024
#    * sample_intvs: 128
#    * sample_intvs_fine: None
#    * sample_stratified: True
#    * setbg_opaque: False
#    * view_dep: True
# * optim:
#    * algo: Adam
#    * lr: 0.0005
#    * lr_end: 0.0001
#    * lr_pose: 0.001
#    * lr_pose_end: 1e-05
#    * sched:
#       * gamma: None
#       * type: ExponentialLR
#    * sched_pose:
#       * gamma: None
#       * type: ExponentialLR
#    * test_iter: 100
#    * test_photo: True
#    * warmup_pose: None
# * output_path: output/barf_lego/debug
# * output_root: output
# * resume: False
# * seed: 0
# * tb:
#    * num_images: [4, 8]
# * trimesh:
#    * chunk_size: 16384
#    * range: [-1.2, 1.2]
#    * res: 128
#    * thres: 25.0
# * visdom: False
# * yaml: barf_blender
# 2025-11-30 07:50:09.690772: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764489009.710376    4978 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764489009.716293    4978 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764489009.731364    4978 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764489009.731395    4978 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764489009.731399    4978 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764489009.731402    4978 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-30 07:50:09.735914: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/alex.pth
# loading training data...
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# number of samples: 100
# loading test data...
# number of samples: 4
# building networks...
# writing videos...
# loading weights from checkpoint /content/drive/MyDrive/projet_nerf_barf/checkpoints/20000.ckpt...
# restoring nerf...
# restoring se3_refine...
# --------------------------
# rot:      0.396
# trans:    0.01166
# --------------------------
# evaluating:   0% 0/4 [00:00<?, ?it/s]
# test-time optim.:   0% 0/100 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4317.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#
# test-time optim.:   0% 0/100 [00:00<?, ?it/s, loss=0.006]
# test-time optim.:   1% 1/100 [00:00<00:43,  2.30it/s, loss=0.006]
# test-time optim.:   1% 1/100 [00:00<00:43,  2.30it/s, loss=0.006]
# test-time optim.:   2% 2/100 [00:00<00:26,  3.74it/s, loss=0.006]
# test-time optim.:   2% 2/100 [00:00<00:26,  3.74it/s, loss=0.005]
# test-time optim.:   3% 3/100 [00:00<00:20,  4.74it/s, loss=0.005]
# test-time optim.:   3% 3/100 [00:00<00:20,  4.74it/s, loss=0.005]
# test-time optim.:   4% 4/100 [00:00<00:17,  5.43it/s, loss=0.005]
# test-time optim.:   4% 4/100 [00:01<00:17,  5.43it/s, loss=0.006]
# test-time optim.:   5% 5/100 [00:01<00:16,  5.84it/s, loss=0.006]
# test-time optim.:   5% 5/100 [00:01<00:16,  5.84it/s, loss=0.006]
# test-time optim.:   6% 6/100 [00:01<00:15,  6.20it/s, loss=0.006]
# test-time optim.:   6% 6/100 [00:01<00:15,  6.20it/s, loss=0.005]
# test-time optim.:   7% 7/100 [00:01<00:14,  6.46it/s, loss=0.005]
# test-time optim.:   7% 7/100 [00:01<00:14,  6.46it/s, loss=0.006]
# test-time optim.:   8% 8/100 [00:01<00:13,  6.64it/s, loss=0.006]
# test-time optim.:   8% 8/100 [00:01<00:13,  6.64it/s, loss=0.005]
# test-time optim.:   9% 9/100 [00:01<00:13,  6.77it/s, loss=0.005]
# test-time optim.:   9% 9/100 [00:01<00:13,  6.77it/s, loss=0.007]
# test-time optim.:  10% 10/100 [00:01<00:13,  6.84it/s, loss=0.007]
# test-time optim.:  10% 10/100 [00:01<00:13,  6.84it/s, loss=0.006]
# test-time optim.:  11% 11/100 [00:01<00:12,  6.91it/s, loss=0.006]
# test-time optim.:  11% 11/100 [00:02<00:12,  6.91it/s, loss=0.005]
# test-time optim.:  12% 12/100 [00:02<00:12,  6.93it/s, loss=0.005]
# test-time optim.:  12% 12/100 [00:02<00:12,  6.93it/s, loss=0.006]
# test-time optim.:  13% 13/100 [00:02<00:12,  6.96it/s, loss=0.006]
# test-time optim.:  13% 13/100 [00:02<00:12,  6.96it/s, loss=0.006]
# test-time optim.:  14% 14/100 [00:02<00:12,  6.96it/s, loss=0.006]
# test-time optim.:  14% 14/100 [00:02<00:12,  6.96it/s, loss=0.004]
# test-time optim.:  15% 15/100 [00:02<00:12,  6.97it/s, loss=0.004]
# test-time optim.:  15% 15/100 [00:02<00:12,  6.97it/s, loss=0.004]
# test-time optim.:  16% 16/100 [00:02<00:12,  6.98it/s, loss=0.004]
# test-time optim.:  16% 16/100 [00:02<00:12,  6.98it/s, loss=0.007]
# test-time optim.:  17% 17/100 [00:02<00:11,  7.00it/s, loss=0.007]
# test-time optim.:  17% 17/100 [00:02<00:11,  7.00it/s, loss=0.006]
# test-time optim.:  18% 18/100 [00:02<00:11,  7.03it/s, loss=0.006]
# test-time optim.:  18% 18/100 [00:03<00:11,  7.03it/s, loss=0.005]
# test-time optim.:  19% 19/100 [00:03<00:11,  7.02it/s, loss=0.005]
# test-time optim.:  19% 19/100 [00:03<00:11,  7.02it/s, loss=0.005]
# test-time optim.:  20% 20/100 [00:03<00:11,  7.02it/s, loss=0.005]
# test-time optim.:  20% 20/100 [00:03<00:11,  7.02it/s, loss=0.005]
# test-time optim.:  21% 21/100 [00:03<00:11,  7.03it/s, loss=0.005]
# test-time optim.:  21% 21/100 [00:03<00:11,  7.03it/s, loss=0.005]
# test-time optim.:  22% 22/100 [00:03<00:11,  7.01it/s, loss=0.005]
# test-time optim.:  22% 22/100 [00:03<00:11,  7.01it/s, loss=0.006]
# test-time optim.:  23% 23/100 [00:03<00:10,  7.02it/s, loss=0.006]
# test-time optim.:  23% 23/100 [00:03<00:10,  7.02it/s, loss=0.007]
# test-time optim.:  24% 24/100 [00:03<00:10,  7.05it/s, loss=0.007]
# test-time optim.:  24% 24/100 [00:03<00:10,  7.05it/s, loss=0.006]
# test-time optim.:  25% 25/100 [00:03<00:10,  7.03it/s, loss=0.006]
# test-time optim.:  25% 25/100 [00:04<00:10,  7.03it/s, loss=0.006]
# test-time optim.:  26% 26/100 [00:04<00:10,  7.04it/s, loss=0.006]
# test-time optim.:  26% 26/100 [00:04<00:10,  7.04it/s, loss=0.005]
# test-time optim.:  27% 27/100 [00:04<00:10,  7.03it/s, loss=0.005]
# test-time optim.:  27% 27/100 [00:04<00:10,  7.03it/s, loss=0.005]
# test-time optim.:  28% 28/100 [00:04<00:10,  7.05it/s, loss=0.005]
# test-time optim.:  28% 28/100 [00:04<00:10,  7.05it/s, loss=0.005]
# test-time optim.:  29% 29/100 [00:04<00:10,  7.03it/s, loss=0.005]
# test-time optim.:  29% 29/100 [00:04<00:10,  7.03it/s, loss=0.005]
# test-time optim.:  30% 30/100 [00:04<00:09,  7.03it/s, loss=0.005]
# test-time optim.:  30% 30/100 [00:04<00:09,  7.03it/s, loss=0.006]
# test-time optim.:  31% 31/100 [00:04<00:09,  7.05it/s, loss=0.006]
# test-time optim.:  31% 31/100 [00:04<00:09,  7.05it/s, loss=0.005]
# test-time optim.:  32% 32/100 [00:04<00:09,  7.05it/s, loss=0.005]
# test-time optim.:  32% 32/100 [00:04<00:09,  7.05it/s, loss=0.006]
# test-time optim.:  33% 33/100 [00:04<00:09,  7.05it/s, loss=0.006]
# test-time optim.:  33% 33/100 [00:05<00:09,  7.05it/s, loss=0.006]
# test-time optim.:  34% 34/100 [00:05<00:09,  7.04it/s, loss=0.006]
# test-time optim.:  34% 34/100 [00:05<00:09,  7.04it/s, loss=0.005]
# test-time optim.:  35% 35/100 [00:05<00:09,  7.04it/s, loss=0.005]
# test-time optim.:  35% 35/100 [00:05<00:09,  7.04it/s, loss=0.005]
# test-time optim.:  36% 36/100 [00:05<00:09,  7.05it/s, loss=0.005]
# test-time optim.:  36% 36/100 [00:05<00:09,  7.05it/s, loss=0.005]
# test-time optim.:  37% 37/100 [00:05<00:08,  7.04it/s, loss=0.005]
# test-time optim.:  37% 37/100 [00:05<00:08,  7.04it/s, loss=0.005]
# test-time optim.:  38% 38/100 [00:05<00:08,  7.04it/s, loss=0.005]
# test-time optim.:  38% 38/100 [00:05<00:08,  7.04it/s, loss=0.005]
# test-time optim.:  39% 39/100 [00:05<00:08,  7.03it/s, loss=0.005]
# test-time optim.:  39% 39/100 [00:05<00:08,  7.03it/s, loss=0.006]
# test-time optim.:  40% 40/100 [00:05<00:08,  7.03it/s, loss=0.006]
# test-time optim.:  40% 40/100 [00:06<00:08,  7.03it/s, loss=0.004]
# test-time optim.:  41% 41/100 [00:06<00:08,  7.04it/s, loss=0.004]
# test-time optim.:  41% 41/100 [00:06<00:08,  7.04it/s, loss=0.005]
# test-time optim.:  42% 42/100 [00:06<00:08,  7.04it/s, loss=0.005]
# test-time optim.:  42% 42/100 [00:06<00:08,  7.04it/s, loss=0.005]
# test-time optim.:  43% 43/100 [00:06<00:08,  7.04it/s, loss=0.005]
# test-time optim.:  43% 43/100 [00:06<00:08,  7.04it/s, loss=0.005]
# test-time optim.:  44% 44/100 [00:06<00:07,  7.04it/s, loss=0.005]
# test-time optim.:  44% 44/100 [00:06<00:07,  7.04it/s, loss=0.005]
# test-time optim.:  45% 45/100 [00:06<00:07,  7.04it/s, loss=0.005]
# test-time optim.:  45% 45/100 [00:06<00:07,  7.04it/s, loss=0.005]
# test-time optim.:  46% 46/100 [00:06<00:07,  7.03it/s, loss=0.005]
# test-time optim.:  46% 46/100 [00:06<00:07,  7.03it/s, loss=0.005]
# test-time optim.:  47% 47/100 [00:06<00:07,  7.03it/s, loss=0.005]
# test-time optim.:  47% 47/100 [00:07<00:07,  7.03it/s, loss=0.006]
# test-time optim.:  48% 48/100 [00:07<00:07,  7.04it/s, loss=0.006]
# test-time optim.:  48% 48/100 [00:07<00:07,  7.04it/s, loss=0.006]
# test-time optim.:  49% 49/100 [00:07<00:07,  7.03it/s, loss=0.006]
# test-time optim.:  49% 49/100 [00:07<00:07,  7.03it/s, loss=0.006]
# test-time optim.:  50% 50/100 [00:07<00:07,  7.03it/s, loss=0.006]
# test-time optim.:  50% 50/100 [00:07<00:07,  7.03it/s, loss=0.005]
# test-time optim.:  51% 51/100 [00:07<00:07,  7.00it/s, loss=0.005]
# test-time optim.:  51% 51/100 [00:07<00:07,  7.00it/s, loss=0.006]
# test-time optim.:  52% 52/100 [00:07<00:06,  7.05it/s, loss=0.006]
# test-time optim.:  52% 52/100 [00:07<00:06,  7.05it/s, loss=0.005]
# test-time optim.:  53% 53/100 [00:07<00:06,  7.05it/s, loss=0.005]
# test-time optim.:  53% 53/100 [00:07<00:06,  7.05it/s, loss=0.005]
# test-time optim.:  54% 54/100 [00:07<00:06,  7.05it/s, loss=0.005]
# test-time optim.:  54% 54/100 [00:08<00:06,  7.05it/s, loss=0.005]
# test-time optim.:  55% 55/100 [00:08<00:06,  7.05it/s, loss=0.005]
# test-time optim.:  55% 55/100 [00:08<00:06,  7.05it/s, loss=0.005]
# test-time optim.:  56% 56/100 [00:08<00:06,  7.05it/s, loss=0.005]
# test-time optim.:  56% 56/100 [00:08<00:06,  7.05it/s, loss=0.006]
# test-time optim.:  57% 57/100 [00:08<00:06,  7.03it/s, loss=0.006]
# test-time optim.:  57% 57/100 [00:08<00:06,  7.03it/s, loss=0.006]
# test-time optim.:  58% 58/100 [00:08<00:05,  7.02it/s, loss=0.006]
# test-time optim.:  58% 58/100 [00:08<00:05,  7.02it/s, loss=0.005]
# test-time optim.:  59% 59/100 [00:08<00:05,  7.03it/s, loss=0.005]
# test-time optim.:  59% 59/100 [00:08<00:05,  7.03it/s, loss=0.006]
# test-time optim.:  60% 60/100 [00:08<00:05,  6.95it/s, loss=0.006]
# test-time optim.:  60% 60/100 [00:08<00:05,  6.95it/s, loss=0.005]
# test-time optim.:  61% 61/100 [00:08<00:05,  6.92it/s, loss=0.005]
# test-time optim.:  61% 61/100 [00:09<00:05,  6.92it/s, loss=0.004]
# test-time optim.:  62% 62/100 [00:09<00:05,  6.94it/s, loss=0.004]
# test-time optim.:  62% 62/100 [00:09<00:05,  6.94it/s, loss=0.006]
# test-time optim.:  63% 63/100 [00:09<00:05,  6.91it/s, loss=0.006]
# test-time optim.:  63% 63/100 [00:09<00:05,  6.91it/s, loss=0.005]
# test-time optim.:  64% 64/100 [00:09<00:05,  6.92it/s, loss=0.005]
# test-time optim.:  64% 64/100 [00:09<00:05,  6.92it/s, loss=0.005]
# test-time optim.:  65% 65/100 [00:09<00:05,  6.89it/s, loss=0.005]
# test-time optim.:  65% 65/100 [00:09<00:05,  6.89it/s, loss=0.006]
# test-time optim.:  66% 66/100 [00:09<00:04,  6.91it/s, loss=0.006]
# test-time optim.:  66% 66/100 [00:09<00:04,  6.91it/s, loss=0.005]
# test-time optim.:  67% 67/100 [00:09<00:04,  6.89it/s, loss=0.005]
# test-time optim.:  67% 67/100 [00:10<00:04,  6.89it/s, loss=0.006]
# test-time optim.:  68% 68/100 [00:10<00:04,  6.90it/s, loss=0.006]
# test-time optim.:  68% 68/100 [00:10<00:04,  6.90it/s, loss=0.004]
# test-time optim.:  69% 69/100 [00:10<00:04,  6.85it/s, loss=0.004]
# test-time optim.:  69% 69/100 [00:10<00:04,  6.85it/s, loss=0.005]
# test-time optim.:  70% 70/100 [00:10<00:04,  6.88it/s, loss=0.005]
# test-time optim.:  70% 70/100 [00:10<00:04,  6.88it/s, loss=0.005]
# test-time optim.:  71% 71/100 [00:10<00:04,  6.90it/s, loss=0.005]
# test-time optim.:  71% 71/100 [00:10<00:04,  6.90it/s, loss=0.005]
# test-time optim.:  72% 72/100 [00:10<00:04,  6.91it/s, loss=0.005]
# test-time optim.:  72% 72/100 [00:10<00:04,  6.91it/s, loss=0.006]
# test-time optim.:  73% 73/100 [00:10<00:03,  6.94it/s, loss=0.006]
# test-time optim.:  73% 73/100 [00:10<00:03,  6.94it/s, loss=0.006]
# test-time optim.:  74% 74/100 [00:10<00:03,  6.97it/s, loss=0.006]
# test-time optim.:  74% 74/100 [00:11<00:03,  6.97it/s, loss=0.004]
# test-time optim.:  75% 75/100 [00:11<00:03,  6.97it/s, loss=0.004]
# test-time optim.:  75% 75/100 [00:11<00:03,  6.97it/s, loss=0.005]
# test-time optim.:  76% 76/100 [00:11<00:03,  6.97it/s, loss=0.005]
# test-time optim.:  76% 76/100 [00:11<00:03,  6.97it/s, loss=0.006]
# test-time optim.:  77% 77/100 [00:11<00:03,  6.91it/s, loss=0.006]
# test-time optim.:  77% 77/100 [00:11<00:03,  6.91it/s, loss=0.005]
# test-time optim.:  78% 78/100 [00:11<00:03,  6.88it/s, loss=0.005]
# test-time optim.:  78% 78/100 [00:11<00:03,  6.88it/s, loss=0.005]
# test-time optim.:  79% 79/100 [00:11<00:03,  6.86it/s, loss=0.005]
# test-time optim.:  79% 79/100 [00:11<00:03,  6.86it/s, loss=0.006]
# test-time optim.:  80% 80/100 [00:11<00:02,  6.87it/s, loss=0.006]
# test-time optim.:  80% 80/100 [00:11<00:02,  6.87it/s, loss=0.004]
# test-time optim.:  81% 81/100 [00:11<00:02,  6.83it/s, loss=0.004]
# test-time optim.:  81% 81/100 [00:12<00:02,  6.83it/s, loss=0.006]
# test-time optim.:  82% 82/100 [00:12<00:02,  6.70it/s, loss=0.006]
# test-time optim.:  82% 82/100 [00:12<00:02,  6.70it/s, loss=0.006]
# test-time optim.:  83% 83/100 [00:12<00:02,  6.45it/s, loss=0.006]
# test-time optim.:  83% 83/100 [00:12<00:02,  6.45it/s, loss=0.007]
# test-time optim.:  84% 84/100 [00:12<00:02,  6.60it/s, loss=0.007]
# test-time optim.:  84% 84/100 [00:12<00:02,  6.60it/s, loss=0.004]
# test-time optim.:  85% 85/100 [00:12<00:02,  6.70it/s, loss=0.004]
# test-time optim.:  85% 85/100 [00:12<00:02,  6.70it/s, loss=0.005]
# test-time optim.:  86% 86/100 [00:12<00:02,  6.76it/s, loss=0.005]
# test-time optim.:  86% 86/100 [00:12<00:02,  6.76it/s, loss=0.005]
# test-time optim.:  87% 87/100 [00:12<00:01,  6.70it/s, loss=0.005]
# test-time optim.:  87% 87/100 [00:12<00:01,  6.70it/s, loss=0.006]
# test-time optim.:  88% 88/100 [00:12<00:01,  6.33it/s, loss=0.006]
# test-time optim.:  88% 88/100 [00:13<00:01,  6.33it/s, loss=0.005]
# test-time optim.:  89% 89/100 [00:13<00:01,  6.42it/s, loss=0.005]
# test-time optim.:  89% 89/100 [00:13<00:01,  6.42it/s, loss=0.006]
# test-time optim.:  90% 90/100 [00:13<00:01,  6.57it/s, loss=0.006]
# test-time optim.:  90% 90/100 [00:13<00:01,  6.57it/s, loss=0.005]
# test-time optim.:  91% 91/100 [00:13<00:01,  6.68it/s, loss=0.005]
# test-time optim.:  91% 91/100 [00:13<00:01,  6.68it/s, loss=0.005]
# test-time optim.:  92% 92/100 [00:13<00:01,  6.75it/s, loss=0.005]
# test-time optim.:  92% 92/100 [00:13<00:01,  6.75it/s, loss=0.006]
# test-time optim.:  93% 93/100 [00:13<00:01,  6.59it/s, loss=0.006]
# test-time optim.:  93% 93/100 [00:13<00:01,  6.59it/s, loss=0.005]
# test-time optim.:  94% 94/100 [00:13<00:00,  6.44it/s, loss=0.005]
# test-time optim.:  94% 94/100 [00:14<00:00,  6.44it/s, loss=0.005]
# test-time optim.:  95% 95/100 [00:14<00:00,  6.57it/s, loss=0.005]
# test-time optim.:  95% 95/100 [00:14<00:00,  6.57it/s, loss=0.004]
# test-time optim.:  96% 96/100 [00:14<00:00,  6.68it/s, loss=0.004]
# test-time optim.:  96% 96/100 [00:14<00:00,  6.68it/s, loss=0.005]
# test-time optim.:  97% 97/100 [00:14<00:00,  6.76it/s, loss=0.005]
# test-time optim.:  97% 97/100 [00:14<00:00,  6.76it/s, loss=0.005]
# test-time optim.:  98% 98/100 [00:14<00:00,  6.84it/s, loss=0.005]
# test-time optim.:  98% 98/100 [00:14<00:00,  6.84it/s, loss=0.005]
# test-time optim.:  99% 99/100 [00:14<00:00,  6.89it/s, loss=0.005]
# test-time optim.:  99% 99/100 [00:14<00:00,  6.89it/s, loss=0.005]
# test-time optim.: 100% 100/100 [00:14<00:00,  6.86it/s, loss=0.005]
# evaluating:  25% 1/4 [00:24<01:12, 24.24s/it]
# test-time optim.:   0% 0/100 [00:00<?, ?it/s]
# test-time optim.:   0% 0/100 [00:00<?, ?it/s, loss=0.009]
# test-time optim.:   1% 1/100 [00:00<00:14,  6.83it/s, loss=0.009]
# test-time optim.:   1% 1/100 [00:00<00:14,  6.83it/s, loss=0.006]
# test-time optim.:   2% 2/100 [00:00<00:14,  6.83it/s, loss=0.006]
# test-time optim.:   2% 2/100 [00:00<00:14,  6.83it/s, loss=0.007]
# test-time optim.:   3% 3/100 [00:00<00:14,  6.75it/s, loss=0.007]
# test-time optim.:   3% 3/100 [00:00<00:14,  6.75it/s, loss=0.006]
# test-time optim.:   4% 4/100 [00:00<00:14,  6.72it/s, loss=0.006]
# test-time optim.:   4% 4/100 [00:00<00:14,  6.72it/s, loss=0.006]
# test-time optim.:   5% 5/100 [00:00<00:14,  6.72it/s, loss=0.006]
# test-time optim.:   5% 5/100 [00:00<00:14,  6.72it/s, loss=0.007]
# test-time optim.:   6% 6/100 [00:00<00:13,  6.76it/s, loss=0.007]
# test-time optim.:   6% 6/100 [00:01<00:13,  6.76it/s, loss=0.007]
# test-time optim.:   7% 7/100 [00:01<00:13,  6.78it/s, loss=0.007]
# test-time optim.:   7% 7/100 [00:01<00:13,  6.78it/s, loss=0.007]
# test-time optim.:   8% 8/100 [00:01<00:13,  6.79it/s, loss=0.007]
# test-time optim.:   8% 8/100 [00:01<00:13,  6.79it/s, loss=0.006]
# test-time optim.:   9% 9/100 [00:01<00:13,  6.79it/s, loss=0.006]
# test-time optim.:   9% 9/100 [00:01<00:13,  6.79it/s, loss=0.006]
# test-time optim.:  10% 10/100 [00:01<00:13,  6.77it/s, loss=0.006]
# test-time optim.:  10% 10/100 [00:01<00:13,  6.77it/s, loss=0.006]
# test-time optim.:  11% 11/100 [00:01<00:13,  6.83it/s, loss=0.006]
# test-time optim.:  11% 11/100 [00:01<00:13,  6.83it/s, loss=0.006]
# test-time optim.:  12% 12/100 [00:01<00:12,  6.88it/s, loss=0.006]
# test-time optim.:  12% 12/100 [00:01<00:12,  6.88it/s, loss=0.006]
# test-time optim.:  13% 13/100 [00:01<00:12,  6.85it/s, loss=0.006]
# test-time optim.:  13% 13/100 [00:02<00:12,  6.85it/s, loss=0.007]
# test-time optim.:  14% 14/100 [00:02<00:12,  6.85it/s, loss=0.007]
# test-time optim.:  14% 14/100 [00:02<00:12,  6.85it/s, loss=0.005]
# test-time optim.:  15% 15/100 [00:02<00:12,  6.81it/s, loss=0.005]
# test-time optim.:  15% 15/100 [00:02<00:12,  6.81it/s, loss=0.006]
# test-time optim.:  16% 16/100 [00:02<00:12,  6.84it/s, loss=0.006]
# test-time optim.:  16% 16/100 [00:02<00:12,  6.84it/s, loss=0.006]
# test-time optim.:  17% 17/100 [00:02<00:12,  6.82it/s, loss=0.006]
# test-time optim.:  17% 17/100 [00:02<00:12,  6.82it/s, loss=0.007]
# test-time optim.:  18% 18/100 [00:02<00:12,  6.82it/s, loss=0.007]
# test-time optim.:  18% 18/100 [00:02<00:12,  6.82it/s, loss=0.008]
# test-time optim.:  19% 19/100 [00:02<00:11,  6.81it/s, loss=0.008]
# test-time optim.:  19% 19/100 [00:02<00:11,  6.81it/s, loss=0.008]
# test-time optim.:  20% 20/100 [00:02<00:11,  6.85it/s, loss=0.008]
# test-time optim.:  20% 20/100 [00:03<00:11,  6.85it/s, loss=0.005]
# test-time optim.:  21% 21/100 [00:03<00:11,  6.86it/s, loss=0.005]
# test-time optim.:  21% 21/100 [00:03<00:11,  6.86it/s, loss=0.005]
# test-time optim.:  22% 22/100 [00:03<00:11,  6.85it/s, loss=0.005]
# test-time optim.:  22% 22/100 [00:03<00:11,  6.85it/s, loss=0.008]
# test-time optim.:  23% 23/100 [00:03<00:11,  6.82it/s, loss=0.008]
# test-time optim.:  23% 23/100 [00:03<00:11,  6.82it/s, loss=0.006]
# test-time optim.:  24% 24/100 [00:03<00:11,  6.82it/s, loss=0.006]
# test-time optim.:  24% 24/100 [00:03<00:11,  6.82it/s, loss=0.007]
# test-time optim.:  25% 25/100 [00:03<00:11,  6.81it/s, loss=0.007]
# test-time optim.:  25% 25/100 [00:03<00:11,  6.81it/s, loss=0.007]
# test-time optim.:  26% 26/100 [00:03<00:10,  6.81it/s, loss=0.007]
# test-time optim.:  26% 26/100 [00:03<00:10,  6.81it/s, loss=0.005]
# test-time optim.:  27% 27/100 [00:03<00:10,  6.78it/s, loss=0.005]
# test-time optim.:  27% 27/100 [00:04<00:10,  6.78it/s, loss=0.008]
# test-time optim.:  28% 28/100 [00:04<00:10,  6.77it/s, loss=0.008]
# test-time optim.:  28% 28/100 [00:04<00:10,  6.77it/s, loss=0.006]
# test-time optim.:  29% 29/100 [00:04<00:10,  6.77it/s, loss=0.006]
# test-time optim.:  29% 29/100 [00:04<00:10,  6.77it/s, loss=0.007]
# test-time optim.:  30% 30/100 [00:04<00:10,  6.75it/s, loss=0.007]
# test-time optim.:  30% 30/100 [00:04<00:10,  6.75it/s, loss=0.007]
# test-time optim.:  31% 31/100 [00:04<00:10,  6.77it/s, loss=0.007]
# test-time optim.:  31% 31/100 [00:04<00:10,  6.77it/s, loss=0.008]
# test-time optim.:  32% 32/100 [00:04<00:10,  6.78it/s, loss=0.008]
# test-time optim.:  32% 32/100 [00:04<00:10,  6.78it/s, loss=0.005]
# test-time optim.:  33% 33/100 [00:04<00:09,  6.77it/s, loss=0.005]
# test-time optim.:  33% 33/100 [00:04<00:09,  6.77it/s, loss=0.006]
# test-time optim.:  34% 34/100 [00:04<00:09,  6.78it/s, loss=0.006]
# test-time optim.:  34% 34/100 [00:05<00:09,  6.78it/s, loss=0.005]
# test-time optim.:  35% 35/100 [00:05<00:09,  6.79it/s, loss=0.005]
# test-time optim.:  35% 35/100 [00:05<00:09,  6.79it/s, loss=0.006]
# test-time optim.:  36% 36/100 [00:05<00:09,  6.80it/s, loss=0.006]
# test-time optim.:  36% 36/100 [00:05<00:09,  6.80it/s, loss=0.007]
# test-time optim.:  37% 37/100 [00:05<00:09,  6.78it/s, loss=0.007]
# test-time optim.:  37% 37/100 [00:05<00:09,  6.78it/s, loss=0.006]
# test-time optim.:  38% 38/100 [00:05<00:09,  6.79it/s, loss=0.006]
# test-time optim.:  38% 38/100 [00:05<00:09,  6.79it/s, loss=0.007]
# test-time optim.:  39% 39/100 [00:05<00:08,  6.79it/s, loss=0.007]
# test-time optim.:  39% 39/100 [00:05<00:08,  6.79it/s, loss=0.007]
# test-time optim.:  40% 40/100 [00:05<00:08,  6.79it/s, loss=0.007]
# test-time optim.:  40% 40/100 [00:06<00:08,  6.79it/s, loss=0.007]
# test-time optim.:  41% 41/100 [00:06<00:08,  6.76it/s, loss=0.007]
# test-time optim.:  41% 41/100 [00:06<00:08,  6.76it/s, loss=0.007]
# test-time optim.:  42% 42/100 [00:06<00:08,  6.77it/s, loss=0.007]
# test-time optim.:  42% 42/100 [00:06<00:08,  6.77it/s, loss=0.006]
# test-time optim.:  43% 43/100 [00:06<00:08,  6.80it/s, loss=0.006]
# test-time optim.:  43% 43/100 [00:06<00:08,  6.80it/s, loss=0.006]
# test-time optim.:  44% 44/100 [00:06<00:08,  6.79it/s, loss=0.006]
# test-time optim.:  44% 44/100 [00:06<00:08,  6.79it/s, loss=0.006]
# test-time optim.:  45% 45/100 [00:06<00:08,  6.80it/s, loss=0.006]
# test-time optim.:  45% 45/100 [00:06<00:08,  6.80it/s, loss=0.005]
# test-time optim.:  46% 46/100 [00:06<00:07,  6.78it/s, loss=0.005]
# test-time optim.:  46% 46/100 [00:06<00:07,  6.78it/s, loss=0.005]
# test-time optim.:  47% 47/100 [00:06<00:07,  6.80it/s, loss=0.005]
# test-time optim.:  47% 47/100 [00:07<00:07,  6.80it/s, loss=0.006]
# test-time optim.:  48% 48/100 [00:07<00:07,  6.75it/s, loss=0.006]
# test-time optim.:  48% 48/100 [00:07<00:07,  6.75it/s, loss=0.005]
# test-time optim.:  49% 49/100 [00:07<00:07,  6.73it/s, loss=0.005]
# test-time optim.:  49% 49/100 [00:07<00:07,  6.73it/s, loss=0.006]
# test-time optim.:  50% 50/100 [00:07<00:07,  6.74it/s, loss=0.006]
# test-time optim.:  50% 50/100 [00:07<00:07,  6.74it/s, loss=0.005]
# test-time optim.:  51% 51/100 [00:07<00:07,  6.75it/s, loss=0.005]
# test-time optim.:  51% 51/100 [00:07<00:07,  6.75it/s, loss=0.006]
# test-time optim.:  52% 52/100 [00:07<00:07,  6.75it/s, loss=0.006]
# test-time optim.:  52% 52/100 [00:07<00:07,  6.75it/s, loss=0.007]
# test-time optim.:  53% 53/100 [00:07<00:06,  6.77it/s, loss=0.007]
# test-time optim.:  53% 53/100 [00:07<00:06,  6.77it/s, loss=0.006]
# test-time optim.:  54% 54/100 [00:07<00:06,  6.75it/s, loss=0.006]
# test-time optim.:  54% 54/100 [00:08<00:06,  6.75it/s, loss=0.006]
# test-time optim.:  55% 55/100 [00:08<00:06,  6.74it/s, loss=0.006]
# test-time optim.:  55% 55/100 [00:08<00:06,  6.74it/s, loss=0.005]
# test-time optim.:  56% 56/100 [00:08<00:06,  6.76it/s, loss=0.005]
# test-time optim.:  56% 56/100 [00:08<00:06,  6.76it/s, loss=0.007]
# test-time optim.:  57% 57/100 [00:08<00:06,  6.74it/s, loss=0.007]
# test-time optim.:  57% 57/100 [00:08<00:06,  6.74it/s, loss=0.006]
# test-time optim.:  58% 58/100 [00:08<00:06,  6.75it/s, loss=0.006]
# test-time optim.:  58% 58/100 [00:08<00:06,  6.75it/s, loss=0.006]
# test-time optim.:  59% 59/100 [00:08<00:06,  6.77it/s, loss=0.006]
# test-time optim.:  59% 59/100 [00:08<00:06,  6.77it/s, loss=0.005]
# test-time optim.:  60% 60/100 [00:08<00:05,  6.76it/s, loss=0.005]
# test-time optim.:  60% 60/100 [00:08<00:05,  6.76it/s, loss=0.006]
# test-time optim.:  61% 61/100 [00:08<00:05,  6.79it/s, loss=0.006]
# test-time optim.:  61% 61/100 [00:09<00:05,  6.79it/s, loss=0.006]
# test-time optim.:  62% 62/100 [00:09<00:05,  6.76it/s, loss=0.006]
# test-time optim.:  62% 62/100 [00:09<00:05,  6.76it/s, loss=0.006]
# test-time optim.:  63% 63/100 [00:09<00:05,  6.77it/s, loss=0.006]
# test-time optim.:  63% 63/100 [00:09<00:05,  6.77it/s, loss=0.005]
# test-time optim.:  64% 64/100 [00:09<00:05,  6.77it/s, loss=0.005]
# test-time optim.:  64% 64/100 [00:09<00:05,  6.77it/s, loss=0.007]
# test-time optim.:  65% 65/100 [00:09<00:05,  6.75it/s, loss=0.007]
# test-time optim.:  65% 65/100 [00:09<00:05,  6.75it/s, loss=0.005]
# test-time optim.:  66% 66/100 [00:09<00:05,  6.75it/s, loss=0.005]
# test-time optim.:  66% 66/100 [00:09<00:05,  6.75it/s, loss=0.005]
# test-time optim.:  67% 67/100 [00:09<00:04,  6.74it/s, loss=0.005]
# test-time optim.:  67% 67/100 [00:10<00:04,  6.74it/s, loss=0.005]
# test-time optim.:  68% 68/100 [00:10<00:04,  6.75it/s, loss=0.005]
# test-time optim.:  68% 68/100 [00:10<00:04,  6.75it/s, loss=0.006]
# test-time optim.:  69% 69/100 [00:10<00:04,  6.77it/s, loss=0.006]
# test-time optim.:  69% 69/100 [00:10<00:04,  6.77it/s, loss=0.008]
# test-time optim.:  70% 70/100 [00:10<00:04,  6.74it/s, loss=0.008]
# test-time optim.:  70% 70/100 [00:10<00:04,  6.74it/s, loss=0.006]
# test-time optim.:  71% 71/100 [00:10<00:04,  6.74it/s, loss=0.006]
# test-time optim.:  71% 71/100 [00:10<00:04,  6.74it/s, loss=0.007]
# test-time optim.:  72% 72/100 [00:10<00:04,  6.74it/s, loss=0.007]
# test-time optim.:  72% 72/100 [00:10<00:04,  6.74it/s, loss=0.007]
# test-time optim.:  73% 73/100 [00:10<00:04,  6.74it/s, loss=0.007]
# test-time optim.:  73% 73/100 [00:10<00:04,  6.74it/s, loss=0.007]
# test-time optim.:  74% 74/100 [00:10<00:03,  6.69it/s, loss=0.007]
# test-time optim.:  74% 74/100 [00:11<00:03,  6.69it/s, loss=0.007]
# test-time optim.:  75% 75/100 [00:11<00:03,  6.65it/s, loss=0.007]
# test-time optim.:  75% 75/100 [00:11<00:03,  6.65it/s, loss=0.008]
# test-time optim.:  76% 76/100 [00:11<00:03,  6.66it/s, loss=0.008]
# test-time optim.:  76% 76/100 [00:11<00:03,  6.66it/s, loss=0.006]
# test-time optim.:  77% 77/100 [00:11<00:03,  6.64it/s, loss=0.006]
# test-time optim.:  77% 77/100 [00:11<00:03,  6.64it/s, loss=0.007]
# test-time optim.:  78% 78/100 [00:11<00:03,  6.67it/s, loss=0.007]
# test-time optim.:  78% 78/100 [00:11<00:03,  6.67it/s, loss=0.005]
# test-time optim.:  79% 79/100 [00:11<00:03,  6.69it/s, loss=0.005]
# test-time optim.:  79% 79/100 [00:11<00:03,  6.69it/s, loss=0.006]
# test-time optim.:  80% 80/100 [00:11<00:02,  6.68it/s, loss=0.006]
# test-time optim.:  80% 80/100 [00:11<00:02,  6.68it/s, loss=0.007]
# test-time optim.:  81% 81/100 [00:11<00:02,  6.66it/s, loss=0.007]
# test-time optim.:  81% 81/100 [00:12<00:02,  6.66it/s, loss=0.006]
# test-time optim.:  82% 82/100 [00:12<00:02,  6.64it/s, loss=0.006]
# test-time optim.:  82% 82/100 [00:12<00:02,  6.64it/s, loss=0.005]
# test-time optim.:  83% 83/100 [00:12<00:02,  6.65it/s, loss=0.005]
# test-time optim.:  83% 83/100 [00:12<00:02,  6.65it/s, loss=0.005]
# test-time optim.:  84% 84/100 [00:12<00:02,  6.62it/s, loss=0.005]
# test-time optim.:  84% 84/100 [00:12<00:02,  6.62it/s, loss=0.007]
# test-time optim.:  85% 85/100 [00:12<00:02,  6.64it/s, loss=0.007]
# test-time optim.:  85% 85/100 [00:12<00:02,  6.64it/s, loss=0.005]
# test-time optim.:  86% 86/100 [00:12<00:02,  6.58it/s, loss=0.005]
# test-time optim.:  86% 86/100 [00:12<00:02,  6.58it/s, loss=0.005]
# test-time optim.:  87% 87/100 [00:12<00:01,  6.61it/s, loss=0.005]
# test-time optim.:  87% 87/100 [00:13<00:01,  6.61it/s, loss=0.006]
# test-time optim.:  88% 88/100 [00:13<00:01,  6.64it/s, loss=0.006]
# test-time optim.:  88% 88/100 [00:13<00:01,  6.64it/s, loss=0.005]
# test-time optim.:  89% 89/100 [00:13<00:01,  6.67it/s, loss=0.005]
# test-time optim.:  89% 89/100 [00:13<00:01,  6.67it/s, loss=0.005]
# test-time optim.:  90% 90/100 [00:13<00:01,  6.67it/s, loss=0.005]
# test-time optim.:  90% 90/100 [00:13<00:01,  6.67it/s, loss=0.006]
# test-time optim.:  91% 91/100 [00:13<00:01,  6.63it/s, loss=0.006]
# test-time optim.:  91% 91/100 [00:13<00:01,  6.63it/s, loss=0.006]
# test-time optim.:  92% 92/100 [00:13<00:01,  6.63it/s, loss=0.006]
# test-time optim.:  92% 92/100 [00:13<00:01,  6.63it/s, loss=0.005]
# test-time optim.:  93% 93/100 [00:13<00:01,  6.61it/s, loss=0.005]
# test-time optim.:  93% 93/100 [00:13<00:01,  6.61it/s, loss=0.005]
# test-time optim.:  94% 94/100 [00:13<00:00,  6.63it/s, loss=0.005]
# test-time optim.:  94% 94/100 [00:14<00:00,  6.63it/s, loss=0.005]
# test-time optim.:  95% 95/100 [00:14<00:00,  6.65it/s, loss=0.005]
# test-time optim.:  95% 95/100 [00:14<00:00,  6.65it/s, loss=0.006]
# test-time optim.:  96% 96/100 [00:14<00:00,  6.70it/s, loss=0.006]
# test-time optim.:  96% 96/100 [00:14<00:00,  6.70it/s, loss=0.007]
# test-time optim.:  97% 97/100 [00:14<00:00,  6.71it/s, loss=0.007]
# test-time optim.:  97% 97/100 [00:14<00:00,  6.71it/s, loss=0.006]
# test-time optim.:  98% 98/100 [00:14<00:00,  6.72it/s, loss=0.006]
# test-time optim.:  98% 98/100 [00:14<00:00,  6.72it/s, loss=0.005]
# test-time optim.:  99% 99/100 [00:14<00:00,  6.73it/s, loss=0.005]
# test-time optim.:  99% 99/100 [00:14<00:00,  6.73it/s, loss=0.006]
# test-time optim.: 100% 100/100 [00:14<00:00,  6.73it/s, loss=0.006]
# evaluating:  50% 2/4 [00:47<00:47, 23.90s/it]
# test-time optim.:   0% 0/100 [00:00<?, ?it/s]
# test-time optim.:   0% 0/100 [00:00<?, ?it/s, loss=0.008]
# test-time optim.:   1% 1/100 [00:00<00:14,  7.02it/s, loss=0.008]
# test-time optim.:   1% 1/100 [00:00<00:14,  7.02it/s, loss=0.008]
# test-time optim.:   2% 2/100 [00:00<00:14,  6.76it/s, loss=0.008]
# test-time optim.:   2% 2/100 [00:00<00:14,  6.76it/s, loss=0.008]
# test-time optim.:   3% 3/100 [00:00<00:14,  6.66it/s, loss=0.008]
# test-time optim.:   3% 3/100 [00:00<00:14,  6.66it/s, loss=0.007]
# test-time optim.:   4% 4/100 [00:00<00:14,  6.61it/s, loss=0.007]
# test-time optim.:   4% 4/100 [00:00<00:14,  6.61it/s, loss=0.008]
# test-time optim.:   5% 5/100 [00:00<00:14,  6.55it/s, loss=0.008]
# test-time optim.:   5% 5/100 [00:00<00:14,  6.55it/s, loss=0.006]
# test-time optim.:   6% 6/100 [00:00<00:14,  6.46it/s, loss=0.006]
# test-time optim.:   6% 6/100 [00:01<00:14,  6.46it/s, loss=0.010]
# test-time optim.:   7% 7/100 [00:01<00:14,  6.50it/s, loss=0.010]
# test-time optim.:   7% 7/100 [00:01<00:14,  6.50it/s, loss=0.010]
# test-time optim.:   8% 8/100 [00:01<00:14,  6.53it/s, loss=0.010]
# test-time optim.:   8% 8/100 [00:01<00:14,  6.53it/s, loss=0.008]
# test-time optim.:   9% 9/100 [00:01<00:13,  6.52it/s, loss=0.008]
# test-time optim.:   9% 9/100 [00:01<00:13,  6.52it/s, loss=0.007]
# test-time optim.:  10% 10/100 [00:01<00:13,  6.50it/s, loss=0.007]
# test-time optim.:  10% 10/100 [00:01<00:13,  6.50it/s, loss=0.007]
# test-time optim.:  11% 11/100 [00:01<00:13,  6.53it/s, loss=0.007]
# test-time optim.:  11% 11/100 [00:01<00:13,  6.53it/s, loss=0.007]
# test-time optim.:  12% 12/100 [00:01<00:13,  6.54it/s, loss=0.007]
# test-time optim.:  12% 12/100 [00:01<00:13,  6.54it/s, loss=0.007]
# test-time optim.:  13% 13/100 [00:01<00:13,  6.57it/s, loss=0.007]
# test-time optim.:  13% 13/100 [00:02<00:13,  6.57it/s, loss=0.009]
# test-time optim.:  14% 14/100 [00:02<00:13,  6.55it/s, loss=0.009]
# test-time optim.:  14% 14/100 [00:02<00:13,  6.55it/s, loss=0.009]
# test-time optim.:  15% 15/100 [00:02<00:12,  6.58it/s, loss=0.009]
# test-time optim.:  15% 15/100 [00:02<00:12,  6.58it/s, loss=0.006]
# test-time optim.:  16% 16/100 [00:02<00:12,  6.57it/s, loss=0.006]
# test-time optim.:  16% 16/100 [00:02<00:12,  6.57it/s, loss=0.007]
# test-time optim.:  17% 17/100 [00:02<00:12,  6.58it/s, loss=0.007]
# test-time optim.:  17% 17/100 [00:02<00:12,  6.58it/s, loss=0.006]
# test-time optim.:  18% 18/100 [00:02<00:12,  6.56it/s, loss=0.006]
# test-time optim.:  18% 18/100 [00:02<00:12,  6.56it/s, loss=0.009]
# test-time optim.:  19% 19/100 [00:02<00:12,  6.57it/s, loss=0.009]
# test-time optim.:  19% 19/100 [00:03<00:12,  6.57it/s, loss=0.006]
# test-time optim.:  20% 20/100 [00:03<00:12,  6.57it/s, loss=0.006]
# test-time optim.:  20% 20/100 [00:03<00:12,  6.57it/s, loss=0.008]
# test-time optim.:  21% 21/100 [00:03<00:12,  6.58it/s, loss=0.008]
# test-time optim.:  21% 21/100 [00:03<00:12,  6.58it/s, loss=0.007]
# test-time optim.:  22% 22/100 [00:03<00:11,  6.57it/s, loss=0.007]
# test-time optim.:  22% 22/100 [00:03<00:11,  6.57it/s, loss=0.008]
# test-time optim.:  23% 23/100 [00:03<00:11,  6.59it/s, loss=0.008]
# test-time optim.:  23% 23/100 [00:03<00:11,  6.59it/s, loss=0.008]
# test-time optim.:  24% 24/100 [00:03<00:11,  6.61it/s, loss=0.008]
# test-time optim.:  24% 24/100 [00:03<00:11,  6.61it/s, loss=0.006]
# test-time optim.:  25% 25/100 [00:03<00:11,  6.61it/s, loss=0.006]
# test-time optim.:  25% 25/100 [00:03<00:11,  6.61it/s, loss=0.009]
# test-time optim.:  26% 26/100 [00:03<00:11,  6.58it/s, loss=0.009]
# test-time optim.:  26% 26/100 [00:04<00:11,  6.58it/s, loss=0.009]
# test-time optim.:  27% 27/100 [00:04<00:11,  6.59it/s, loss=0.009]
# test-time optim.:  27% 27/100 [00:04<00:11,  6.59it/s, loss=0.008]
# test-time optim.:  28% 28/100 [00:04<00:10,  6.58it/s, loss=0.008]
# test-time optim.:  28% 28/100 [00:04<00:10,  6.58it/s, loss=0.006]
# test-time optim.:  29% 29/100 [00:04<00:10,  6.60it/s, loss=0.006]
# test-time optim.:  29% 29/100 [00:04<00:10,  6.60it/s, loss=0.007]
# test-time optim.:  30% 30/100 [00:04<00:10,  6.58it/s, loss=0.007]
# test-time optim.:  30% 30/100 [00:04<00:10,  6.58it/s, loss=0.007]
# test-time optim.:  31% 31/100 [00:04<00:10,  6.60it/s, loss=0.007]
# test-time optim.:  31% 31/100 [00:04<00:10,  6.60it/s, loss=0.009]
# test-time optim.:  32% 32/100 [00:04<00:10,  6.56it/s, loss=0.009]
# test-time optim.:  32% 32/100 [00:05<00:10,  6.56it/s, loss=0.007]
# test-time optim.:  33% 33/100 [00:05<00:10,  6.58it/s, loss=0.007]
# test-time optim.:  33% 33/100 [00:05<00:10,  6.58it/s, loss=0.009]
# test-time optim.:  34% 34/100 [00:05<00:10,  6.58it/s, loss=0.009]
# test-time optim.:  34% 34/100 [00:05<00:10,  6.58it/s, loss=0.008]
# test-time optim.:  35% 35/100 [00:05<00:09,  6.60it/s, loss=0.008]
# test-time optim.:  35% 35/100 [00:05<00:09,  6.60it/s, loss=0.008]
# test-time optim.:  36% 36/100 [00:05<00:09,  6.59it/s, loss=0.008]
# test-time optim.:  36% 36/100 [00:05<00:09,  6.59it/s, loss=0.008]
# test-time optim.:  37% 37/100 [00:05<00:09,  6.60it/s, loss=0.008]
# test-time optim.:  37% 37/100 [00:05<00:09,  6.60it/s, loss=0.008]
# test-time optim.:  38% 38/100 [00:05<00:09,  6.58it/s, loss=0.008]
# test-time optim.:  38% 38/100 [00:05<00:09,  6.58it/s, loss=0.008]
# test-time optim.:  39% 39/100 [00:05<00:09,  6.59it/s, loss=0.008]
# test-time optim.:  39% 39/100 [00:06<00:09,  6.59it/s, loss=0.008]
# test-time optim.:  40% 40/100 [00:06<00:09,  6.59it/s, loss=0.008]
# test-time optim.:  40% 40/100 [00:06<00:09,  6.59it/s, loss=0.008]
# test-time optim.:  41% 41/100 [00:06<00:08,  6.59it/s, loss=0.008]
# test-time optim.:  41% 41/100 [00:06<00:08,  6.59it/s, loss=0.008]
# test-time optim.:  42% 42/100 [00:06<00:08,  6.58it/s, loss=0.008]
# test-time optim.:  42% 42/100 [00:06<00:08,  6.58it/s, loss=0.008]
# test-time optim.:  43% 43/100 [00:06<00:08,  6.60it/s, loss=0.008]
# test-time optim.:  43% 43/100 [00:06<00:08,  6.60it/s, loss=0.007]
# test-time optim.:  44% 44/100 [00:06<00:08,  6.58it/s, loss=0.007]
# test-time optim.:  44% 44/100 [00:06<00:08,  6.58it/s, loss=0.006]
# test-time optim.:  45% 45/100 [00:06<00:08,  6.59it/s, loss=0.006]
# test-time optim.:  45% 45/100 [00:06<00:08,  6.59it/s, loss=0.008]
# test-time optim.:  46% 46/100 [00:06<00:08,  6.59it/s, loss=0.008]
# test-time optim.:  46% 46/100 [00:07<00:08,  6.59it/s, loss=0.008]
# test-time optim.:  47% 47/100 [00:07<00:08,  6.61it/s, loss=0.008]
# test-time optim.:  47% 47/100 [00:07<00:08,  6.61it/s, loss=0.005]
# test-time optim.:  48% 48/100 [00:07<00:07,  6.57it/s, loss=0.005]
# test-time optim.:  48% 48/100 [00:07<00:07,  6.57it/s, loss=0.008]
# test-time optim.:  49% 49/100 [00:07<00:07,  6.58it/s, loss=0.008]
# test-time optim.:  49% 49/100 [00:07<00:07,  6.58it/s, loss=0.007]
# test-time optim.:  50% 50/100 [00:07<00:07,  6.58it/s, loss=0.007]
# test-time optim.:  50% 50/100 [00:07<00:07,  6.58it/s, loss=0.008]
# test-time optim.:  51% 51/100 [00:07<00:07,  6.57it/s, loss=0.008]
# test-time optim.:  51% 51/100 [00:07<00:07,  6.57it/s, loss=0.008]
# test-time optim.:  52% 52/100 [00:07<00:07,  6.58it/s, loss=0.008]
# test-time optim.:  52% 52/100 [00:08<00:07,  6.58it/s, loss=0.008]
# test-time optim.:  53% 53/100 [00:08<00:07,  6.59it/s, loss=0.008]
# test-time optim.:  53% 53/100 [00:08<00:07,  6.59it/s, loss=0.008]
# test-time optim.:  54% 54/100 [00:08<00:06,  6.59it/s, loss=0.008]
# test-time optim.:  54% 54/100 [00:08<00:06,  6.59it/s, loss=0.006]
# test-time optim.:  55% 55/100 [00:08<00:06,  6.59it/s, loss=0.006]
# test-time optim.:  55% 55/100 [00:08<00:06,  6.59it/s, loss=0.009]
# test-time optim.:  56% 56/100 [00:08<00:06,  6.59it/s, loss=0.009]
# test-time optim.:  56% 56/100 [00:08<00:06,  6.59it/s, loss=0.008]
# test-time optim.:  57% 57/100 [00:08<00:06,  6.60it/s, loss=0.008]
# test-time optim.:  57% 57/100 [00:08<00:06,  6.60it/s, loss=0.006]
# test-time optim.:  58% 58/100 [00:08<00:06,  6.58it/s, loss=0.006]
# test-time optim.:  58% 58/100 [00:08<00:06,  6.58it/s, loss=0.007]
# test-time optim.:  59% 59/100 [00:08<00:06,  6.60it/s, loss=0.007]
# test-time optim.:  59% 59/100 [00:09<00:06,  6.60it/s, loss=0.008]
# test-time optim.:  60% 60/100 [00:09<00:06,  6.58it/s, loss=0.008]
# test-time optim.:  60% 60/100 [00:09<00:06,  6.58it/s, loss=0.007]
# test-time optim.:  61% 61/100 [00:09<00:05,  6.59it/s, loss=0.007]
# test-time optim.:  61% 61/100 [00:09<00:05,  6.59it/s, loss=0.005]
# test-time optim.:  62% 62/100 [00:09<00:05,  6.59it/s, loss=0.005]
# test-time optim.:  62% 62/100 [00:09<00:05,  6.59it/s, loss=0.008]
# test-time optim.:  63% 63/100 [00:09<00:05,  6.60it/s, loss=0.008]
# test-time optim.:  63% 63/100 [00:09<00:05,  6.60it/s, loss=0.006]
# test-time optim.:  64% 64/100 [00:09<00:05,  6.57it/s, loss=0.006]
# test-time optim.:  64% 64/100 [00:09<00:05,  6.57it/s, loss=0.008]
# test-time optim.:  65% 65/100 [00:09<00:05,  6.57it/s, loss=0.008]
# test-time optim.:  65% 65/100 [00:10<00:05,  6.57it/s, loss=0.006]
# test-time optim.:  66% 66/100 [00:10<00:05,  6.58it/s, loss=0.006]
# test-time optim.:  66% 66/100 [00:10<00:05,  6.58it/s, loss=0.008]
# test-time optim.:  67% 67/100 [00:10<00:05,  6.59it/s, loss=0.008]
# test-time optim.:  67% 67/100 [00:10<00:05,  6.59it/s, loss=0.006]
# test-time optim.:  68% 68/100 [00:10<00:04,  6.58it/s, loss=0.006]
# test-time optim.:  68% 68/100 [00:10<00:04,  6.58it/s, loss=0.007]
# test-time optim.:  69% 69/100 [00:10<00:04,  6.59it/s, loss=0.007]
# test-time optim.:  69% 69/100 [00:10<00:04,  6.59it/s, loss=0.007]
# test-time optim.:  70% 70/100 [00:10<00:04,  6.59it/s, loss=0.007]
# test-time optim.:  70% 70/100 [00:10<00:04,  6.59it/s, loss=0.006]
# test-time optim.:  71% 71/100 [00:10<00:04,  6.59it/s, loss=0.006]
# test-time optim.:  71% 71/100 [00:10<00:04,  6.59it/s, loss=0.008]
# test-time optim.:  72% 72/100 [00:10<00:04,  6.58it/s, loss=0.008]
# test-time optim.:  72% 72/100 [00:11<00:04,  6.58it/s, loss=0.007]
# test-time optim.:  73% 73/100 [00:11<00:04,  6.59it/s, loss=0.007]
# test-time optim.:  73% 73/100 [00:11<00:04,  6.59it/s, loss=0.008]
# test-time optim.:  74% 74/100 [00:11<00:03,  6.57it/s, loss=0.008]
# test-time optim.:  74% 74/100 [00:11<00:03,  6.57it/s, loss=0.007]
# test-time optim.:  75% 75/100 [00:11<00:03,  6.58it/s, loss=0.007]
# test-time optim.:  75% 75/100 [00:11<00:03,  6.58it/s, loss=0.007]
# test-time optim.:  76% 76/100 [00:11<00:03,  6.58it/s, loss=0.007]
# test-time optim.:  76% 76/100 [00:11<00:03,  6.58it/s, loss=0.006]
# test-time optim.:  77% 77/100 [00:11<00:03,  6.59it/s, loss=0.006]
# test-time optim.:  77% 77/100 [00:11<00:03,  6.59it/s, loss=0.007]
# test-time optim.:  78% 78/100 [00:11<00:03,  6.59it/s, loss=0.007]
# test-time optim.:  78% 78/100 [00:12<00:03,  6.59it/s, loss=0.008]
# test-time optim.:  79% 79/100 [00:12<00:03,  6.60it/s, loss=0.008]
# test-time optim.:  79% 79/100 [00:12<00:03,  6.60it/s, loss=0.007]
# test-time optim.:  80% 80/100 [00:12<00:03,  6.58it/s, loss=0.007]
# test-time optim.:  80% 80/100 [00:12<00:03,  6.58it/s, loss=0.007]
# test-time optim.:  81% 81/100 [00:12<00:02,  6.58it/s, loss=0.007]
# test-time optim.:  81% 81/100 [00:12<00:02,  6.58it/s, loss=0.007]
# test-time optim.:  82% 82/100 [00:12<00:02,  6.58it/s, loss=0.007]
# test-time optim.:  82% 82/100 [00:12<00:02,  6.58it/s, loss=0.007]
# test-time optim.:  83% 83/100 [00:12<00:02,  6.59it/s, loss=0.007]
# test-time optim.:  83% 83/100 [00:12<00:02,  6.59it/s, loss=0.010]
# test-time optim.:  84% 84/100 [00:12<00:02,  6.58it/s, loss=0.010]
# test-time optim.:  84% 84/100 [00:12<00:02,  6.58it/s, loss=0.009]
# test-time optim.:  85% 85/100 [00:12<00:02,  6.57it/s, loss=0.009]
# test-time optim.:  85% 85/100 [00:13<00:02,  6.57it/s, loss=0.006]
# test-time optim.:  86% 86/100 [00:13<00:02,  6.54it/s, loss=0.006]
# test-time optim.:  86% 86/100 [00:13<00:02,  6.54it/s, loss=0.007]
# test-time optim.:  87% 87/100 [00:13<00:01,  6.52it/s, loss=0.007]
# test-time optim.:  87% 87/100 [00:13<00:01,  6.52it/s, loss=0.007]
# test-time optim.:  88% 88/100 [00:13<00:01,  6.51it/s, loss=0.007]
# test-time optim.:  88% 88/100 [00:13<00:01,  6.51it/s, loss=0.008]
# test-time optim.:  89% 89/100 [00:13<00:01,  6.46it/s, loss=0.008]
# test-time optim.:  89% 89/100 [00:13<00:01,  6.46it/s, loss=0.007]
# test-time optim.:  90% 90/100 [00:13<00:01,  6.42it/s, loss=0.007]
# test-time optim.:  90% 90/100 [00:13<00:01,  6.42it/s, loss=0.006]
# test-time optim.:  91% 91/100 [00:13<00:01,  6.46it/s, loss=0.006]
# test-time optim.:  91% 91/100 [00:14<00:01,  6.46it/s, loss=0.006]
# test-time optim.:  92% 92/100 [00:14<00:01,  6.48it/s, loss=0.006]
# test-time optim.:  92% 92/100 [00:14<00:01,  6.48it/s, loss=0.010]
# test-time optim.:  93% 93/100 [00:14<00:01,  6.49it/s, loss=0.010]
# test-time optim.:  93% 93/100 [00:14<00:01,  6.49it/s, loss=0.008]
# test-time optim.:  94% 94/100 [00:14<00:00,  6.49it/s, loss=0.008]
# test-time optim.:  94% 94/100 [00:14<00:00,  6.49it/s, loss=0.006]
# test-time optim.:  95% 95/100 [00:14<00:00,  6.46it/s, loss=0.006]
# test-time optim.:  95% 95/100 [00:14<00:00,  6.46it/s, loss=0.007]
# test-time optim.:  96% 96/100 [00:14<00:00,  6.47it/s, loss=0.007]
# test-time optim.:  96% 96/100 [00:14<00:00,  6.47it/s, loss=0.006]
# test-time optim.:  97% 97/100 [00:14<00:00,  6.45it/s, loss=0.006]
# test-time optim.:  97% 97/100 [00:14<00:00,  6.45it/s, loss=0.007]
# test-time optim.:  98% 98/100 [00:14<00:00,  6.43it/s, loss=0.007]
# test-time optim.:  98% 98/100 [00:15<00:00,  6.43it/s, loss=0.009]
# test-time optim.:  99% 99/100 [00:15<00:00,  6.46it/s, loss=0.009]
# test-time optim.:  99% 99/100 [00:15<00:00,  6.46it/s, loss=0.008]
# test-time optim.: 100% 100/100 [00:15<00:00,  6.47it/s, loss=0.008]
# evaluating:  75% 3/4 [01:12<00:24, 24.19s/it]
# test-time optim.:   0% 0/100 [00:00<?, ?it/s]
# test-time optim.:   0% 0/100 [00:00<?, ?it/s, loss=0.009]
# test-time optim.:   1% 1/100 [00:00<00:14,  6.85it/s, loss=0.009]
# test-time optim.:   1% 1/100 [00:00<00:14,  6.85it/s, loss=0.008]
# test-time optim.:   2% 2/100 [00:00<00:14,  6.62it/s, loss=0.008]
# test-time optim.:   2% 2/100 [00:00<00:14,  6.62it/s, loss=0.008]
# test-time optim.:   3% 3/100 [00:00<00:14,  6.57it/s, loss=0.008]
# test-time optim.:   3% 3/100 [00:00<00:14,  6.57it/s, loss=0.007]
# test-time optim.:   4% 4/100 [00:00<00:14,  6.55it/s, loss=0.007]
# test-time optim.:   4% 4/100 [00:00<00:14,  6.55it/s, loss=0.009]
# test-time optim.:   5% 5/100 [00:00<00:14,  6.52it/s, loss=0.009]
# test-time optim.:   5% 5/100 [00:00<00:14,  6.52it/s, loss=0.008]
# test-time optim.:   6% 6/100 [00:00<00:14,  6.31it/s, loss=0.008]
# test-time optim.:   6% 6/100 [00:01<00:14,  6.31it/s, loss=0.007]
# test-time optim.:   7% 7/100 [00:01<00:14,  6.33it/s, loss=0.007]
# test-time optim.:   7% 7/100 [00:01<00:14,  6.33it/s, loss=0.006]
# test-time optim.:   8% 8/100 [00:01<00:14,  6.37it/s, loss=0.006]
# test-time optim.:   8% 8/100 [00:01<00:14,  6.37it/s, loss=0.008]
# test-time optim.:   9% 9/100 [00:01<00:14,  6.43it/s, loss=0.008]
# test-time optim.:   9% 9/100 [00:01<00:14,  6.43it/s, loss=0.007]
# test-time optim.:  10% 10/100 [00:01<00:13,  6.45it/s, loss=0.007]
# test-time optim.:  10% 10/100 [00:01<00:13,  6.45it/s, loss=0.009]
# test-time optim.:  11% 11/100 [00:01<00:13,  6.49it/s, loss=0.009]
# test-time optim.:  11% 11/100 [00:01<00:13,  6.49it/s, loss=0.009]
# test-time optim.:  12% 12/100 [00:01<00:13,  6.47it/s, loss=0.009]
# test-time optim.:  12% 12/100 [00:02<00:13,  6.47it/s, loss=0.008]
# test-time optim.:  13% 13/100 [00:02<00:13,  6.39it/s, loss=0.008]
# test-time optim.:  13% 13/100 [00:02<00:13,  6.39it/s, loss=0.008]
# test-time optim.:  14% 14/100 [00:02<00:13,  6.37it/s, loss=0.008]
# test-time optim.:  14% 14/100 [00:02<00:13,  6.37it/s, loss=0.007]
# test-time optim.:  15% 15/100 [00:02<00:13,  6.40it/s, loss=0.007]
# test-time optim.:  15% 15/100 [00:02<00:13,  6.40it/s, loss=0.010]
# test-time optim.:  16% 16/100 [00:02<00:13,  6.41it/s, loss=0.010]
# test-time optim.:  16% 16/100 [00:02<00:13,  6.41it/s, loss=0.007]
# test-time optim.:  17% 17/100 [00:02<00:12,  6.40it/s, loss=0.007]
# test-time optim.:  17% 17/100 [00:02<00:12,  6.40it/s, loss=0.009]
# test-time optim.:  18% 18/100 [00:02<00:12,  6.43it/s, loss=0.009]
# test-time optim.:  18% 18/100 [00:02<00:12,  6.43it/s, loss=0.008]
# test-time optim.:  19% 19/100 [00:02<00:12,  6.40it/s, loss=0.008]
# test-time optim.:  19% 19/100 [00:03<00:12,  6.40it/s, loss=0.006]
# test-time optim.:  20% 20/100 [00:03<00:12,  6.39it/s, loss=0.006]
# test-time optim.:  20% 20/100 [00:03<00:12,  6.39it/s, loss=0.007]
# test-time optim.:  21% 21/100 [00:03<00:12,  6.40it/s, loss=0.007]
# test-time optim.:  21% 21/100 [00:03<00:12,  6.40it/s, loss=0.008]
# test-time optim.:  22% 22/100 [00:03<00:12,  6.41it/s, loss=0.008]
# test-time optim.:  22% 22/100 [00:03<00:12,  6.41it/s, loss=0.009]
# test-time optim.:  23% 23/100 [00:03<00:12,  6.40it/s, loss=0.009]
# test-time optim.:  23% 23/100 [00:03<00:12,  6.40it/s, loss=0.009]
# test-time optim.:  24% 24/100 [00:03<00:11,  6.41it/s, loss=0.009]
# test-time optim.:  24% 24/100 [00:03<00:11,  6.41it/s, loss=0.007]
# test-time optim.:  25% 25/100 [00:03<00:11,  6.42it/s, loss=0.007]
# test-time optim.:  25% 25/100 [00:04<00:11,  6.42it/s, loss=0.006]
# test-time optim.:  26% 26/100 [00:04<00:11,  6.38it/s, loss=0.006]
# test-time optim.:  26% 26/100 [00:04<00:11,  6.38it/s, loss=0.007]
# test-time optim.:  27% 27/100 [00:04<00:11,  6.38it/s, loss=0.007]
# test-time optim.:  27% 27/100 [00:04<00:11,  6.38it/s, loss=0.006]
# test-time optim.:  28% 28/100 [00:04<00:11,  6.41it/s, loss=0.006]
# test-time optim.:  28% 28/100 [00:04<00:11,  6.41it/s, loss=0.008]
# test-time optim.:  29% 29/100 [00:04<00:11,  6.41it/s, loss=0.008]
# test-time optim.:  29% 29/100 [00:04<00:11,  6.41it/s, loss=0.010]
# test-time optim.:  30% 30/100 [00:04<00:10,  6.40it/s, loss=0.010]
# test-time optim.:  30% 30/100 [00:04<00:10,  6.40it/s, loss=0.008]
# test-time optim.:  31% 31/100 [00:04<00:10,  6.38it/s, loss=0.008]
# test-time optim.:  31% 31/100 [00:04<00:10,  6.38it/s, loss=0.009]
# test-time optim.:  32% 32/100 [00:04<00:10,  6.40it/s, loss=0.009]
# test-time optim.:  32% 32/100 [00:05<00:10,  6.40it/s, loss=0.008]
# test-time optim.:  33% 33/100 [00:05<00:10,  6.38it/s, loss=0.008]
# test-time optim.:  33% 33/100 [00:05<00:10,  6.38it/s, loss=0.008]
# test-time optim.:  34% 34/100 [00:05<00:10,  6.39it/s, loss=0.008]
# test-time optim.:  34% 34/100 [00:05<00:10,  6.39it/s, loss=0.007]
# test-time optim.:  35% 35/100 [00:05<00:10,  6.42it/s, loss=0.007]
# test-time optim.:  35% 35/100 [00:05<00:10,  6.42it/s, loss=0.006]
# test-time optim.:  36% 36/100 [00:05<00:09,  6.44it/s, loss=0.006]
# test-time optim.:  36% 36/100 [00:05<00:09,  6.44it/s, loss=0.008]
# test-time optim.:  37% 37/100 [00:05<00:09,  6.44it/s, loss=0.008]
# test-time optim.:  37% 37/100 [00:05<00:09,  6.44it/s, loss=0.008]
# test-time optim.:  38% 38/100 [00:05<00:09,  6.48it/s, loss=0.008]
# test-time optim.:  38% 38/100 [00:06<00:09,  6.48it/s, loss=0.009]
# test-time optim.:  39% 39/100 [00:06<00:09,  6.48it/s, loss=0.009]
# test-time optim.:  39% 39/100 [00:06<00:09,  6.48it/s, loss=0.008]
# test-time optim.:  40% 40/100 [00:06<00:09,  6.48it/s, loss=0.008]
# test-time optim.:  40% 40/100 [00:06<00:09,  6.48it/s, loss=0.007]
# test-time optim.:  41% 41/100 [00:06<00:09,  6.48it/s, loss=0.007]
# test-time optim.:  41% 41/100 [00:06<00:09,  6.48it/s, loss=0.008]
# test-time optim.:  42% 42/100 [00:06<00:08,  6.47it/s, loss=0.008]
# test-time optim.:  42% 42/100 [00:06<00:08,  6.47it/s, loss=0.007]
# test-time optim.:  43% 43/100 [00:06<00:08,  6.50it/s, loss=0.007]
# test-time optim.:  43% 43/100 [00:06<00:08,  6.50it/s, loss=0.008]
# test-time optim.:  44% 44/100 [00:06<00:08,  6.50it/s, loss=0.008]
# test-time optim.:  44% 44/100 [00:06<00:08,  6.50it/s, loss=0.008]
# test-time optim.:  45% 45/100 [00:06<00:08,  6.49it/s, loss=0.008]
# test-time optim.:  45% 45/100 [00:07<00:08,  6.49it/s, loss=0.008]
# test-time optim.:  46% 46/100 [00:07<00:08,  6.48it/s, loss=0.008]
# test-time optim.:  46% 46/100 [00:07<00:08,  6.48it/s, loss=0.010]
# test-time optim.:  47% 47/100 [00:07<00:08,  6.48it/s, loss=0.010]
# test-time optim.:  47% 47/100 [00:07<00:08,  6.48it/s, loss=0.009]
# test-time optim.:  48% 48/100 [00:07<00:08,  6.49it/s, loss=0.009]
# test-time optim.:  48% 48/100 [00:07<00:08,  6.49it/s, loss=0.007]
# test-time optim.:  49% 49/100 [00:07<00:07,  6.51it/s, loss=0.007]
# test-time optim.:  49% 49/100 [00:07<00:07,  6.51it/s, loss=0.007]
# test-time optim.:  50% 50/100 [00:07<00:07,  6.51it/s, loss=0.007]
# test-time optim.:  50% 50/100 [00:07<00:07,  6.51it/s, loss=0.009]
# test-time optim.:  51% 51/100 [00:07<00:07,  6.51it/s, loss=0.009]
# test-time optim.:  51% 51/100 [00:08<00:07,  6.51it/s, loss=0.008]
# test-time optim.:  52% 52/100 [00:08<00:07,  6.49it/s, loss=0.008]
# test-time optim.:  52% 52/100 [00:08<00:07,  6.49it/s, loss=0.007]
# test-time optim.:  53% 53/100 [00:08<00:07,  6.48it/s, loss=0.007]
# test-time optim.:  53% 53/100 [00:08<00:07,  6.48it/s, loss=0.009]
# test-time optim.:  54% 54/100 [00:08<00:07,  6.46it/s, loss=0.009]
# test-time optim.:  54% 54/100 [00:08<00:07,  6.46it/s, loss=0.009]
# test-time optim.:  55% 55/100 [00:08<00:06,  6.45it/s, loss=0.009]
# test-time optim.:  55% 55/100 [00:08<00:06,  6.45it/s, loss=0.008]
# test-time optim.:  56% 56/100 [00:08<00:06,  6.48it/s, loss=0.008]
# test-time optim.:  56% 56/100 [00:08<00:06,  6.48it/s, loss=0.008]
# test-time optim.:  57% 57/100 [00:08<00:06,  6.50it/s, loss=0.008]
# test-time optim.:  57% 57/100 [00:08<00:06,  6.50it/s, loss=0.008]
# test-time optim.:  58% 58/100 [00:08<00:06,  6.52it/s, loss=0.008]
# test-time optim.:  58% 58/100 [00:09<00:06,  6.52it/s, loss=0.011]
# test-time optim.:  59% 59/100 [00:09<00:06,  6.53it/s, loss=0.011]
# test-time optim.:  59% 59/100 [00:09<00:06,  6.53it/s, loss=0.006]
# test-time optim.:  60% 60/100 [00:09<00:06,  6.54it/s, loss=0.006]
# test-time optim.:  60% 60/100 [00:09<00:06,  6.54it/s, loss=0.008]
# test-time optim.:  61% 61/100 [00:09<00:06,  6.50it/s, loss=0.008]
# test-time optim.:  61% 61/100 [00:09<00:06,  6.50it/s, loss=0.010]
# test-time optim.:  62% 62/100 [00:09<00:05,  6.49it/s, loss=0.010]
# test-time optim.:  62% 62/100 [00:09<00:05,  6.49it/s, loss=0.010]
# test-time optim.:  63% 63/100 [00:09<00:05,  6.51it/s, loss=0.010]
# test-time optim.:  63% 63/100 [00:09<00:05,  6.51it/s, loss=0.006]
# test-time optim.:  64% 64/100 [00:09<00:05,  6.52it/s, loss=0.006]
# test-time optim.:  64% 64/100 [00:10<00:05,  6.52it/s, loss=0.008]
# test-time optim.:  65% 65/100 [00:10<00:05,  6.54it/s, loss=0.008]
# test-time optim.:  65% 65/100 [00:10<00:05,  6.54it/s, loss=0.009]
# test-time optim.:  66% 66/100 [00:10<00:05,  6.54it/s, loss=0.009]
# test-time optim.:  66% 66/100 [00:10<00:05,  6.54it/s, loss=0.007]
# test-time optim.:  67% 67/100 [00:10<00:05,  6.54it/s, loss=0.007]
# test-time optim.:  67% 67/100 [00:10<00:05,  6.54it/s, loss=0.008]
# test-time optim.:  68% 68/100 [00:10<00:04,  6.53it/s, loss=0.008]
# test-time optim.:  68% 68/100 [00:10<00:04,  6.53it/s, loss=0.008]
# test-time optim.:  69% 69/100 [00:10<00:04,  6.53it/s, loss=0.008]
# test-time optim.:  69% 69/100 [00:10<00:04,  6.53it/s, loss=0.009]
# test-time optim.:  70% 70/100 [00:10<00:04,  6.52it/s, loss=0.009]
# test-time optim.:  70% 70/100 [00:10<00:04,  6.52it/s, loss=0.010]
# test-time optim.:  71% 71/100 [00:10<00:04,  6.52it/s, loss=0.010]
# test-time optim.:  71% 71/100 [00:11<00:04,  6.52it/s, loss=0.007]
# test-time optim.:  72% 72/100 [00:11<00:04,  6.52it/s, loss=0.007]
# test-time optim.:  72% 72/100 [00:11<00:04,  6.52it/s, loss=0.008]
# test-time optim.:  73% 73/100 [00:11<00:04,  6.52it/s, loss=0.008]
# test-time optim.:  73% 73/100 [00:11<00:04,  6.52it/s, loss=0.008]
# test-time optim.:  74% 74/100 [00:11<00:03,  6.54it/s, loss=0.008]
# test-time optim.:  74% 74/100 [00:11<00:03,  6.54it/s, loss=0.008]
# test-time optim.:  75% 75/100 [00:11<00:03,  6.55it/s, loss=0.008]
# test-time optim.:  75% 75/100 [00:11<00:03,  6.55it/s, loss=0.009]
# test-time optim.:  76% 76/100 [00:11<00:03,  6.56it/s, loss=0.009]
# test-time optim.:  76% 76/100 [00:11<00:03,  6.56it/s, loss=0.009]
# test-time optim.:  77% 77/100 [00:11<00:03,  6.57it/s, loss=0.009]
# test-time optim.:  77% 77/100 [00:12<00:03,  6.57it/s, loss=0.007]
# test-time optim.:  78% 78/100 [00:12<00:03,  6.58it/s, loss=0.007]
# test-time optim.:  78% 78/100 [00:12<00:03,  6.58it/s, loss=0.006]
# test-time optim.:  79% 79/100 [00:12<00:03,  6.56it/s, loss=0.006]
# test-time optim.:  79% 79/100 [00:12<00:03,  6.56it/s, loss=0.008]
# test-time optim.:  80% 80/100 [00:12<00:03,  6.52it/s, loss=0.008]
# test-time optim.:  80% 80/100 [00:12<00:03,  6.52it/s, loss=0.007]
# test-time optim.:  81% 81/100 [00:12<00:02,  6.50it/s, loss=0.007]
# test-time optim.:  81% 81/100 [00:12<00:02,  6.50it/s, loss=0.007]
# test-time optim.:  82% 82/100 [00:12<00:02,  6.50it/s, loss=0.007]
# test-time optim.:  82% 82/100 [00:12<00:02,  6.50it/s, loss=0.007]
# test-time optim.:  83% 83/100 [00:12<00:02,  6.53it/s, loss=0.007]
# test-time optim.:  83% 83/100 [00:12<00:02,  6.53it/s, loss=0.008]
# test-time optim.:  84% 84/100 [00:12<00:02,  6.54it/s, loss=0.008]
# test-time optim.:  84% 84/100 [00:13<00:02,  6.54it/s, loss=0.008]
# test-time optim.:  85% 85/100 [00:13<00:02,  6.55it/s, loss=0.008]
# test-time optim.:  85% 85/100 [00:13<00:02,  6.55it/s, loss=0.009]
# test-time optim.:  86% 86/100 [00:13<00:02,  6.56it/s, loss=0.009]
# test-time optim.:  86% 86/100 [00:13<00:02,  6.56it/s, loss=0.009]
# test-time optim.:  87% 87/100 [00:13<00:01,  6.57it/s, loss=0.009]
# test-time optim.:  87% 87/100 [00:13<00:01,  6.57it/s, loss=0.008]
# test-time optim.:  88% 88/100 [00:13<00:01,  6.57it/s, loss=0.008]
# test-time optim.:  88% 88/100 [00:13<00:01,  6.57it/s, loss=0.007]
# test-time optim.:  89% 89/100 [00:13<00:01,  6.57it/s, loss=0.007]
# test-time optim.:  89% 89/100 [00:13<00:01,  6.57it/s, loss=0.007]
# test-time optim.:  90% 90/100 [00:13<00:01,  6.57it/s, loss=0.007]
# test-time optim.:  90% 90/100 [00:14<00:01,  6.57it/s, loss=0.009]
# test-time optim.:  91% 91/100 [00:14<00:01,  6.58it/s, loss=0.009]
# test-time optim.:  91% 91/100 [00:14<00:01,  6.58it/s, loss=0.009]
# test-time optim.:  92% 92/100 [00:14<00:01,  6.57it/s, loss=0.009]
# test-time optim.:  92% 92/100 [00:14<00:01,  6.57it/s, loss=0.009]
# test-time optim.:  93% 93/100 [00:14<00:01,  6.59it/s, loss=0.009]
# test-time optim.:  93% 93/100 [00:14<00:01,  6.59it/s, loss=0.006]
# test-time optim.:  94% 94/100 [00:14<00:00,  6.58it/s, loss=0.006]
# test-time optim.:  94% 94/100 [00:14<00:00,  6.58it/s, loss=0.007]
# test-time optim.:  95% 95/100 [00:14<00:00,  6.59it/s, loss=0.007]
# test-time optim.:  95% 95/100 [00:14<00:00,  6.59it/s, loss=0.010]
# test-time optim.:  96% 96/100 [00:14<00:00,  6.57it/s, loss=0.010]
# test-time optim.:  96% 96/100 [00:14<00:00,  6.57it/s, loss=0.008]
# test-time optim.:  97% 97/100 [00:14<00:00,  6.58it/s, loss=0.008]
# test-time optim.:  97% 97/100 [00:15<00:00,  6.58it/s, loss=0.007]
# test-time optim.:  98% 98/100 [00:15<00:00,  6.56it/s, loss=0.007]
# test-time optim.:  98% 98/100 [00:15<00:00,  6.56it/s, loss=0.009]
# test-time optim.:  99% 99/100 [00:15<00:00,  6.52it/s, loss=0.009]
# test-time optim.:  99% 99/100 [00:15<00:00,  6.52it/s, loss=0.009]
# test-time optim.: 100% 100/100 [00:15<00:00,  6.50it/s, loss=0.009]
# --------------------------
# PSNR:     21.81
# SSIM:      0.80
# LPIPS:     0.23
# --------------------------
# writing videos...

# %%
# !pip install ipdb

# %%
# !pip install visdom

# %%
# Corriger l'appel SSIM avec gestion adaptative des dimensions
nerf_file = '/content/barf_workspace/bundle-adjusting-NeRF/model/nerf.py'

with open(nerf_file, 'r') as f:
    content = f.read()

# Remplacer par un code qui gère automatiquement les dimensions
old_line = 'ssim = pytorch_ssim(rgb_map.permute(2,0,1).unsqueeze(0), var.image.permute(2,0,1).unsqueeze(0)).item()'

new_code = '''# Adapter les dimensions pour SSIM
            if rgb_map.dim() == 3:  # [H, W, C]
                rgb_ssim = rgb_map.permute(2,0,1).unsqueeze(0)  # -> [1, C, H, W]
            else:  # déjà [1, H, W, C] ou [1, C, H, W]
                if rgb_map.shape[-1] == 3:  # [1, H, W, C]
                    rgb_ssim = rgb_map.permute(0,3,1,2)  # -> [1, C, H, W]
                else:  # déjà [1, C, H, W]
                    rgb_ssim = rgb_map

            if var.image.dim() == 3:  # [H, W, C]
                img_ssim = var.image.permute(2,0,1).unsqueeze(0)  # -> [1, C, H, W]
            else:  # déjà [1, H, W, C] ou [1, C, H, W]
                if var.image.shape[-1] == 3:  # [1, H, W, C]
                    img_ssim = var.image.permute(0,3,1,2)  # -> [1, C, H, W]
                else:  # déjà [1, C, H, W]
                    img_ssim = var.image

            ssim = pytorch_ssim(rgb_ssim, img_ssim).item()'''

content = content.replace(old_line, new_code)

with open(nerf_file, 'w') as f:
    f.write(content)

print("✅ Code SSIM adaptatif ajouté")
# Out:
# ✅ Code SSIM adaptatif ajouté

# %%
# Chercher tous les dossiers "output"
# !find /content -type d -name "output" 2>/dev/null

# Chercher les fichiers vidéo récemment créés
# !find /content -type f -name "*.mp4" -o -name "*.gif" -o -name "*.png" | head -20

# Vérifier le dossier de travail actuel
# !pwd

# Lister les fichiers dans le répertoire BARF
# !ls -la /content/barf_workspace/bundle-adjusting-NeRF/
# Out:
# /content/barf_workspace/bundle-adjusting-NeRF/output
# /content/drive/MyDrive/projet_nerf_barf/results/results_20251122_095039/poses_gt_lego.png
# /content/drive/MyDrive/projet_nerf_barf/results/results_20251122_122911/poses_gt_lego.png
# /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_151212/poses_gt_lego.png
# /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_153909/poses_gt_lego.png
# /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_154842/poses_gt_lego.png
# /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_155523/poses_gt_lego.png
# /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_155759/poses_gt_lego.png
# /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_160014/poses_gt_lego.png
# /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_160040/poses_gt_lego.png
# /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_160151/poses_gt_lego.png
# /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_160527/poses_gt_lego.png
# /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_161140/poses_gt_lego.png
# /content/drive/MyDrive/projet_nerf_barf/results/results_20251123_161835/poses_gt_lego.png
# /content/drive/MyDrive/projet_nerf_barf/results/results_20251124_232300/poses_gt_lego.png
# /content/drive/MyDrive/projet_nerf_barf/results/results_20251124_232908/poses_gt_lego.png
# /content/drive/MyDrive/projet_nerf_barf/results/results_20251127_100016/poses_gt_lego.png
# /content/drive/MyDrive/projet_nerf_barf/results/results_20251128_095106/poses_gt_lego.png
# /content/data/nerf_synthetic/chair/val/r_58.png
# /content/data/nerf_synthetic/chair/val/r_92.png
# /content/data/nerf_synthetic/chair/val/r_16.png
# /content/barf_workspace/bundle-adjusting-NeRF
# total 128
# drwxr-xr-x 10 root root  4096 Nov 28 15:02 .
# drwxr-xr-x  3 root root  4096 Nov 28 12:18 ..
# -rw-r--r--  1 root root 11796 Nov 28 12:18 camera.py
# drwxr-xr-x  3 root root  4096 Nov 28 12:27 data
# -rw-r--r--  1 root root   808 Nov 28 14:21 evaluate.py
# drwxr-xr-x  2 root root  4096 Nov 28 13:06 evaluations_manual
# drwxr-xr-x  4 root root  4096 Nov 28 12:27 external
# -rw-r--r--  1 root root  1591 Nov 28 12:18 extract_mesh.py
# drwxr-xr-x  8 root root  4096 Nov 28 12:18 .git
# -rw-r--r--  1 root root  1799 Nov 28 12:18 .gitignore
# -rw-r--r--  1 root root   113 Nov 28 12:18 .gitmodules
# -rw-r--r--  1 root root  1071 Nov 28 12:18 LICENSE
# drwxr-xr-x  3 root root  4096 Nov 28 12:26 model
# drwxr-xr-x  2 root root  4096 Nov 28 13:27 options
# -rw-r--r--  1 root root  4979 Nov 28 14:51 options.py
# drwxr-xr-x  3 root root  4096 Nov 28 12:26 output
# drwxr-xr-x  2 root root  4096 Nov 28 15:02 __pycache__
# -rw-r--r--  1 root root  9338 Nov 28 12:18 README.md
# -rw-r--r--  1 root root   315 Nov 28 12:18 requirements.yaml
# -rw-r--r--  1 root root   711 Nov 28 12:18 train.py
# -rw-r--r--  1 root root  7652 Nov 28 12:18 util.py
# -rw-r--r--  1 root root 10570 Nov 28 15:02 util_vis.py
# -rw-r--r--  1 root root  6883 Nov 28 12:18 warp.py

# %%
# Voir la structure complète du dossier output
# !ls -lhR /content/barf_workspace/bundle-adjusting-NeRF/output/

# Ou plus spécifiquement pour votre groupe barf_lego
# !ls -lh /content/barf_workspace/bundle-adjusting-NeRF/output/barf_lego/

# Si le dossier debug existe
# !ls -lh /content/barf_workspace/bundle-adjusting-NeRF/output/barf_lego/debug/ 2>/dev/null || echo "Pas de dossier debug"
# Out:
# /content/barf_workspace/bundle-adjusting-NeRF/output/:
# total 4.0K
# drwxr-xr-x 3 root root 4.0K Nov 28 12:26 barf_lego
#
# /content/barf_workspace/bundle-adjusting-NeRF/output/barf_lego:
# total 4.0K
# drwxr-xr-x 8 root root 4.0K Nov 28 14:21 debug
#
# /content/barf_workspace/bundle-adjusting-NeRF/output/barf_lego/debug:
# total 13M
# drwxr-xr-x 2 root root 4.0K Nov 28 14:21 20000
# drwxr-xr-x 2 root root 4.0K Nov 28 14:21 21000
# drwxr-xr-x 2 root root 4.0K Nov 28 14:21 22000
# drwxr-xr-x 2 root root 4.0K Nov 28 14:21 checkpoint_latest
# -rw-r--r-- 1 root root 682K Nov 28 12:30 events.out.tfevents.1764332859.b031689cdc94.3544.0
# -rw------- 1 root root 6.1M Nov 28 13:12 latest.ckpt
# -rw------- 1 root root 6.1M Nov 28 13:12 model.ckpt
# -rw-r--r-- 1 root root 1.7K Nov 28 12:27 options.yaml
# drwxr-xr-x 2 root root 4.0K Nov 28 15:02 poses
# -rw-r--r-- 1 root root  50K Nov 28 15:02 poses.mp4
# -rw-r--r-- 1 root root 4.4K Nov 28 15:02 quant_pose.txt
# -rw-r--r-- 1 root root  181 Nov 28 15:04 quant.txt
# drwxr-xr-x 2 root root 4.0K Nov 28 13:40 test_view
# -rw-r--r-- 1 root root 4.0K Nov 28 15:04 test_view_depth.mp4
# -rw-r--r-- 1 root root 9.7K Nov 28 15:04 test_view_rgb.mp4
#
# /content/barf_workspace/bundle-adjusting-NeRF/output/barf_lego/debug/20000:
# total 0
#
# /content/barf_workspace/bundle-adjusting-NeRF/output/barf_lego/debug/21000:
# total 0
#
# /content/barf_workspace/bundle-adjusting-NeRF/output/barf_lego/debug/22000:
# total 0
#
# /content/barf_workspace/bundle-adjusting-NeRF/output/barf_lego/debug/checkpoint_latest:
# total 0
#
# /content/barf_workspace/bundle-adjusting-NeRF/output/barf_lego/debug/poses:
# total 572K
# -rw-r--r-- 1 root root 349K Nov 28 15:02 0.png
# -rw-r--r-- 1 root root 218K Nov 28 15:02 GT.png
#
# /content/barf_workspace/bundle-adjusting-NeRF/output/barf_lego/debug/test_view:
# total 928K
# -rw-r--r-- 1 root root  18K Nov 28 15:03 depth_0.png
# -rw-r--r-- 1 root root  18K Nov 28 15:03 depth_1.png
# -rw-r--r-- 1 root root  18K Nov 28 15:03 depth_2.png
# -rw-r--r-- 1 root root  18K Nov 28 15:04 depth_3.png
# -rw-r--r-- 1 root root 104K Nov 28 15:03 rgb_0.png
# -rw-r--r-- 1 root root 107K Nov 28 15:03 rgb_1.png
# -rw-r--r-- 1 root root 108K Nov 28 15:03 rgb_2.png
# -rw-r--r-- 1 root root 110K Nov 28 15:04 rgb_3.png
# -rw-r--r-- 1 root root 100K Nov 28 15:03 rgb_GT_0.png
# -rw-r--r-- 1 root root 102K Nov 28 15:03 rgb_GT_1.png
# -rw-r--r-- 1 root root 104K Nov 28 15:03 rgb_GT_2.png
# -rw-r--r-- 1 root root 105K Nov 28 15:04 rgb_GT_3.png
# total 4.0K
# drwxr-xr-x 8 root root 4.0K Nov 28 14:21 debug
# total 13M
# drwxr-xr-x 2 root root 4.0K Nov 28 14:21 20000
# drwxr-xr-x 2 root root 4.0K Nov 28 14:21 21000
# drwxr-xr-x 2 root root 4.0K Nov 28 14:21 22000
# drwxr-xr-x 2 root root 4.0K Nov 28 14:21 checkpoint_latest
# -rw-r--r-- 1 root root 682K Nov 28 12:30 events.out.tfevents.1764332859.b031689cdc94.3544.0
# -rw------- 1 root root 6.1M Nov 28 13:12 latest.ckpt
# -rw------- 1 root root 6.1M Nov 28 13:12 model.ckpt
# -rw-r--r-- 1 root root 1.7K Nov 28 12:27 options.yaml
# drwxr-xr-x 2 root root 4.0K Nov 28 15:02 poses
# -rw-r--r-- 1 root root  50K Nov 28 15:02 poses.mp4
# -rw-r--r-- 1 root root 4.4K Nov 28 15:02 quant_pose.txt
# -rw-r--r-- 1 root root  181 Nov 28 15:04 quant.txt
# drwxr-xr-x 2 root root 4.0K Nov 28 13:40 test_view
# -rw-r--r-- 1 root root 4.0K Nov 28 15:04 test_view_depth.mp4
# -rw-r--r-- 1 root root 9.7K Nov 28 15:04 test_view_rgb.mp4

# %% [markdown]
# **4**                                     hadi pour tout les checkpoints li kayn

# %%
# ==========================================
# ÉVALUATION AUTOMATIQUE DE TOUS LES CHECKPOINTS
# ==========================================

import os
import glob
from datetime import datetime
import subprocess
import re

# Paramètres
checkpoint_dir = "/content/drive/MyDrive/projet_nerf_barf/checkpoints"
results_base_dir = "/content/drive/MyDrive/projet_nerf_barf/results"
barf_dir = "/content/barf_workspace/bundle-adjusting-NeRF"
data_root = "/content/data/nerf_synthetic"

# Créer le dossier de résultats
os.makedirs(results_base_dir, exist_ok=True)

# Trouver tous les checkpoints
checkpoint_files = sorted(glob.glob(os.path.join(checkpoint_dir, "*.ckpt")))

print(f"🔍 Checkpoints trouvés : {len(checkpoint_files)}")
for ckpt in checkpoint_files:
    print(f"  - {os.path.basename(ckpt)}")

if len(checkpoint_files) == 0:
    print("❌ Aucun checkpoint trouvé!")
    exit(1)

print("\n" + "="*70)
print("🚀 DÉBUT DE L'ÉVALUATION")
print("="*70 + "\n")

# Résultats globaux
results_summary = []

# Évaluer chaque checkpoint
for idx, checkpoint_path in enumerate(checkpoint_files, 1):
    checkpoint_name = os.path.basename(checkpoint_path).replace('.ckpt', '')

    print(f"\n{'='*70}")
    print(f"📊 [{idx}/{len(checkpoint_files)}] Évaluation : {checkpoint_name}")
    print(f"{'='*70}\n")

    # Créer un dossier de résultats pour ce checkpoint
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    result_dir = os.path.join(results_base_dir, f"eval_{checkpoint_name}")
    os.makedirs(result_dir, exist_ok=True)

    try:
        # Nettoyer les anciens résultats BARF
        output_barf = f"{barf_dir}/output/barf_lego"
        if os.path.exists(output_barf):
            os.system(f"rm -rf {output_barf}")

        # Commande d'évaluation
        cmd = [
            "python", f"{barf_dir}/evaluate.py",
            "--group=barf_lego",
            "--model=barf",
            "--yaml=barf_blender",
            "--data.scene=lego",
            f"--data.root={data_root}",
            f"--load={checkpoint_path}"
        ]

        print(f"🔄 Exécution de l'évaluation...")

        # Exécuter l'évaluation
        result = subprocess.run(
            cmd,
            cwd=barf_dir,
            capture_output=True,
            text=True,
            timeout=600  # Timeout de 10 minutes
        )

        # Sauvegarder les logs
        log_file = os.path.join(result_dir, "evaluation_log.txt")
        with open(log_file, 'w') as f:
            f.write(f"Checkpoint: {checkpoint_name}\n")
            f.write(f"Path: {checkpoint_path}\n")
            f.write(f"Date: {datetime.now()}\n\n")
            f.write("="*70 + "\n")
            f.write("STDOUT:\n")
            f.write("="*70 + "\n")
            f.write(result.stdout)
            f.write("\n\n" + "="*70 + "\n")
            f.write("STDERR:\n")
            f.write("="*70 + "\n")
            f.write(result.stderr)

        # Extraire les métriques PSNR, SSIM, LPIPS
        output = result.stdout + result.stderr
        psnr = ssim = lpips = "N/A"
        rot_error = trans_error = "N/A"

        # Rechercher les métriques
        for line in output.split('\n'):
            if 'PSNR:' in line:
                match = re.search(r'PSNR:\s+([\d.]+)', line)
                if match:
                    psnr = match.group(1)
            if 'SSIM:' in line:
                match = re.search(r'SSIM:\s+([\d.]+)', line)
                if match:
                    ssim = match.group(1)
            if 'LPIPS:' in line:
                match = re.search(r'LPIPS:\s+([\d.]+)', line)
                if match:
                    lpips = match.group(1)
            if 'rot:' in line:
                match = re.search(r'rot:\s+([\d.]+)', line)
                if match:
                    rot_error = match.group(1)
            if 'trans:' in line:
                match = re.search(r'trans:\s+([\d.]+)', line)
                if match:
                    trans_error = match.group(1)

        # Copier les résultats générés
        if os.path.exists(output_barf):
            print(f"📁 Copie des résultats...")
            os.system(f"cp -r {output_barf}/* {result_dir}/ 2>/dev/null")
            print(f"✅ Résultats sauvegardés dans : {result_dir}")

        # Enregistrer les résultats
        status = 'SUCCESS' if result.returncode == 0 else 'FAILED'
        results_summary.append({
            'checkpoint': checkpoint_name,
            'psnr': psnr,
            'ssim': ssim,
            'lpips': lpips,
            'rot_error': rot_error,
            'trans_error': trans_error,
            'result_dir': result_dir,
            'status': status
        })

        print(f"\n📈 Métriques pour {checkpoint_name}:")
        print(f"   PSNR:       {psnr}")
        print(f"   SSIM:       {ssim}")
        print(f"   LPIPS:      {lpips}")
        print(f"   Rot Error:  {rot_error}°")
        print(f"   Trans Err:  {trans_error}")
        print(f"   Status:     {status}")

    except subprocess.TimeoutExpired:
        print(f"⏱️ Timeout lors de l'évaluation de {checkpoint_name}")
        results_summary.append({
            'checkpoint': checkpoint_name,
            'psnr': 'TIMEOUT',
            'ssim': 'TIMEOUT',
            'lpips': 'TIMEOUT',
            'rot_error': 'TIMEOUT',
            'trans_error': 'TIMEOUT',
            'result_dir': result_dir,
            'status': 'TIMEOUT'
        })
    except Exception as e:
        print(f"❌ Erreur lors de l'évaluation de {checkpoint_name}: {str(e)}")
        results_summary.append({
            'checkpoint': checkpoint_name,
            'psnr': 'ERROR',
            'ssim': 'ERROR',
            'lpips': 'ERROR',
            'rot_error': 'ERROR',
            'trans_error': 'ERROR',
            'result_dir': result_dir,
            'status': 'ERROR'
        })

# Créer un rapport récapitulatif
print("\n" + "="*70)
print("📋 RÉSUMÉ DES ÉVALUATIONS")
print("="*70 + "\n")

summary_file = os.path.join(results_base_dir, f"evaluation_summary_{datetime.now().strftime('%Y%m%d_%H%M%S')}.txt")

with open(summary_file, 'w') as f:
    # En-tête
    f.write("="*70 + "\n")
    f.write("RAPPORT D'ÉVALUATION BARF - SCÈNE LEGO\n")
    f.write(f"Date: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
    f.write("="*70 + "\n\n")

    # Tableau des résultats
    header = f"{'Checkpoint':<15} {'PSNR':<8} {'SSIM':<8} {'LPIPS':<8} {'Rot°':<8} {'Trans':<8} {'Status':<10}"
    separator = "-" * len(header)

    print(header)
    print(separator)
    f.write(header + "\n")
    f.write(separator + "\n")

    for res in results_summary:
        line = (f"{res['checkpoint']:<15} {res['psnr']:<8} {res['ssim']:<8} "
                f"{res['lpips']:<8} {res['rot_error']:<8} {res['trans_error']:<8} {res['status']:<10}")
        print(line)
        f.write(line + "\n")

    print(separator)
    f.write(separator + "\n")

    # Statistiques
    successful = [r for r in results_summary if r['status'] == 'SUCCESS']
    if successful:
        f.write(f"\n{'='*70}\n")
        f.write("STATISTIQUES\n")
        f.write(f"{'='*70}\n")
        f.write(f"Total évalués: {len(results_summary)}\n")
        f.write(f"Succès: {len(successful)}\n")
        f.write(f"Échecs: {len(results_summary) - len(successful)}\n")

        # Meilleur checkpoint
        try:
            best_psnr = max(successful, key=lambda x: float(x['psnr']) if x['psnr'] != 'N/A' else 0)
            f.write(f"\nMeilleur PSNR: {best_psnr['checkpoint']} ({best_psnr['psnr']})\n")
            print(f"\n🏆 Meilleur PSNR: {best_psnr['checkpoint']} ({best_psnr['psnr']})")
        except:
            pass

    # Informations supplémentaires
    f.write(f"\n{'='*70}\n")
    f.write(f"Résultats complets sauvegardés dans : {results_base_dir}\n")
    f.write(f"Rapport récapitulatif : {summary_file}\n")
    f.write(f"{'='*70}\n")

print("\n✅ Évaluation terminée pour tous les checkpoints!")
print(f"📁 Consultez les résultats dans : {results_base_dir}")
print(f"📄 Rapport récapitulatif : {summary_file}")
# Out:
# 🔍 Checkpoints trouvés : 88
#   - 100000.ckpt
#   - 20000.ckpt
#   - 21000.ckpt
#   - 22000.ckpt
#   - 23000.ckpt
#   - 24000.ckpt
#   - 25000.ckpt
#   - 26000.ckpt
#   - 27000.ckpt
#   - 28000.ckpt
#   - 29000.ckpt
#   - 30000.ckpt
#   - 31000.ckpt
#   - 32000.ckpt
#   - 33000.ckpt
#   - 34000.ckpt
#   - 35000.ckpt
#   - 36000.ckpt
#   - 37000.ckpt
#   - 38000.ckpt
#   - 39000.ckpt
#   - 40000.ckpt
#   - 41000.ckpt
#   - 42000.ckpt
#   - 43000.ckpt
#   - 44000.ckpt
#   - 45000.ckpt
#   - 46000.ckpt
#   - 47000.ckpt
#   - 48000.ckpt
#   - 49000.ckpt
#   - 50000.ckpt
#   - 51000.ckpt
#   - 52000.ckpt
#   - 53000.ckpt
#   - 54000.ckpt
#   - 55000.ckpt
#   - 56000.ckpt
#   - 57000.ckpt
#   - 58000.ckpt
#   - 59000.ckpt
#   - 60000.ckpt
#   - 61000.ckpt
#   - 62000.ckpt
#   - 63000.ckpt
#   - 64000.ckpt
#   - 65000.ckpt
#   - 66000.ckpt
#   - 67000.ckpt
#   - 68000.ckpt
#   - 69000.ckpt
#   - 70000.ckpt
#   - 71000.ckpt
#   - 72000.ckpt
#   - 73000.ckpt
#   - 74000.ckpt
#   - 75000.ckpt
#   - 76000.ckpt
#   - 77000.ckpt
#   - 78000.ckpt
#   - 79000.ckpt
#   - 80000.ckpt
#   - 81000.ckpt
#   - 82000.ckpt
#   - 83000.ckpt
#   - 84000.ckpt
#   - 85000.ckpt
#   - 86000.ckpt
#   - 87000.ckpt
#   - 88000.ckpt
#   - 89000.ckpt
#   - 90000.ckpt
#   - 91000.ckpt
#   - 92000.ckpt
#   - 93000.ckpt
#   - 94000.ckpt
#   - 95000.ckpt
#   - 96000.ckpt
#   - 97000.ckpt
#   - 98000.ckpt
#   - 99000.ckpt
#   - checkpoint_iter_100000_20251123_154804.ckpt
#   - checkpoint_latest.ckpt
#   - checkpoint_latest_20251123_153851.ckpt
#   - checkpoint_latest_20251123_154531.ckpt
#   - checkpoint_latest_20251123_154825.ckpt
#   - checkpoint_latest_20251123_155430.ckpt
#   - checkpoint_latest_20251123_161738.ckpt
#
# ======================================================================
# 🚀 DÉBUT DE L'ÉVALUATION
# ======================================================================
#
#
# ======================================================================
# 📊 [1/88] Évaluation : 100000
# ======================================================================
#
# 🔄 Exécution de l'évaluation...
# 📁 Copie des résultats...
# ✅ Résultats sauvegardés dans : /content/drive/MyDrive/projet_nerf_barf/results/eval_100000
#
# 📈 Métriques pour 100000:
#    PSNR:       8.95
#    SSIM:       0.70
#    LPIPS:      0.54
#    Rot Error:  1.087°
#    Trans Err:  0.02038
#    Status:     SUCCESS
#
# ======================================================================
# 📊 [2/88] Évaluation : 20000
# ======================================================================
#
# 🔄 Exécution de l'évaluation...
# 📁 Copie des résultats...
# ✅ Résultats sauvegardés dans : /content/drive/MyDrive/projet_nerf_barf/results/eval_20000
#
# 📈 Métriques pour 20000:
#    PSNR:       21.81
#    SSIM:       0.80
#    LPIPS:      0.23
#    Rot Error:  0.396°
#    Trans Err:  0.01166
#    Status:     SUCCESS
#
# ======================================================================
# 📊 [3/88] Évaluation : 21000
# ======================================================================
#
# 🔄 Exécution de l'évaluation...
# 📁 Copie des résultats...
# ✅ Résultats sauvegardés dans : /content/drive/MyDrive/projet_nerf_barf/results/eval_21000
#
# 📈 Métriques pour 21000:
#    PSNR:       8.95
#    SSIM:       0.70
#    LPIPS:      0.54
#    Rot Error:  0.437°
#    Trans Err:  0.01251
#    Status:     SUCCESS
#
# ======================================================================
# 📊 [4/88] Évaluation : 22000
# ======================================================================
#
# 🔄 Exécution de l'évaluation...
# 📁 Copie des résultats...
# ✅ Résultats sauvegardés dans : /content/drive/MyDrive/projet_nerf_barf/results/eval_22000
#
# 📈 Métriques pour 22000:
#    PSNR:       8.95
#    SSIM:       0.70
#    LPIPS:      0.54
#    Rot Error:  0.437°
#    Trans Err:  0.01251
#    Status:     SUCCESS
#
# ======================================================================
# 📊 [5/88] Évaluation : 23000
# ======================================================================
#
# 🔄 Exécution de l'évaluation...
# 📁 Copie des résultats...
# ✅ Résultats sauvegardés dans : /content/drive/MyDrive/projet_nerf_barf/results/eval_23000
#
# 📈 Métriques pour 23000:
#    PSNR:       8.95
#    SSIM:       0.70
#    LPIPS:      0.54
#    Rot Error:  0.437°
#    Trans Err:  0.01251
#    Status:     SUCCESS
#
# ======================================================================
# 📊 [6/88] Évaluation : 24000
# ======================================================================
#
# 🔄 Exécution de l'évaluation...
# 📁 Copie des résultats...
# ✅ Résultats sauvegardés dans : /content/drive/MyDrive/projet_nerf_barf/results/eval_24000
#
# 📈 Métriques pour 24000:
#    PSNR:       8.95
#    SSIM:       0.70
#    LPIPS:      0.54
#    Rot Error:  0.437°
#    Trans Err:  0.01251
#    Status:     SUCCESS
#
# ======================================================================
# 📊 [7/88] Évaluation : 25000
# ======================================================================
#
# 🔄 Exécution de l'évaluation...
# 📁 Copie des résultats...
# ✅ Résultats sauvegardés dans : /content/drive/MyDrive/projet_nerf_barf/results/eval_25000
#
# 📈 Métriques pour 25000:
#    PSNR:       8.95
#    SSIM:       0.70
#    LPIPS:      0.54
#    Rot Error:  0.437°
#    Trans Err:  0.01251
#    Status:     SUCCESS
#
# ======================================================================
# 📊 [8/88] Évaluation : 26000
# ======================================================================
#
# 🔄 Exécution de l'évaluation...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3233959219.py in <cell line: 0>()
#      69
#      70         # Exécuter l'évaluation
# ---> 71         result = subprocess.run(
#      72             cmd,
#      73             cwd=barf_dir,
#
# /usr/lib/python3.12/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548     with Popen(*popenargs, **kwargs) as process:
#     549         try:
# --> 550             stdout, stderr = process.communicate(input, timeout=timeout)
#     551         except TimeoutExpired as exc:
#     552             process.kill()
#
# /usr/lib/python3.12/subprocess.py in communicate(self, input, timeout)
#    1207
#    1208             try:
# -> 1209                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1210             except KeyboardInterrupt:
#    1211                 # https://bugs.python.org/issue25942
#
# /usr/lib/python3.12/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    2113                             'failed to raise TimeoutExpired.')
#    2114
# -> 2115                     ready = selector.select(timeout)
#    2116                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2117
#
# /usr/lib/python3.12/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
# ==========================================
# ÉVALUATION DES CHECKPOINTS AVANT DIVERGENCE (≤20000)
# ==========================================

import os
import glob
from datetime import datetime
import subprocess
import re

# Paramètres
checkpoint_dir = "/content/drive/MyDrive/projet_nerf_barf/checkpoints"
results_base_dir = "/content/drive/MyDrive/projet_nerf_barf/results"
barf_dir = "/content/barf_workspace/bundle-adjusting-NeRF"
data_root = "/content/data/nerf_synthetic"

# Créer le dossier de résultats
os.makedirs(results_base_dir, exist_ok=True)

# Fonction pour extraire le numéro d'itération du nom du fichier
def get_iteration_number(filename):
    """Extrait le numéro d'itération du nom de fichier"""
    basename = os.path.basename(filename).replace('.ckpt', '')
    try:
        # Si c'est juste un nombre (ex: "20000.ckpt")
        return int(basename)
    except ValueError:
        # Si c'est un nom spécial comme "checkpoint_latest_..."
        # On ignore ces fichiers
        return None

# Trouver tous les checkpoints
all_checkpoints = glob.glob(os.path.join(checkpoint_dir, "*.ckpt"))

# Filtrer et trier les checkpoints <= 20000
checkpoint_files = []
for f in all_checkpoints:
    iteration = get_iteration_number(f)
    if iteration is not None and iteration <= 20000:
        checkpoint_files.append((f, iteration))

# Trier par numéro d'itération
checkpoint_files.sort(key=lambda x: x[1])
checkpoint_files = [f[0] for f in checkpoint_files]

print("="*70)
print(f"🔍 ÉVALUATION DES CHECKPOINTS AVANT DIVERGENCE")
print("="*70)
print(f"Total checkpoints trouvés: {len(all_checkpoints)}")
print(f"Checkpoints à évaluer (≤20k): {len(checkpoint_files)}")
print("\nCheckpoints sélectionnés:")
for ckpt in checkpoint_files:
    iter_num = get_iteration_number(ckpt)
    print(f"  ✓ {os.path.basename(ckpt)} (iteration {iter_num})")

# Afficher les checkpoints ignorés
ignored = [f for f in all_checkpoints if get_iteration_number(f) is None or get_iteration_number(f) > 20000]
if ignored:
    print(f"\nCheckpoints ignorés ({len(ignored)}):")
    for ckpt in ignored[:5]:  # Afficher seulement les 5 premiers
        print(f"  ✗ {os.path.basename(ckpt)}")
    if len(ignored) > 5:
        print(f"  ... et {len(ignored)-5} autres")

if len(checkpoint_files) == 0:
    print("❌ Aucun checkpoint ≤20000 trouvé!")
    exit(1)

print("\n" + "="*70)
print("🚀 DÉBUT DE L'ÉVALUATION")
print("="*70 + "\n")

# Résultats globaux
results_summary = []

# Évaluer chaque checkpoint
for idx, checkpoint_path in enumerate(checkpoint_files, 1):
    checkpoint_name = os.path.basename(checkpoint_path).replace('.ckpt', '')
    checkpoint_iter = get_iteration_number(checkpoint_path)

    print(f"\n{'='*70}")
    print(f"📊 [{idx}/{len(checkpoint_files)}] Évaluation : {checkpoint_name} (iter {checkpoint_iter})")
    print(f"{'='*70}\n")

    # Créer un dossier de résultats pour ce checkpoint
    result_dir = os.path.join(results_base_dir, f"eval_{checkpoint_name}")
    os.makedirs(result_dir, exist_ok=True)

    try:
        # Nettoyer les anciens résultats BARF
        output_barf = f"{barf_dir}/output/barf_lego"
        if os.path.exists(output_barf):
            os.system(f"rm -rf {output_barf}")

        # Commande d'évaluation
        cmd = [
            "python", f"{barf_dir}/evaluate.py",
            "--group=barf_lego",
            "--model=barf",
            "--yaml=barf_blender",
            "--data.scene=lego",
            f"--data.root={data_root}",
            f"--load={checkpoint_path}"
        ]

        print(f"🔄 Exécution de l'évaluation...")

        # Exécuter l'évaluation
        result = subprocess.run(
            cmd,
            cwd=barf_dir,
            capture_output=True,
            text=True,
            timeout=600  # Timeout de 10 minutes
        )

        # Sauvegarder les logs
        log_file = os.path.join(result_dir, "evaluation_log.txt")
        with open(log_file, 'w') as f:
            f.write(f"Checkpoint: {checkpoint_name}\n")
            f.write(f"Iteration: {checkpoint_iter}\n")
            f.write(f"Path: {checkpoint_path}\n")
            f.write(f"Date: {datetime.now()}\n\n")
            f.write("="*70 + "\n")
            f.write("STDOUT:\n")
            f.write("="*70 + "\n")
            f.write(result.stdout)
            f.write("\n\n" + "="*70 + "\n")
            f.write("STDERR:\n")
            f.write("="*70 + "\n")
            f.write(result.stderr)

        # Extraire les métriques
        output = result.stdout + result.stderr
        psnr = ssim = lpips = "N/A"
        rot_error = trans_error = "N/A"

        for line in output.split('\n'):
            if 'PSNR:' in line:
                match = re.search(r'PSNR:\s+([\d.]+)', line)
                if match:
                    psnr = match.group(1)
            if 'SSIM:' in line:
                match = re.search(r'SSIM:\s+([\d.]+)', line)
                if match:
                    ssim = match.group(1)
            if 'LPIPS:' in line:
                match = re.search(r'LPIPS:\s+([\d.]+)', line)
                if match:
                    lpips = match.group(1)
            if 'rot:' in line:
                match = re.search(r'rot:\s+([\d.]+)', line)
                if match:
                    rot_error = match.group(1)
            if 'trans:' in line:
                match = re.search(r'trans:\s+([\d.]+)', line)
                if match:
                    trans_error = match.group(1)

        # Copier les résultats générés
        if os.path.exists(output_barf):
            print(f"📁 Copie des résultats...")
            os.system(f"cp -r {output_barf}/* {result_dir}/ 2>/dev/null")
            print(f"✅ Résultats sauvegardés dans : {result_dir}")

        # Enregistrer les résultats
        status = 'SUCCESS' if result.returncode == 0 else 'FAILED'
        results_summary.append({
            'checkpoint': checkpoint_name,
            'iteration': checkpoint_iter,
            'psnr': psnr,
            'ssim': ssim,
            'lpips': lpips,
            'rot_error': rot_error,
            'trans_error': trans_error,
            'result_dir': result_dir,
            'status': status
        })

        print(f"\n📈 Métriques pour {checkpoint_name}:")
        print(f"   PSNR:       {psnr}")
        print(f"   SSIM:       {ssim}")
        print(f"   LPIPS:      {lpips}")
        print(f"   Rot Error:  {rot_error}°")
        print(f"   Trans Err:  {trans_error}")
        print(f"   Status:     {status}")

    except subprocess.TimeoutExpired:
        print(f"⏱️ Timeout lors de l'évaluation de {checkpoint_name}")
        results_summary.append({
            'checkpoint': checkpoint_name,
            'iteration': checkpoint_iter,
            'psnr': 'TIMEOUT',
            'ssim': 'TIMEOUT',
            'lpips': 'TIMEOUT',
            'rot_error': 'TIMEOUT',
            'trans_error': 'TIMEOUT',
            'result_dir': result_dir,
            'status': 'TIMEOUT'
        })
    except Exception as e:
        print(f"❌ Erreur lors de l'évaluation de {checkpoint_name}: {str(e)}")
        results_summary.append({
            'checkpoint': checkpoint_name,
            'iteration': checkpoint_iter,
            'psnr': 'ERROR',
            'ssim': 'ERROR',
            'lpips': 'ERROR',
            'rot_error': 'ERROR',
            'trans_error': 'ERROR',
            'result_dir': result_dir,
            'status': 'ERROR'
        })

# Créer un rapport récapitulatif
print("\n" + "="*70)
print("📋 RÉSUMÉ DES ÉVALUATIONS (CHECKPOINTS ≤20k)")
print("="*70 + "\n")

summary_file = os.path.join(results_base_dir, f"evaluation_summary_pre_divergence_{datetime.now().strftime('%Y%m%d_%H%M%S')}.txt")

with open(summary_file, 'w') as f:
    # En-tête
    f.write("="*70 + "\n")
    f.write("RAPPORT D'ÉVALUATION BARF - CHECKPOINTS AVANT DIVERGENCE\n")
    f.write("Scène: LEGO | Checkpoints: ≤20000 itérations\n")
    f.write(f"Date: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
    f.write("="*70 + "\n\n")

    # Tableau des résultats
    header = f"{'Iter':<8} {'PSNR':<8} {'SSIM':<8} {'LPIPS':<8} {'Rot°':<8} {'Trans':<10} {'Status':<10}"
    separator = "-" * len(header)

    print(header)
    print(separator)
    f.write(header + "\n")
    f.write(separator + "\n")

    # Trier par itération
    results_summary.sort(key=lambda x: x['iteration'])

    for res in results_summary:
        line = (f"{res['iteration']:<8} {res['psnr']:<8} {res['ssim']:<8} "
                f"{res['lpips']:<8} {res['rot_error']:<8} {res['trans_error']:<10} {res['status']:<10}")
        print(line)
        f.write(line + "\n")

    print(separator)
    f.write(separator + "\n")

    # Statistiques
    successful = [r for r in results_summary if r['status'] == 'SUCCESS']
    if successful:
        f.write(f"\n{'='*70}\n")
        f.write("STATISTIQUES\n")
        f.write(f"{'='*70}\n")
        f.write(f"Total évalués: {len(results_summary)}\n")
        f.write(f"Succès: {len(successful)}\n")
        f.write(f"Échecs: {len(results_summary) - len(successful)}\n")

        # Meilleur checkpoint par métrique
        try:
            valid_psnr = [r for r in successful if r['psnr'] != 'N/A']
            if valid_psnr:
                best_psnr = max(valid_psnr, key=lambda x: float(x['psnr']))
                f.write(f"\n🏆 Meilleur PSNR: iteration {best_psnr['iteration']} ({best_psnr['psnr']})\n")
                print(f"\n🏆 Meilleur PSNR: iteration {best_psnr['iteration']} ({best_psnr['psnr']})")

            valid_ssim = [r for r in successful if r['ssim'] != 'N/A']
            if valid_ssim:
                best_ssim = max(valid_ssim, key=lambda x: float(x['ssim']))
                f.write(f"🏆 Meilleur SSIM: iteration {best_ssim['iteration']} ({best_ssim['ssim']})\n")
                print(f"🏆 Meilleur SSIM: iteration {best_ssim['iteration']} ({best_ssim['ssim']})")

            valid_lpips = [r for r in successful if r['lpips'] != 'N/A']
            if valid_lpips:
                best_lpips = min(valid_lpips, key=lambda x: float(x['lpips']))
                f.write(f"🏆 Meilleur LPIPS: iteration {best_lpips['iteration']} ({best_lpips['lpips']})\n")
                print(f"🏆 Meilleur LPIPS: iteration {best_lpips['iteration']} ({best_lpips['lpips']})")
        except Exception as e:
            f.write(f"\nErreur lors du calcul des meilleurs: {e}\n")

    # Informations supplémentaires
    f.write(f"\n{'='*70}\n")
    f.write("NOTES:\n")
    f.write("- Seuls les checkpoints ≤20000 ont été évalués\n")
    f.write("- Les checkpoints >20000 ont été exclus (divergence détectée)\n")
    f.write(f"\nRésultats complets: {results_base_dir}\n")
    f.write(f"Rapport récapitulatif: {summary_file}\n")
    f.write(f"{'='*70}\n")

print("\n✅ Évaluation terminée pour tous les checkpoints avant divergence!")
print(f"📁 Résultats dans : {results_base_dir}")
print(f"📄 Rapport : {summary_file}")

# Afficher un graphique si matplotlib est disponible
try:
    import matplotlib.pyplot as plt

    successful = [r for r in results_summary if r['status'] == 'SUCCESS' and r['psnr'] != 'N/A']
    if successful:
        iterations = [r['iteration'] for r in successful]
        psnrs = [float(r['psnr']) for r in successful]

        plt.figure(figsize=(10, 6))
        plt.plot(iterations, psnrs, 'b-o', linewidth=2, markersize=8)
        plt.xlabel('Itérations', fontsize=12)
        plt.ylabel('PSNR (dB)', fontsize=12)
        plt.title('Évolution du PSNR avant divergence', fontsize=14, fontweight='bold')
        plt.grid(True, alpha=0.3)
        plt.tight_layout()

        plot_file = os.path.join(results_base_dir, 'psnr_evolution.png')
        plt.savefig(plot_file, dpi=150)
        print(f"\n📊 Graphique sauvegardé : {plot_file}")
        plt.show()
except:
    pass
# Out:
# ======================================================================
# 🔍 ÉVALUATION DES CHECKPOINTS AVANT DIVERGENCE
# ======================================================================
# Total checkpoints trouvés: 88
# Checkpoints à évaluer (≤20k): 1
#
# Checkpoints sélectionnés:
#   ✓ 20000.ckpt (iteration 20000)
#
# Checkpoints ignorés (87):
#   ✗ 21000.ckpt
#   ✗ 22000.ckpt
#   ✗ 23000.ckpt
#   ✗ 24000.ckpt
#   ✗ 25000.ckpt
#   ... et 82 autres
#
# ======================================================================
# 🚀 DÉBUT DE L'ÉVALUATION
# ======================================================================
#
#
# ======================================================================
# 📊 [1/1] Évaluation : 20000 (iter 20000)
# ======================================================================
#
# 🔄 Exécution de l'évaluation...
# 📁 Copie des résultats...
# ✅ Résultats sauvegardés dans : /content/drive/MyDrive/projet_nerf_barf/results/eval_20000
#
# 📈 Métriques pour 20000:
#    PSNR:       21.81
#    SSIM:       0.80
#    LPIPS:      0.23
#    Rot Error:  0.396°
#    Trans Err:  0.01166
#    Status:     SUCCESS
#
# ======================================================================
# 📋 RÉSUMÉ DES ÉVALUATIONS (CHECKPOINTS ≤20k)
# ======================================================================
#
# Iter     PSNR     SSIM     LPIPS    Rot°     Trans      Status
# ------------------------------------------------------------------
# 20000    21.81    0.80     0.23     0.396    0.01166    SUCCESS
# ------------------------------------------------------------------
#
# 🏆 Meilleur PSNR: iteration 20000 (21.81)
# 🏆 Meilleur SSIM: iteration 20000 (0.80)
# 🏆 Meilleur LPIPS: iteration 20000 (0.23)
#
# ✅ Évaluation terminée pour tous les checkpoints avant divergence!
# 📁 Résultats dans : /content/drive/MyDrive/projet_nerf_barf/results
# 📄 Rapport : /content/drive/MyDrive/projet_nerf_barf/results/evaluation_summary_pre_divergence_20251130_081251.txt
#
# 📊 Graphique sauvegardé : /content/drive/MyDrive/projet_nerf_barf/results/psnr_evolution.png

# %% [markdown]
# hadi pour chaque iteration m9drtch n executiha GPU hbs

# %%
# 1. Corriger le fichier util_vis.py
# !sed -i 's/depth=opt\.visdom\.cam_depth/depth=0.5/g' /content/barf_workspace/bundle-adjusting-NeRF/util_vis.py

# 2. Checkpoint à évaluer
checkpoint_path = "/content/drive/MyDrive/projet_nerf_barf/checkpoints/20000.ckpt"

# 3. Nombre d'itérations pour l'évaluation
iterations = [1, 10, 50, 100, 500]

# 4. Évaluer à chaque itération
for it in iterations:
    print(f"\n{'='*60}")
    print(f"Évaluation à l'itération: {it}")
    print(f"{'='*60}\n")

    # !python /content/barf_workspace/bundle-adjusting-NeRF/evaluate.py \
        --group=barf_lego \
        --model=barf \
        --yaml=barf_blender \
        --data.scene=lego \
        --data.root=/content/data/nerf_synthetic \
        --load={checkpoint_path} \
        --resume_iter={it}
# Out:
# ============================================================
# Évaluation à l'itération: 1
# ============================================================
#
# Process ID: 13860
# [/content/barf_workspace/bundle-adjusting-NeRF/evaluate.py] (PyTorch code for evaluating NeRF/BARF)
# setting configurations...
# loading options/base.yaml...
# loading options/nerf_blender.yaml...
# loading options/barf_blender.yaml...
# "resume_iter" not found in original opt, add? (y/n) y
# * H: 400
# * W: 400
# * arch:
#    * density_activ: softplus
#    * layers_feat: [None, 256, 256, 256, 256, 256, 256, 256, 256]
#    * layers_rgb: [None, 128, 3]
#    * posenc:
#       * L_3D: 10
#       * L_view: 4
#    * skip: [4]
#    * tf_init: True
# * barf_c2f: [0.1, 0.5]
# * batch_size: None
# * camera:
#    * model: perspective
#    * ndc: False
#    * noise: 0.15
# * cpu: False
# * data:
#    * augment:
#    * bgcolor: 1
#    * center_crop: None
#    * dataset: blender
#    * image_size: [400, 400]
#    * num_workers: 4
#    * preload: True
#    * root: /content/data/nerf_synthetic
#    * scene: lego
#    * train_sub: None
#    * val_on_test: False
#    * val_sub: 4
# * device: cuda:0
# * freq:
#    * ckpt: 5000
#    * scalar: 200
#    * val: 2000
#    * vis: 1000
# * gpu: 0
# * group: barf_lego
# * load: /content/drive/MyDrive/projet_nerf_barf/checkpoints/20000.ckpt
# * loss_weight:
#    * render: 0
#    * render_fine: None
# * max_epoch: None
# * max_iter: 200000
# * model: barf
# * name: debug
# * nerf:
#    * density_noise_reg: None
#    * depth:
#       * param: metric
#       * range: [2, 6]
#    * fine_sampling: False
#    * rand_rays: 1024
#    * sample_intvs: 128
#    * sample_intvs_fine: None
#    * sample_stratified: True
#    * setbg_opaque: False
#    * view_dep: True
# * optim:
#    * algo: Adam
#    * lr: 0.0005
#    * lr_end: 0.0001
#    * lr_pose: 0.001
#    * lr_pose_end: 1e-05
#    * sched:
#       * gamma: None
#       * type: ExponentialLR
#    * sched_pose:
#       * gamma: None
#       * type: ExponentialLR
#    * test_iter: 100
#    * test_photo: True
#    * warmup_pose: None
# * output_path: output/barf_lego/debug
# * output_root: output
# * resume: False
# * resume_iter: 1
# * seed: 0
# * tb:
#    * num_images: [4, 8]
# * trimesh:
#    * chunk_size: 16384
#    * range: [-1.2, 1.2]
#    * res: 128
#    * thres: 25.0
# * visdom: False
# * yaml: barf_blender
# 2025-11-30 08:22:35.992419: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764490956.023781   13860 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764490956.033997   13860 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764490956.059392   13860 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764490956.059424   13860 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764490956.059433   13860 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764490956.059439   13860 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-30 08:22:36.066531: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# y
# y
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/alex.pth
# loading training data...
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# number of samples: 100
# loading test data...
# number of samples: 4
# building networks...
# writing videos...
# loading weights from checkpoint /content/drive/MyDrive/projet_nerf_barf/checkpoints/20000.ckpt...
# restoring nerf...
# restoring se3_refine...
# --------------------------
# rot:      0.396
# trans:    0.01166
# --------------------------
# evaluating:   0% 0/4 [00:00<?, ?it/s]
# test-time optim.:   0% 0/100 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4317.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#
# test-time optim.:   0% 0/100 [00:00<?, ?it/s, loss=0.006]
# test-time optim.:   1% 1/100 [00:00<00:45,  2.18it/s, loss=0.006]
# test-time optim.:   1% 1/100 [00:00<00:45,  2.18it/s, loss=0.006]
# test-time optim.:   2% 2/100 [00:00<00:28,  3.49it/s, loss=0.006]
# test-time optim.:   2% 2/100 [00:00<00:28,  3.49it/s, loss=0.005]
# test-time optim.:   3% 3/100 [00:00<00:21,  4.57it/s, loss=0.005]
# test-time optim.:   3% 3/100 [00:00<00:21,  4.57it/s, loss=0.005]
# test-time optim.:   4% 4/100 [00:00<00:17,  5.34it/s, loss=0.005]
# test-time optim.:   4% 4/100 [00:01<00:17,  5.34it/s, loss=0.006]
# test-time optim.:   5% 5/100 [00:01<00:16,  5.89it/s, loss=0.006]
# test-time optim.:   5% 5/100 [00:01<00:16,  5.89it/s, loss=0.006]
# test-time optim.:   6% 6/100 [00:01<00:14,  6.27it/s, loss=0.006]
# test-time optim.:   6% 6/100 [00:01<00:14,  6.27it/s, loss=0.005]
# test-time optim.:   7% 7/100 [00:01<00:14,  6.57it/s, loss=0.005]
# test-time optim.:   7% 7/100 [00:01<00:14,  6.57it/s, loss=0.006]
# test-time optim.:   8% 8/100 [00:01<00:13,  6.78it/s, loss=0.006]
# test-time optim.:   8% 8/100 [00:01<00:13,  6.78it/s, loss=0.005]
# test-time optim.:   9% 9/100 [00:01<00:13,  6.88it/s, loss=0.005]
# test-time optim.:   9% 9/100 [00:01<00:13,  6.88it/s, loss=0.007]
# test-time optim.:  10% 10/100 [00:01<00:12,  6.99it/s, loss=0.007]
# test-time optim.:  10% 10/100 [00:01<00:12,  6.99it/s, loss=0.006]
# test-time optim.:  11% 11/100 [00:01<00:12,  7.06it/s, loss=0.006]
# test-time optim.:  11% 11/100 [00:02<00:12,  7.06it/s, loss=0.005]
# test-time optim.:  12% 12/100 [00:02<00:12,  7.06it/s, loss=0.005]
# test-time optim.:  12% 12/100 [00:02<00:12,  7.06it/s, loss=0.006]
# test-time optim.:  13% 13/100 [00:02<00:12,  7.05it/s, loss=0.006]
# test-time optim.:  13% 13/100 [00:02<00:12,  7.05it/s, loss=0.006]
# test-time optim.:  14% 14/100 [00:02<00:12,  7.02it/s, loss=0.006]
# test-time optim.:  14% 14/100 [00:02<00:12,  7.02it/s, loss=0.004]
# test-time optim.:  15% 15/100 [00:02<00:12,  7.05it/s, loss=0.004]
# test-time optim.:  15% 15/100 [00:02<00:12,  7.05it/s, loss=0.004]
# test-time optim.:  16% 16/100 [00:02<00:11,  7.06it/s, loss=0.004]
# test-time optim.:  16% 16/100 [00:02<00:11,  7.06it/s, loss=0.007]
# test-time optim.:  17% 17/100 [00:02<00:11,  7.07it/s, loss=0.007]
# test-time optim.:  17% 17/100 [00:02<00:11,  7.07it/s, loss=0.006]
# test-time optim.:  18% 18/100 [00:02<00:11,  7.08it/s, loss=0.006]
# test-time optim.:  18% 18/100 [00:03<00:11,  7.08it/s, loss=0.005]
# test-time optim.:  19% 19/100 [00:03<00:11,  7.06it/s, loss=0.005]
# test-time optim.:  19% 19/100 [00:03<00:11,  7.06it/s, loss=0.005]
# test-time optim.:  20% 20/100 [00:03<00:11,  7.06it/s, loss=0.005]
# test-time optim.:  20% 20/100 [00:03<00:11,  7.06it/s, loss=0.005]
# test-time optim.:  21% 21/100 [00:03<00:11,  7.06it/s, loss=0.005]
# test-time optim.:  21% 21/100 [00:03<00:11,  7.06it/s, loss=0.005]
# test-time optim.:  22% 22/100 [00:03<00:11,  7.07it/s, loss=0.005]
# test-time optim.:  22% 22/100 [00:03<00:11,  7.07it/s, loss=0.006]
# test-time optim.:  23% 23/100 [00:03<00:10,  7.08it/s, loss=0.006]
# test-time optim.:  23% 23/100 [00:03<00:10,  7.08it/s, loss=0.007]
# test-time optim.:  24% 24/100 [00:03<00:10,  7.08it/s, loss=0.007]
# test-time optim.:  24% 24/100 [00:03<00:10,  7.08it/s, loss=0.006]
# test-time optim.:  25% 25/100 [00:03<00:10,  7.07it/s, loss=0.006]
# test-time optim.:  25% 25/100 [00:03<00:10,  7.07it/s, loss=0.006]
# test-time optim.:  26% 26/100 [00:03<00:10,  7.09it/s, loss=0.006]
# test-time optim.:  26% 26/100 [00:04<00:10,  7.09it/s, loss=0.005]
# test-time optim.:  27% 27/100 [00:04<00:10,  7.14it/s, loss=0.005]
# test-time optim.:  27% 27/100 [00:04<00:10,  7.14it/s, loss=0.005]
# test-time optim.:  28% 28/100 [00:04<00:10,  7.15it/s, loss=0.005]
# test-time optim.:  28% 28/100 [00:04<00:10,  7.15it/s, loss=0.005]
# test-time optim.:  29% 29/100 [00:04<00:09,  7.13it/s, loss=0.005]
# test-time optim.:  29% 29/100 [00:04<00:09,  7.13it/s, loss=0.005]
# test-time optim.:  30% 30/100 [00:04<00:09,  7.10it/s, loss=0.005]
# test-time optim.:  30% 30/100 [00:04<00:09,  7.10it/s, loss=0.006]
# test-time optim.:  31% 31/100 [00:04<00:09,  7.07it/s, loss=0.006]
# test-time optim.:  31% 31/100 [00:04<00:09,  7.07it/s, loss=0.005]
# test-time optim.:  32% 32/100 [00:04<00:09,  7.09it/s, loss=0.005]
# test-time optim.:  32% 32/100 [00:04<00:09,  7.09it/s, loss=0.006]
# test-time optim.:  33% 33/100 [00:04<00:09,  7.06it/s, loss=0.006]
# test-time optim.:  33% 33/100 [00:05<00:09,  7.06it/s, loss=0.006]
# test-time optim.:  34% 34/100 [00:05<00:09,  7.05it/s, loss=0.006]
# test-time optim.:  34% 34/100 [00:05<00:09,  7.05it/s, loss=0.005]
# test-time optim.:  35% 35/100 [00:05<00:09,  7.07it/s, loss=0.005]
# test-time optim.:  35% 35/100 [00:05<00:09,  7.07it/s, loss=0.005]
# test-time optim.:  36% 36/100 [00:05<00:09,  7.10it/s, loss=0.005]
# test-time optim.:  36% 36/100 [00:05<00:09,  7.10it/s, loss=0.005]
# test-time optim.:  37% 37/100 [00:05<00:08,  7.12it/s, loss=0.005]
# test-time optim.:  37% 37/100 [00:05<00:08,  7.12it/s, loss=0.005]
# test-time optim.:  38% 38/100 [00:05<00:08,  7.12it/s, loss=0.005]
# test-time optim.:  38% 38/100 [00:05<00:08,  7.12it/s, loss=0.005]
# test-time optim.:  39% 39/100 [00:05<00:08,  7.13it/s, loss=0.005]
# test-time optim.:  39% 39/100 [00:05<00:08,  7.13it/s, loss=0.006]
# test-time optim.:  40% 40/100 [00:05<00:08,  7.18it/s, loss=0.006]
# test-time optim.:  40% 40/100 [00:06<00:08,  7.18it/s, loss=0.004]
# test-time optim.:  41% 41/100 [00:06<00:08,  7.20it/s, loss=0.004]
# test-time optim.:  41% 41/100 [00:06<00:08,  7.20it/s, loss=0.005]
# test-time optim.:  42% 42/100 [00:06<00:08,  7.19it/s, loss=0.005]
# test-time optim.:  42% 42/100 [00:06<00:08,  7.19it/s, loss=0.005]
# test-time optim.:  43% 43/100 [00:06<00:07,  7.20it/s, loss=0.005]
# test-time optim.:  43% 43/100 [00:06<00:07,  7.20it/s, loss=0.005]
# test-time optim.:  44% 44/100 [00:06<00:07,  7.17it/s, loss=0.005]
# test-time optim.:  44% 44/100 [00:06<00:07,  7.17it/s, loss=0.005]
# test-time optim.:  45% 45/100 [00:06<00:07,  7.13it/s, loss=0.005]
# test-time optim.:  45% 45/100 [00:06<00:07,  7.13it/s, loss=0.005]
# test-time optim.:  46% 46/100 [00:06<00:07,  7.09it/s, loss=0.005]
# test-time optim.:  46% 46/100 [00:06<00:07,  7.09it/s, loss=0.005]
# test-time optim.:  47% 47/100 [00:06<00:07,  7.11it/s, loss=0.005]
# test-time optim.:  47% 47/100 [00:07<00:07,  7.11it/s, loss=0.006]
# test-time optim.:  48% 48/100 [00:07<00:07,  7.16it/s, loss=0.006]
# test-time optim.:  48% 48/100 [00:07<00:07,  7.16it/s, loss=0.006]
# test-time optim.:  49% 49/100 [00:07<00:07,  7.18it/s, loss=0.006]
# test-time optim.:  49% 49/100 [00:07<00:07,  7.18it/s, loss=0.006]
# test-time optim.:  50% 50/100 [00:07<00:06,  7.19it/s, loss=0.006]
# test-time optim.:  50% 50/100 [00:07<00:06,  7.19it/s, loss=0.005]
# test-time optim.:  51% 51/100 [00:07<00:06,  7.20it/s, loss=0.005]
# test-time optim.:  51% 51/100 [00:07<00:06,  7.20it/s, loss=0.006]
# test-time optim.:  52% 52/100 [00:07<00:06,  7.18it/s, loss=0.006]
# test-time optim.:  52% 52/100 [00:07<00:06,  7.18it/s, loss=0.005]
# test-time optim.:  53% 53/100 [00:07<00:06,  7.16it/s, loss=0.005]
# test-time optim.:  53% 53/100 [00:07<00:06,  7.16it/s, loss=0.005]
# test-time optim.:  54% 54/100 [00:07<00:06,  7.13it/s, loss=0.005]
# test-time optim.:  54% 54/100 [00:08<00:06,  7.13it/s, loss=0.005]
# test-time optim.:  55% 55/100 [00:08<00:06,  7.13it/s, loss=0.005]
# test-time optim.:  55% 55/100 [00:08<00:06,  7.13it/s, loss=0.005]
# test-time optim.:  56% 56/100 [00:08<00:06,  7.14it/s, loss=0.005]
# test-time optim.:  56% 56/100 [00:08<00:06,  7.14it/s, loss=0.006]
# test-time optim.:  57% 57/100 [00:08<00:05,  7.18it/s, loss=0.006]
# test-time optim.:  57% 57/100 [00:08<00:05,  7.18it/s, loss=0.006]
# test-time optim.:  58% 58/100 [00:08<00:05,  7.19it/s, loss=0.006]
# test-time optim.:  58% 58/100 [00:08<00:05,  7.19it/s, loss=0.005]
# test-time optim.:  59% 59/100 [00:08<00:05,  7.18it/s, loss=0.005]
# test-time optim.:  59% 59/100 [00:08<00:05,  7.18it/s, loss=0.006]
# test-time optim.:  60% 60/100 [00:08<00:05,  7.19it/s, loss=0.006]
# test-time optim.:  60% 60/100 [00:08<00:05,  7.19it/s, loss=0.005]
# test-time optim.:  61% 61/100 [00:08<00:05,  7.17it/s, loss=0.005]
# test-time optim.:  61% 61/100 [00:09<00:05,  7.17it/s, loss=0.004]
# test-time optim.:  62% 62/100 [00:09<00:05,  7.15it/s, loss=0.004]
# test-time optim.:  62% 62/100 [00:09<00:05,  7.15it/s, loss=0.006]
# test-time optim.:  63% 63/100 [00:09<00:05,  7.12it/s, loss=0.006]
# test-time optim.:  63% 63/100 [00:09<00:05,  7.12it/s, loss=0.005]
# test-time optim.:  64% 64/100 [00:09<00:05,  7.12it/s, loss=0.005]
# test-time optim.:  64% 64/100 [00:09<00:05,  7.12it/s, loss=0.005]
# test-time optim.:  65% 65/100 [00:09<00:04,  7.12it/s, loss=0.005]
# test-time optim.:  65% 65/100 [00:09<00:04,  7.12it/s, loss=0.006]
# test-time optim.:  66% 66/100 [00:09<00:04,  7.13it/s, loss=0.006]
# test-time optim.:  66% 66/100 [00:09<00:04,  7.13it/s, loss=0.005]
# test-time optim.:  67% 67/100 [00:09<00:04,  7.18it/s, loss=0.005]
# test-time optim.:  67% 67/100 [00:09<00:04,  7.18it/s, loss=0.006]
# test-time optim.:  68% 68/100 [00:09<00:04,  7.18it/s, loss=0.006]
# test-time optim.:  68% 68/100 [00:10<00:04,  7.18it/s, loss=0.004]
# test-time optim.:  69% 69/100 [00:10<00:04,  7.16it/s, loss=0.004]
# test-time optim.:  69% 69/100 [00:10<00:04,  7.16it/s, loss=0.005]
# test-time optim.:  70% 70/100 [00:10<00:04,  7.17it/s, loss=0.005]
# test-time optim.:  70% 70/100 [00:10<00:04,  7.17it/s, loss=0.005]
# test-time optim.:  71% 71/100 [00:10<00:04,  7.18it/s, loss=0.005]
# test-time optim.:  71% 71/100 [00:10<00:04,  7.18it/s, loss=0.005]
# test-time optim.:  72% 72/100 [00:10<00:03,  7.14it/s, loss=0.005]
# test-time optim.:  72% 72/100 [00:10<00:03,  7.14it/s, loss=0.006]
# test-time optim.:  73% 73/100 [00:10<00:03,  7.11it/s, loss=0.006]
# test-time optim.:  73% 73/100 [00:10<00:03,  7.11it/s, loss=0.006]
# test-time optim.:  74% 74/100 [00:10<00:03,  7.09it/s, loss=0.006]
# test-time optim.:  74% 74/100 [00:10<00:03,  7.09it/s, loss=0.004]
# test-time optim.:  75% 75/100 [00:10<00:03,  7.09it/s, loss=0.004]
# test-time optim.:  75% 75/100 [00:10<00:03,  7.09it/s, loss=0.005]
# test-time optim.:  76% 76/100 [00:10<00:03,  7.09it/s, loss=0.005]
# test-time optim.:  76% 76/100 [00:11<00:03,  7.09it/s, loss=0.006]
# test-time optim.:  77% 77/100 [00:11<00:03,  7.08it/s, loss=0.006]
# test-time optim.:  77% 77/100 [00:11<00:03,  7.08it/s, loss=0.005]
# test-time optim.:  78% 78/100 [00:11<00:03,  7.11it/s, loss=0.005]
# test-time optim.:  78% 78/100 [00:11<00:03,  7.11it/s, loss=0.005]
# test-time optim.:  79% 79/100 [00:11<00:02,  7.11it/s, loss=0.005]
# test-time optim.:  79% 79/100 [00:11<00:02,  7.11it/s, loss=0.006]
# test-time optim.:  80% 80/100 [00:11<00:02,  7.14it/s, loss=0.006]
# test-time optim.:  80% 80/100 [00:11<00:02,  7.14it/s, loss=0.004]
# test-time optim.:  81% 81/100 [00:11<00:02,  7.15it/s, loss=0.004]
# test-time optim.:  81% 81/100 [00:11<00:02,  7.15it/s, loss=0.006]
# test-time optim.:  82% 82/100 [00:11<00:02,  7.13it/s, loss=0.006]
# test-time optim.:  82% 82/100 [00:11<00:02,  7.13it/s, loss=0.006]
# test-time optim.:  83% 83/100 [00:11<00:02,  7.13it/s, loss=0.006]
# test-time optim.:  83% 83/100 [00:12<00:02,  7.13it/s, loss=0.007]
# test-time optim.:  84% 84/100 [00:12<00:02,  7.11it/s, loss=0.007]
# test-time optim.:  84% 84/100 [00:12<00:02,  7.11it/s, loss=0.004]
# test-time optim.:  85% 85/100 [00:12<00:02,  7.12it/s, loss=0.004]
# test-time optim.:  85% 85/100 [00:12<00:02,  7.12it/s, loss=0.005]
# test-time optim.:  86% 86/100 [00:12<00:01,  7.13it/s, loss=0.005]
# test-time optim.:  86% 86/100 [00:12<00:01,  7.13it/s, loss=0.005]
# test-time optim.:  87% 87/100 [00:12<00:01,  7.14it/s, loss=0.005]
# test-time optim.:  87% 87/100 [00:12<00:01,  7.14it/s, loss=0.006]
# test-time optim.:  88% 88/100 [00:12<00:01,  7.10it/s, loss=0.006]
# test-time optim.:  88% 88/100 [00:12<00:01,  7.10it/s, loss=0.005]
# test-time optim.:  89% 89/100 [00:12<00:01,  7.10it/s, loss=0.005]
# test-time optim.:  89% 89/100 [00:12<00:01,  7.10it/s, loss=0.006]
# test-time optim.:  90% 90/100 [00:12<00:01,  7.09it/s, loss=0.006]
# test-time optim.:  90% 90/100 [00:13<00:01,  7.09it/s, loss=0.005]
# test-time optim.:  91% 91/100 [00:13<00:01,  7.08it/s, loss=0.005]
# test-time optim.:  91% 91/100 [00:13<00:01,  7.08it/s, loss=0.005]
# test-time optim.:  92% 92/100 [00:13<00:01,  7.07it/s, loss=0.005]
# test-time optim.:  92% 92/100 [00:13<00:01,  7.07it/s, loss=0.006]
# test-time optim.:  93% 93/100 [00:13<00:00,  7.07it/s, loss=0.006]
# test-time optim.:  93% 93/100 [00:13<00:00,  7.07it/s, loss=0.005]
# test-time optim.:  94% 94/100 [00:13<00:00,  7.08it/s, loss=0.005]
# test-time optim.:  94% 94/100 [00:13<00:00,  7.08it/s, loss=0.005]
# test-time optim.:  95% 95/100 [00:13<00:00,  7.07it/s, loss=0.005]
# test-time optim.:  95% 95/100 [00:13<00:00,  7.07it/s, loss=0.004]
# test-time optim.:  96% 96/100 [00:13<00:00,  7.06it/s, loss=0.004]
# test-time optim.:  96% 96/100 [00:13<00:00,  7.06it/s, loss=0.005]
# test-time optim.:  97% 97/100 [00:13<00:00,  7.04it/s, loss=0.005]
# test-time optim.:  97% 97/100 [00:14<00:00,  7.04it/s, loss=0.005]
# test-time optim.:  98% 98/100 [00:14<00:00,  7.06it/s, loss=0.005]
# test-time optim.:  98% 98/100 [00:14<00:00,  7.06it/s, loss=0.005]
# test-time optim.:  99% 99/100 [00:14<00:00,  7.07it/s, loss=0.005]
# test-time optim.:  99% 99/100 [00:14<00:00,  7.07it/s, loss=0.005]
# test-time optim.: 100% 100/100 [00:14<00:00,  7.09it/s, loss=0.005]
# evaluating:  25% 1/4 [00:23<01:09, 23.02s/it]
# test-time optim.:   0% 0/100 [00:00<?, ?it/s]
# test-time optim.:   0% 0/100 [00:00<?, ?it/s, loss=0.009]
# test-time optim.:   1% 1/100 [00:00<00:13,  7.38it/s, loss=0.009]
# test-time optim.:   1% 1/100 [00:00<00:13,  7.38it/s, loss=0.006]
# test-time optim.:   2% 2/100 [00:00<00:13,  7.18it/s, loss=0.006]
# test-time optim.:   2% 2/100 [00:00<00:13,  7.18it/s, loss=0.007]
# test-time optim.:   3% 3/100 [00:00<00:13,  7.11it/s, loss=0.007]
# test-time optim.:   3% 3/100 [00:00<00:13,  7.11it/s, loss=0.006]
# test-time optim.:   4% 4/100 [00:00<00:13,  7.08it/s, loss=0.006]
# test-time optim.:   4% 4/100 [00:00<00:13,  7.08it/s, loss=0.006]
# test-time optim.:   5% 5/100 [00:00<00:13,  7.06it/s, loss=0.006]
# test-time optim.:   5% 5/100 [00:00<00:13,  7.06it/s, loss=0.007]
# test-time optim.:   6% 6/100 [00:00<00:13,  7.06it/s, loss=0.007]
# test-time optim.:   6% 6/100 [00:00<00:13,  7.06it/s, loss=0.007]
# test-time optim.:   7% 7/100 [00:00<00:13,  6.92it/s, loss=0.007]
# test-time optim.:   7% 7/100 [00:01<00:13,  6.92it/s, loss=0.007]
# test-time optim.:   8% 8/100 [00:01<00:13,  6.96it/s, loss=0.007]
# test-time optim.:   8% 8/100 [00:01<00:13,  6.96it/s, loss=0.006]
# test-time optim.:   9% 9/100 [00:01<00:12,  7.00it/s, loss=0.006]
# test-time optim.:   9% 9/100 [00:01<00:12,  7.00it/s, loss=0.006]
# test-time optim.:  10% 10/100 [00:01<00:12,  7.01it/s, loss=0.006]
# test-time optim.:  10% 10/100 [00:01<00:12,  7.01it/s, loss=0.006]
# test-time optim.:  11% 11/100 [00:01<00:12,  7.01it/s, loss=0.006]
# test-time optim.:  11% 11/100 [00:01<00:12,  7.01it/s, loss=0.006]
# test-time optim.:  12% 12/100 [00:01<00:12,  7.04it/s, loss=0.006]
# test-time optim.:  12% 12/100 [00:01<00:12,  7.04it/s, loss=0.006]
# test-time optim.:  13% 13/100 [00:01<00:12,  7.05it/s, loss=0.006]
# test-time optim.:  13% 13/100 [00:01<00:12,  7.05it/s, loss=0.007]
# test-time optim.:  14% 14/100 [00:01<00:12,  7.05it/s, loss=0.007]
# test-time optim.:  14% 14/100 [00:02<00:12,  7.05it/s, loss=0.005]
# test-time optim.:  15% 15/100 [00:02<00:12,  7.06it/s, loss=0.005]
# test-time optim.:  15% 15/100 [00:02<00:12,  7.06it/s, loss=0.006]
# test-time optim.:  16% 16/100 [00:02<00:11,  7.05it/s, loss=0.006]
# test-time optim.:  16% 16/100 [00:02<00:11,  7.05it/s, loss=0.006]
# test-time optim.:  17% 17/100 [00:02<00:11,  7.05it/s, loss=0.006]
# test-time optim.:  17% 17/100 [00:02<00:11,  7.05it/s, loss=0.007]
# test-time optim.:  18% 18/100 [00:02<00:11,  7.06it/s, loss=0.007]
# test-time optim.:  18% 18/100 [00:02<00:11,  7.06it/s, loss=0.008]
# test-time optim.:  19% 19/100 [00:02<00:11,  7.06it/s, loss=0.008]
# test-time optim.:  19% 19/100 [00:02<00:11,  7.06it/s, loss=0.008]
# test-time optim.:  20% 20/100 [00:02<00:11,  7.05it/s, loss=0.008]
# test-time optim.:  20% 20/100 [00:02<00:11,  7.05it/s, loss=0.005]
# test-time optim.:  21% 21/100 [00:02<00:11,  7.05it/s, loss=0.005]
# test-time optim.:  21% 21/100 [00:03<00:11,  7.05it/s, loss=0.005]
# test-time optim.:  22% 22/100 [00:03<00:11,  7.05it/s, loss=0.005]
# test-time optim.:  22% 22/100 [00:03<00:11,  7.05it/s, loss=0.008]
# test-time optim.:  23% 23/100 [00:03<00:10,  7.04it/s, loss=0.008]
# test-time optim.:  23% 23/100 [00:03<00:10,  7.04it/s, loss=0.006]
# test-time optim.:  24% 24/100 [00:03<00:10,  7.05it/s, loss=0.006]
# test-time optim.:  24% 24/100 [00:03<00:10,  7.05it/s, loss=0.007]
# test-time optim.:  25% 25/100 [00:03<00:10,  7.04it/s, loss=0.007]
# test-time optim.:  25% 25/100 [00:03<00:10,  7.04it/s, loss=0.007]
# test-time optim.:  26% 26/100 [00:03<00:10,  7.07it/s, loss=0.007]
# test-time optim.:  26% 26/100 [00:03<00:10,  7.07it/s, loss=0.005]
# test-time optim.:  27% 27/100 [00:03<00:10,  7.07it/s, loss=0.005]
# test-time optim.:  27% 27/100 [00:03<00:10,  7.07it/s, loss=0.008]
# test-time optim.:  28% 28/100 [00:03<00:10,  7.06it/s, loss=0.008]
# test-time optim.:  28% 28/100 [00:04<00:10,  7.06it/s, loss=0.006]
# test-time optim.:  29% 29/100 [00:04<00:10,  7.07it/s, loss=0.006]
# test-time optim.:  29% 29/100 [00:04<00:10,  7.07it/s, loss=0.007]
# test-time optim.:  30% 30/100 [00:04<00:09,  7.06it/s, loss=0.007]
# test-time optim.:  30% 30/100 [00:04<00:09,  7.06it/s, loss=0.007]
# test-time optim.:  31% 31/100 [00:04<00:09,  7.05it/s, loss=0.007]
# test-time optim.:  31% 31/100 [00:04<00:09,  7.05it/s, loss=0.008]
# test-time optim.:  32% 32/100 [00:04<00:09,  7.05it/s, loss=0.008]
# test-time optim.:  32% 32/100 [00:04<00:09,  7.05it/s, loss=0.005]
# test-time optim.:  33% 33/100 [00:04<00:09,  7.06it/s, loss=0.005]
# test-time optim.:  33% 33/100 [00:04<00:09,  7.06it/s, loss=0.006]
# test-time optim.:  34% 34/100 [00:04<00:09,  7.06it/s, loss=0.006]
# test-time optim.:  34% 34/100 [00:04<00:09,  7.06it/s, loss=0.005]
# test-time optim.:  35% 35/100 [00:04<00:09,  7.06it/s, loss=0.005]
# test-time optim.:  35% 35/100 [00:05<00:09,  7.06it/s, loss=0.006]
# test-time optim.:  36% 36/100 [00:05<00:09,  7.06it/s, loss=0.006]
# test-time optim.:  36% 36/100 [00:05<00:09,  7.06it/s, loss=0.007]
# test-time optim.:  37% 37/100 [00:05<00:08,  7.04it/s, loss=0.007]
# test-time optim.:  37% 37/100 [00:05<00:08,  7.04it/s, loss=0.006]
# test-time optim.:  38% 38/100 [00:05<00:08,  7.05it/s, loss=0.006]
# test-time optim.:  38% 38/100 [00:05<00:08,  7.05it/s, loss=0.007]
# test-time optim.:  39% 39/100 [00:05<00:08,  7.06it/s, loss=0.007]
# test-time optim.:  39% 39/100 [00:05<00:08,  7.06it/s, loss=0.007]
# test-time optim.:  40% 40/100 [00:05<00:08,  7.02it/s, loss=0.007]
# test-time optim.:  40% 40/100 [00:05<00:08,  7.02it/s, loss=0.007]
# test-time optim.:  41% 41/100 [00:05<00:08,  7.02it/s, loss=0.007]
# test-time optim.:  41% 41/100 [00:05<00:08,  7.02it/s, loss=0.007]
# test-time optim.:  42% 42/100 [00:05<00:08,  7.03it/s, loss=0.007]
# test-time optim.:  42% 42/100 [00:06<00:08,  7.03it/s, loss=0.006]
# test-time optim.:  43% 43/100 [00:06<00:08,  7.05it/s, loss=0.006]
# test-time optim.:  43% 43/100 [00:06<00:08,  7.05it/s, loss=0.006]
# test-time optim.:  44% 44/100 [00:06<00:07,  7.05it/s, loss=0.006]
# test-time optim.:  44% 44/100 [00:06<00:07,  7.05it/s, loss=0.006]
# test-time optim.:  45% 45/100 [00:06<00:07,  7.06it/s, loss=0.006]
# test-time optim.:  45% 45/100 [00:06<00:07,  7.06it/s, loss=0.005]
# test-time optim.:  46% 46/100 [00:06<00:07,  7.07it/s, loss=0.005]
# test-time optim.:  46% 46/100 [00:06<00:07,  7.07it/s, loss=0.005]
# test-time optim.:  47% 47/100 [00:06<00:07,  7.01it/s, loss=0.005]
# test-time optim.:  47% 47/100 [00:06<00:07,  7.01it/s, loss=0.006]
# test-time optim.:  48% 48/100 [00:06<00:07,  7.02it/s, loss=0.006]
# test-time optim.:  48% 48/100 [00:06<00:07,  7.02it/s, loss=0.005]
# test-time optim.:  49% 49/100 [00:06<00:07,  7.05it/s, loss=0.005]
# test-time optim.:  49% 49/100 [00:07<00:07,  7.05it/s, loss=0.006]
# test-time optim.:  50% 50/100 [00:07<00:07,  7.02it/s, loss=0.006]
# test-time optim.:  50% 50/100 [00:07<00:07,  7.02it/s, loss=0.005]
# test-time optim.:  51% 51/100 [00:07<00:06,  7.03it/s, loss=0.005]
# test-time optim.:  51% 51/100 [00:07<00:06,  7.03it/s, loss=0.006]
# test-time optim.:  52% 52/100 [00:07<00:06,  7.04it/s, loss=0.006]
# test-time optim.:  52% 52/100 [00:07<00:06,  7.04it/s, loss=0.007]
# test-time optim.:  53% 53/100 [00:07<00:06,  7.02it/s, loss=0.007]
# test-time optim.:  53% 53/100 [00:07<00:06,  7.02it/s, loss=0.006]
# test-time optim.:  54% 54/100 [00:07<00:06,  7.04it/s, loss=0.006]
# test-time optim.:  54% 54/100 [00:07<00:06,  7.04it/s, loss=0.006]
# test-time optim.:  55% 55/100 [00:07<00:06,  7.05it/s, loss=0.006]
# test-time optim.:  55% 55/100 [00:07<00:06,  7.05it/s, loss=0.005]
# test-time optim.:  56% 56/100 [00:07<00:06,  7.03it/s, loss=0.005]
# test-time optim.:  56% 56/100 [00:08<00:06,  7.03it/s, loss=0.007]
# test-time optim.:  57% 57/100 [00:08<00:06,  6.93it/s, loss=0.007]
# test-time optim.:  57% 57/100 [00:08<00:06,  6.93it/s, loss=0.006]
# test-time optim.:  58% 58/100 [00:08<00:06,  6.94it/s, loss=0.006]
# test-time optim.:  58% 58/100 [00:08<00:06,  6.94it/s, loss=0.006]
# test-time optim.:  59% 59/100 [00:08<00:05,  6.87it/s, loss=0.006]
# test-time optim.:  59% 59/100 [00:08<00:05,  6.87it/s, loss=0.005]
# test-time optim.:  60% 60/100 [00:08<00:05,  6.88it/s, loss=0.005]
# test-time optim.:  60% 60/100 [00:08<00:05,  6.88it/s, loss=0.006]
# test-time optim.:  61% 61/100 [00:08<00:05,  6.91it/s, loss=0.006]
# test-time optim.:  61% 61/100 [00:08<00:05,  6.91it/s, loss=0.006]
# test-time optim.:  62% 62/100 [00:08<00:05,  6.98it/s, loss=0.006]
# test-time optim.:  62% 62/100 [00:08<00:05,  6.98it/s, loss=0.006]
# test-time optim.:  63% 63/100 [00:08<00:05,  7.02it/s, loss=0.006]
# test-time optim.:  63% 63/100 [00:09<00:05,  7.02it/s, loss=0.005]
# test-time optim.:  64% 64/100 [00:09<00:05,  7.03it/s, loss=0.005]
# test-time optim.:  64% 64/100 [00:09<00:05,  7.03it/s, loss=0.007]
# test-time optim.:  65% 65/100 [00:09<00:04,  7.04it/s, loss=0.007]
# test-time optim.:  65% 65/100 [00:09<00:04,  7.04it/s, loss=0.005]
# test-time optim.:  66% 66/100 [00:09<00:04,  7.04it/s, loss=0.005]
# test-time optim.:  66% 66/100 [00:09<00:04,  7.04it/s, loss=0.005]
# test-time optim.:  67% 67/100 [00:09<00:04,  7.04it/s, loss=0.005]
# test-time optim.:  67% 67/100 [00:09<00:04,  7.04it/s, loss=0.005]
# test-time optim.:  68% 68/100 [00:09<00:04,  7.04it/s, loss=0.005]
# test-time optim.:  68% 68/100 [00:09<00:04,  7.04it/s, loss=0.006]
# test-time optim.:  69% 69/100 [00:09<00:04,  7.05it/s, loss=0.006]
# test-time optim.:  69% 69/100 [00:09<00:04,  7.05it/s, loss=0.008]
# test-time optim.:  70% 70/100 [00:09<00:04,  7.05it/s, loss=0.008]
# test-time optim.:  70% 70/100 [00:10<00:04,  7.05it/s, loss=0.006]
# test-time optim.:  71% 71/100 [00:10<00:04,  7.05it/s, loss=0.006]
# test-time optim.:  71% 71/100 [00:10<00:04,  7.05it/s, loss=0.007]
# test-time optim.:  72% 72/100 [00:10<00:03,  7.05it/s, loss=0.007]
# test-time optim.:  72% 72/100 [00:10<00:03,  7.05it/s, loss=0.007]
# test-time optim.:  73% 73/100 [00:10<00:03,  7.06it/s, loss=0.007]
# test-time optim.:  73% 73/100 [00:10<00:03,  7.06it/s, loss=0.007]
# test-time optim.:  74% 74/100 [00:10<00:03,  7.06it/s, loss=0.007]
# test-time optim.:  74% 74/100 [00:10<00:03,  7.06it/s, loss=0.007]
# test-time optim.:  75% 75/100 [00:10<00:03,  7.06it/s, loss=0.007]
# test-time optim.:  75% 75/100 [00:10<00:03,  7.06it/s, loss=0.008]
# test-time optim.:  76% 76/100 [00:10<00:03,  7.05it/s, loss=0.008]
# test-time optim.:  76% 76/100 [00:10<00:03,  7.05it/s, loss=0.006]
# test-time optim.:  77% 77/100 [00:10<00:03,  7.05it/s, loss=0.006]
# test-time optim.:  77% 77/100 [00:11<00:03,  7.05it/s, loss=0.007]
# test-time optim.:  78% 78/100 [00:11<00:03,  7.05it/s, loss=0.007]
# test-time optim.:  78% 78/100 [00:11<00:03,  7.05it/s, loss=0.005]
# test-time optim.:  79% 79/100 [00:11<00:02,  7.05it/s, loss=0.005]
# test-time optim.:  79% 79/100 [00:11<00:02,  7.05it/s, loss=0.006]
# test-time optim.:  80% 80/100 [00:11<00:02,  7.06it/s, loss=0.006]
# test-time optim.:  80% 80/100 [00:11<00:02,  7.06it/s, loss=0.007]
# test-time optim.:  81% 81/100 [00:11<00:02,  7.05it/s, loss=0.007]
# test-time optim.:  81% 81/100 [00:11<00:02,  7.05it/s, loss=0.006]
# test-time optim.:  82% 82/100 [00:11<00:02,  7.04it/s, loss=0.006]
# test-time optim.:  82% 82/100 [00:11<00:02,  7.04it/s, loss=0.005]
# test-time optim.:  83% 83/100 [00:11<00:02,  7.03it/s, loss=0.005]
# test-time optim.:  83% 83/100 [00:11<00:02,  7.03it/s, loss=0.005]
# test-time optim.:  84% 84/100 [00:11<00:02,  7.04it/s, loss=0.005]
# test-time optim.:  84% 84/100 [00:12<00:02,  7.04it/s, loss=0.007]
# test-time optim.:  85% 85/100 [00:12<00:02,  7.06it/s, loss=0.007]
# test-time optim.:  85% 85/100 [00:12<00:02,  7.06it/s, loss=0.005]
# test-time optim.:  86% 86/100 [00:12<00:01,  7.06it/s, loss=0.005]
# test-time optim.:  86% 86/100 [00:12<00:01,  7.06it/s, loss=0.005]
# test-time optim.:  87% 87/100 [00:12<00:01,  7.06it/s, loss=0.005]
# test-time optim.:  87% 87/100 [00:12<00:01,  7.06it/s, loss=0.006]
# test-time optim.:  88% 88/100 [00:12<00:01,  7.06it/s, loss=0.006]
# test-time optim.:  88% 88/100 [00:12<00:01,  7.06it/s, loss=0.005]
# test-time optim.:  89% 89/100 [00:12<00:01,  7.05it/s, loss=0.005]
# test-time optim.:  89% 89/100 [00:12<00:01,  7.05it/s, loss=0.005]
# test-time optim.:  90% 90/100 [00:12<00:01,  7.05it/s, loss=0.005]
# test-time optim.:  90% 90/100 [00:12<00:01,  7.05it/s, loss=0.006]
# test-time optim.:  91% 91/100 [00:12<00:01,  6.97it/s, loss=0.006]
# test-time optim.:  91% 91/100 [00:13<00:01,  6.97it/s, loss=0.006]
# test-time optim.:  92% 92/100 [00:13<00:01,  6.97it/s, loss=0.006]
# test-time optim.:  92% 92/100 [00:13<00:01,  6.97it/s, loss=0.005]
# test-time optim.:  93% 93/100 [00:13<00:01,  6.96it/s, loss=0.005]
# test-time optim.:  93% 93/100 [00:13<00:01,  6.96it/s, loss=0.005]
# test-time optim.:  94% 94/100 [00:13<00:00,  6.98it/s, loss=0.005]
# test-time optim.:  94% 94/100 [00:13<00:00,  6.98it/s, loss=0.005]
# test-time optim.:  95% 95/100 [00:13<00:00,  6.95it/s, loss=0.005]
# test-time optim.:  95% 95/100 [00:13<00:00,  6.95it/s, loss=0.006]
# test-time optim.:  96% 96/100 [00:13<00:00,  6.95it/s, loss=0.006]
# test-time optim.:  96% 96/100 [00:13<00:00,  6.95it/s, loss=0.007]
# test-time optim.:  97% 97/100 [00:13<00:00,  6.95it/s, loss=0.007]
# test-time optim.:  97% 97/100 [00:13<00:00,  6.95it/s, loss=0.006]
# test-time optim.:  98% 98/100 [00:13<00:00,  6.96it/s, loss=0.006]
# test-time optim.:  98% 98/100 [00:14<00:00,  6.96it/s, loss=0.005]
# test-time optim.:  99% 99/100 [00:14<00:00,  6.99it/s, loss=0.005]
# test-time optim.:  99% 99/100 [00:14<00:00,  6.99it/s, loss=0.006]
# test-time optim.: 100% 100/100 [00:14<00:00,  7.01it/s, loss=0.006]
# evaluating:  50% 2/4 [00:45<00:45, 22.85s/it]
# test-time optim.:   0% 0/100 [00:00<?, ?it/s]
# test-time optim.:   0% 0/100 [00:00<?, ?it/s, loss=0.008]
# test-time optim.:   1% 1/100 [00:00<00:13,  7.18it/s, loss=0.008]
# test-time optim.:   1% 1/100 [00:00<00:13,  7.18it/s, loss=0.008]
# test-time optim.:   2% 2/100 [00:00<00:13,  7.02it/s, loss=0.008]
# test-time optim.:   2% 2/100 [00:00<00:13,  7.02it/s, loss=0.008]
# test-time optim.:   3% 3/100 [00:00<00:13,  7.01it/s, loss=0.008]
# test-time optim.:   3% 3/100 [00:00<00:13,  7.01it/s, loss=0.007]
# test-time optim.:   4% 4/100 [00:00<00:13,  6.93it/s, loss=0.007]
# test-time optim.:   4% 4/100 [00:00<00:13,  6.93it/s, loss=0.008]
# test-time optim.:   5% 5/100 [00:00<00:13,  6.91it/s, loss=0.008]
# test-time optim.:   5% 5/100 [00:00<00:13,  6.91it/s, loss=0.006]
# test-time optim.:   6% 6/100 [00:00<00:13,  6.93it/s, loss=0.006]
# test-time optim.:   6% 6/100 [00:01<00:13,  6.93it/s, loss=0.010]
# test-time optim.:   7% 7/100 [00:01<00:13,  6.80it/s, loss=0.010]
# test-time optim.:   7% 7/100 [00:01<00:13,  6.80it/s, loss=0.010]
# test-time optim.:   8% 8/100 [00:01<00:13,  6.81it/s, loss=0.010]
# test-time optim.:   8% 8/100 [00:01<00:13,  6.81it/s, loss=0.008]
# test-time optim.:   9% 9/100 [00:01<00:13,  6.82it/s, loss=0.008]
# test-time optim.:   9% 9/100 [00:01<00:13,  6.82it/s, loss=0.007]
# test-time optim.:  10% 10/100 [00:01<00:13,  6.88it/s, loss=0.007]
# test-time optim.:  10% 10/100 [00:01<00:13,  6.88it/s, loss=0.007]
# test-time optim.:  11% 11/100 [00:01<00:12,  6.90it/s, loss=0.007]
# test-time optim.:  11% 11/100 [00:01<00:12,  6.90it/s, loss=0.007]
# test-time optim.:  12% 12/100 [00:01<00:12,  6.90it/s, loss=0.007]
# test-time optim.:  12% 12/100 [00:01<00:12,  6.90it/s, loss=0.007]
# test-time optim.:  13% 13/100 [00:01<00:12,  6.90it/s, loss=0.007]
# test-time optim.:  13% 13/100 [00:02<00:12,  6.90it/s, loss=0.009]
# test-time optim.:  14% 14/100 [00:02<00:12,  6.91it/s, loss=0.009]
# test-time optim.:  14% 14/100 [00:02<00:12,  6.91it/s, loss=0.009]
# test-time optim.:  15% 15/100 [00:02<00:12,  6.87it/s, loss=0.009]
# test-time optim.:  15% 15/100 [00:02<00:12,  6.87it/s, loss=0.006]
# test-time optim.:  16% 16/100 [00:02<00:12,  6.91it/s, loss=0.006]
# test-time optim.:  16% 16/100 [00:02<00:12,  6.91it/s, loss=0.007]
# test-time optim.:  17% 17/100 [00:02<00:11,  6.96it/s, loss=0.007]
# test-time optim.:  17% 17/100 [00:02<00:11,  6.96it/s, loss=0.006]
# test-time optim.:  18% 18/100 [00:02<00:11,  6.94it/s, loss=0.006]
# test-time optim.:  18% 18/100 [00:02<00:11,  6.94it/s, loss=0.009]
# test-time optim.:  19% 19/100 [00:02<00:11,  6.92it/s, loss=0.009]
# test-time optim.:  19% 19/100 [00:02<00:11,  6.92it/s, loss=0.006]
# test-time optim.:  20% 20/100 [00:02<00:11,  6.90it/s, loss=0.006]
# test-time optim.:  20% 20/100 [00:03<00:11,  6.90it/s, loss=0.008]
# test-time optim.:  21% 21/100 [00:03<00:11,  6.91it/s, loss=0.008]
# test-time optim.:  21% 21/100 [00:03<00:11,  6.91it/s, loss=0.007]
# test-time optim.:  22% 22/100 [00:03<00:11,  6.88it/s, loss=0.007]
# test-time optim.:  22% 22/100 [00:03<00:11,  6.88it/s, loss=0.008]
# test-time optim.:  23% 23/100 [00:03<00:11,  6.89it/s, loss=0.008]
# test-time optim.:  23% 23/100 [00:03<00:11,  6.89it/s, loss=0.008]
# test-time optim.:  24% 24/100 [00:03<00:10,  6.93it/s, loss=0.008]
# test-time optim.:  24% 24/100 [00:03<00:10,  6.93it/s, loss=0.006]
# test-time optim.:  25% 25/100 [00:03<00:10,  6.89it/s, loss=0.006]
# test-time optim.:  25% 25/100 [00:03<00:10,  6.89it/s, loss=0.009]
# test-time optim.:  26% 26/100 [00:03<00:10,  6.88it/s, loss=0.009]
# test-time optim.:  26% 26/100 [00:03<00:10,  6.88it/s, loss=0.009]
# test-time optim.:  27% 27/100 [00:03<00:10,  6.88it/s, loss=0.009]
# test-time optim.:  27% 27/100 [00:04<00:10,  6.88it/s, loss=0.008]
# test-time optim.:  28% 28/100 [00:04<00:10,  6.88it/s, loss=0.008]
# test-time optim.:  28% 28/100 [00:04<00:10,  6.88it/s, loss=0.006]
# test-time optim.:  29% 29/100 [00:04<00:10,  6.91it/s, loss=0.006]
# test-time optim.:  29% 29/100 [00:04<00:10,  6.91it/s, loss=0.007]
# test-time optim.:  30% 30/100 [00:04<00:10,  6.90it/s, loss=0.007]
# test-time optim.:  30% 30/100 [00:04<00:10,  6.90it/s, loss=0.007]
# test-time optim.:  31% 31/100 [00:04<00:10,  6.89it/s, loss=0.007]
# test-time optim.:  31% 31/100 [00:04<00:10,  6.89it/s, loss=0.009]
# test-time optim.:  32% 32/100 [00:04<00:09,  6.89it/s, loss=0.009]
# test-time optim.:  32% 32/100 [00:04<00:09,  6.89it/s, loss=0.007]
# test-time optim.:  33% 33/100 [00:04<00:09,  6.91it/s, loss=0.007]
# test-time optim.:  33% 33/100 [00:04<00:09,  6.91it/s, loss=0.009]
# test-time optim.:  34% 34/100 [00:04<00:09,  6.88it/s, loss=0.009]
# test-time optim.:  34% 34/100 [00:05<00:09,  6.88it/s, loss=0.008]
# test-time optim.:  35% 35/100 [00:05<00:09,  6.89it/s, loss=0.008]
# test-time optim.:  35% 35/100 [00:05<00:09,  6.89it/s, loss=0.008]
# test-time optim.:  36% 36/100 [00:05<00:09,  6.90it/s, loss=0.008]
# test-time optim.:  36% 36/100 [00:05<00:09,  6.90it/s, loss=0.008]
# test-time optim.:  37% 37/100 [00:05<00:09,  6.88it/s, loss=0.008]
# test-time optim.:  37% 37/100 [00:05<00:09,  6.88it/s, loss=0.008]
# test-time optim.:  38% 38/100 [00:05<00:09,  6.87it/s, loss=0.008]
# test-time optim.:  38% 38/100 [00:05<00:09,  6.87it/s, loss=0.008]
# test-time optim.:  39% 39/100 [00:05<00:08,  6.85it/s, loss=0.008]
# test-time optim.:  39% 39/100 [00:05<00:08,  6.85it/s, loss=0.008]
# test-time optim.:  40% 40/100 [00:05<00:08,  6.88it/s, loss=0.008]
# test-time optim.:  40% 40/100 [00:05<00:08,  6.88it/s, loss=0.008]
# test-time optim.:  41% 41/100 [00:05<00:08,  6.92it/s, loss=0.008]
# test-time optim.:  41% 41/100 [00:06<00:08,  6.92it/s, loss=0.008]
# test-time optim.:  42% 42/100 [00:06<00:08,  6.94it/s, loss=0.008]
# test-time optim.:  42% 42/100 [00:06<00:08,  6.94it/s, loss=0.008]
# test-time optim.:  43% 43/100 [00:06<00:08,  6.90it/s, loss=0.008]
# test-time optim.:  43% 43/100 [00:06<00:08,  6.90it/s, loss=0.007]
# test-time optim.:  44% 44/100 [00:06<00:08,  6.89it/s, loss=0.007]
# test-time optim.:  44% 44/100 [00:06<00:08,  6.89it/s, loss=0.006]
# test-time optim.:  45% 45/100 [00:06<00:08,  6.86it/s, loss=0.006]
# test-time optim.:  45% 45/100 [00:06<00:08,  6.86it/s, loss=0.008]
# test-time optim.:  46% 46/100 [00:06<00:07,  6.86it/s, loss=0.008]
# test-time optim.:  46% 46/100 [00:06<00:07,  6.86it/s, loss=0.008]
# test-time optim.:  47% 47/100 [00:06<00:07,  6.83it/s, loss=0.008]
# test-time optim.:  47% 47/100 [00:06<00:07,  6.83it/s, loss=0.005]
# test-time optim.:  48% 48/100 [00:06<00:07,  6.86it/s, loss=0.005]
# test-time optim.:  48% 48/100 [00:07<00:07,  6.86it/s, loss=0.008]
# test-time optim.:  49% 49/100 [00:07<00:07,  6.83it/s, loss=0.008]
# test-time optim.:  49% 49/100 [00:07<00:07,  6.83it/s, loss=0.007]
# test-time optim.:  50% 50/100 [00:07<00:07,  6.85it/s, loss=0.007]
# test-time optim.:  50% 50/100 [00:07<00:07,  6.85it/s, loss=0.008]
# test-time optim.:  51% 51/100 [00:07<00:07,  6.87it/s, loss=0.008]
# test-time optim.:  51% 51/100 [00:07<00:07,  6.87it/s, loss=0.008]
# test-time optim.:  52% 52/100 [00:07<00:07,  6.86it/s, loss=0.008]
# test-time optim.:  52% 52/100 [00:07<00:07,  6.86it/s, loss=0.008]
# test-time optim.:  53% 53/100 [00:07<00:06,  6.85it/s, loss=0.008]
# test-time optim.:  53% 53/100 [00:07<00:06,  6.85it/s, loss=0.008]
# test-time optim.:  54% 54/100 [00:07<00:06,  6.81it/s, loss=0.008]
# test-time optim.:  54% 54/100 [00:07<00:06,  6.81it/s, loss=0.006]
# test-time optim.:  55% 55/100 [00:07<00:06,  6.87it/s, loss=0.006]
# test-time optim.:  55% 55/100 [00:08<00:06,  6.87it/s, loss=0.009]
# test-time optim.:  56% 56/100 [00:08<00:06,  6.85it/s, loss=0.009]
# test-time optim.:  56% 56/100 [00:08<00:06,  6.85it/s, loss=0.008]
# test-time optim.:  57% 57/100 [00:08<00:06,  6.87it/s, loss=0.008]
# test-time optim.:  57% 57/100 [00:08<00:06,  6.87it/s, loss=0.006]
# test-time optim.:  58% 58/100 [00:08<00:06,  6.87it/s, loss=0.006]
# test-time optim.:  58% 58/100 [00:08<00:06,  6.87it/s, loss=0.007]
# test-time optim.:  59% 59/100 [00:08<00:06,  6.83it/s, loss=0.007]
# test-time optim.:  59% 59/100 [00:08<00:06,  6.83it/s, loss=0.008]
# test-time optim.:  60% 60/100 [00:08<00:05,  6.87it/s, loss=0.008]
# test-time optim.:  60% 60/100 [00:08<00:05,  6.87it/s, loss=0.007]
# test-time optim.:  61% 61/100 [00:08<00:05,  6.89it/s, loss=0.007]
# test-time optim.:  61% 61/100 [00:09<00:05,  6.89it/s, loss=0.005]
# test-time optim.:  62% 62/100 [00:09<00:05,  6.88it/s, loss=0.005]
# test-time optim.:  62% 62/100 [00:09<00:05,  6.88it/s, loss=0.008]
# test-time optim.:  63% 63/100 [00:09<00:05,  6.75it/s, loss=0.008]
# test-time optim.:  63% 63/100 [00:09<00:05,  6.75it/s, loss=0.006]
# test-time optim.:  64% 64/100 [00:09<00:05,  6.78it/s, loss=0.006]
# test-time optim.:  64% 64/100 [00:09<00:05,  6.78it/s, loss=0.008]
# test-time optim.:  65% 65/100 [00:09<00:05,  6.79it/s, loss=0.008]
# test-time optim.:  65% 65/100 [00:09<00:05,  6.79it/s, loss=0.006]
# test-time optim.:  66% 66/100 [00:09<00:05,  6.79it/s, loss=0.006]
# test-time optim.:  66% 66/100 [00:09<00:05,  6.79it/s, loss=0.008]
# test-time optim.:  67% 67/100 [00:09<00:04,  6.80it/s, loss=0.008]
# test-time optim.:  67% 67/100 [00:09<00:04,  6.80it/s, loss=0.006]
# test-time optim.:  68% 68/100 [00:09<00:04,  6.78it/s, loss=0.006]
# test-time optim.:  68% 68/100 [00:10<00:04,  6.78it/s, loss=0.007]
# test-time optim.:  69% 69/100 [00:10<00:04,  6.78it/s, loss=0.007]
# test-time optim.:  69% 69/100 [00:10<00:04,  6.78it/s, loss=0.007]
# test-time optim.:  70% 70/100 [00:10<00:04,  6.76it/s, loss=0.007]
# test-time optim.:  70% 70/100 [00:10<00:04,  6.76it/s, loss=0.006]
# test-time optim.:  71% 71/100 [00:10<00:04,  6.76it/s, loss=0.006]
# test-time optim.:  71% 71/100 [00:10<00:04,  6.76it/s, loss=0.008]
# test-time optim.:  72% 72/100 [00:10<00:04,  6.78it/s, loss=0.008]
# test-time optim.:  72% 72/100 [00:10<00:04,  6.78it/s, loss=0.007]
# test-time optim.:  73% 73/100 [00:10<00:03,  6.76it/s, loss=0.007]
# test-time optim.:  73% 73/100 [00:10<00:03,  6.76it/s, loss=0.008]
# test-time optim.:  74% 74/100 [00:10<00:03,  6.78it/s, loss=0.008]
# test-time optim.:  74% 74/100 [00:10<00:03,  6.78it/s, loss=0.007]
# test-time optim.:  75% 75/100 [00:10<00:03,  6.77it/s, loss=0.007]
# test-time optim.:  75% 75/100 [00:11<00:03,  6.77it/s, loss=0.007]
# test-time optim.:  76% 76/100 [00:11<00:03,  6.71it/s, loss=0.007]
# test-time optim.:  76% 76/100 [00:11<00:03,  6.71it/s, loss=0.006]
# test-time optim.:  77% 77/100 [00:11<00:03,  6.20it/s, loss=0.006]
# test-time optim.:  77% 77/100 [00:11<00:03,  6.20it/s, loss=0.007]
# test-time optim.:  78% 78/100 [00:11<00:03,  6.04it/s, loss=0.007]
# test-time optim.:  78% 78/100 [00:11<00:03,  6.04it/s, loss=0.008]
# test-time optim.:  79% 79/100 [00:11<00:03,  5.77it/s, loss=0.008]
# test-time optim.:  79% 79/100 [00:11<00:03,  5.77it/s, loss=0.007]
# test-time optim.:  80% 80/100 [00:11<00:03,  5.99it/s, loss=0.007]
# test-time optim.:  80% 80/100 [00:11<00:03,  5.99it/s, loss=0.007]
# test-time optim.:  81% 81/100 [00:11<00:03,  6.20it/s, loss=0.007]
# test-time optim.:  81% 81/100 [00:12<00:03,  6.20it/s, loss=0.007]
# test-time optim.:  82% 82/100 [00:12<00:02,  6.36it/s, loss=0.007]
# test-time optim.:  82% 82/100 [00:12<00:02,  6.36it/s, loss=0.007]
# test-time optim.:  83% 83/100 [00:12<00:02,  6.31it/s, loss=0.007]
# test-time optim.:  83% 83/100 [00:12<00:02,  6.31it/s, loss=0.010]
# test-time optim.:  84% 84/100 [00:12<00:02,  6.02it/s, loss=0.010]
# test-time optim.:  84% 84/100 [00:12<00:02,  6.02it/s, loss=0.009]
# test-time optim.:  85% 85/100 [00:12<00:02,  6.12it/s, loss=0.009]
# test-time optim.:  85% 85/100 [00:12<00:02,  6.12it/s, loss=0.006]
# test-time optim.:  86% 86/100 [00:12<00:02,  6.30it/s, loss=0.006]
# test-time optim.:  86% 86/100 [00:12<00:02,  6.30it/s, loss=0.007]
# test-time optim.:  87% 87/100 [00:12<00:02,  6.44it/s, loss=0.007]
# test-time optim.:  87% 87/100 [00:13<00:02,  6.44it/s, loss=0.007]
# test-time optim.:  88% 88/100 [00:13<00:01,  6.54it/s, loss=0.007]
# test-time optim.:  88% 88/100 [00:13<00:01,  6.54it/s, loss=0.008]
# test-time optim.:  89% 89/100 [00:13<00:01,  6.56it/s, loss=0.008]
# test-time optim.:  89% 89/100 [00:13<00:01,  6.56it/s, loss=0.007]
# test-time optim.:  90% 90/100 [00:13<00:01,  6.52it/s, loss=0.007]
# test-time optim.:  90% 90/100 [00:13<00:01,  6.52it/s, loss=0.006]
# test-time optim.:  91% 91/100 [00:13<00:01,  6.42it/s, loss=0.006]
# test-time optim.:  91% 91/100 [00:13<00:01,  6.42it/s, loss=0.006]
# test-time optim.:  92% 92/100 [00:13<00:01,  6.54it/s, loss=0.006]
# test-time optim.:  92% 92/100 [00:13<00:01,  6.54it/s, loss=0.010]
# test-time optim.:  93% 93/100 [00:13<00:01,  6.61it/s, loss=0.010]
# test-time optim.:  93% 93/100 [00:13<00:01,  6.61it/s, loss=0.008]
# test-time optim.:  94% 94/100 [00:13<00:00,  6.69it/s, loss=0.008]
# test-time optim.:  94% 94/100 [00:14<00:00,  6.69it/s, loss=0.006]
# test-time optim.:  95% 95/100 [00:14<00:00,  6.70it/s, loss=0.006]
# test-time optim.:  95% 95/100 [00:14<00:00,  6.70it/s, loss=0.007]
# test-time optim.:  96% 96/100 [00:14<00:00,  6.72it/s, loss=0.007]
# test-time optim.:  96% 96/100 [00:14<00:00,  6.72it/s, loss=0.006]
# test-time optim.:  97% 97/100 [00:14<00:00,  6.73it/s, loss=0.006]
# test-time optim.:  97% 97/100 [00:14<00:00,  6.73it/s, loss=0.007]
# test-time optim.:  98% 98/100 [00:14<00:00,  6.74it/s, loss=0.007]
# test-time optim.:  98% 98/100 [00:14<00:00,  6.74it/s, loss=0.009]
# test-time optim.:  99% 99/100 [00:14<00:00,  6.76it/s, loss=0.009]
# test-time optim.:  99% 99/100 [00:14<00:00,  6.76it/s, loss=0.008]
# test-time optim.: 100% 100/100 [00:14<00:00,  6.75it/s, loss=0.008]
# evaluating:  75% 3/4 [01:09<00:23, 23.19s/it]
# test-time optim.:   0% 0/100 [00:00<?, ?it/s]
# test-time optim.:   0% 0/100 [00:00<?, ?it/s, loss=0.009]
# test-time optim.:   1% 1/100 [00:00<00:14,  6.92it/s, loss=0.009]
# test-time optim.:   1% 1/100 [00:00<00:14,  6.92it/s, loss=0.008]
# test-time optim.:   2% 2/100 [00:00<00:14,  6.74it/s, loss=0.008]
# test-time optim.:   2% 2/100 [00:00<00:14,  6.74it/s, loss=0.008]
# test-time optim.:   3% 3/100 [00:00<00:14,  6.71it/s, loss=0.008]
# test-time optim.:   3% 3/100 [00:00<00:14,  6.71it/s, loss=0.007]
# test-time optim.:   4% 4/100 [00:00<00:14,  6.72it/s, loss=0.007]
# test-time optim.:   4% 4/100 [00:00<00:14,  6.72it/s, loss=0.009]
# test-time optim.:   5% 5/100 [00:00<00:14,  6.72it/s, loss=0.009]
# test-time optim.:   5% 5/100 [00:00<00:14,  6.72it/s, loss=0.008]
# test-time optim.:   6% 6/100 [00:00<00:14,  6.64it/s, loss=0.008]
# test-time optim.:   6% 6/100 [00:01<00:14,  6.64it/s, loss=0.007]
# test-time optim.:   7% 7/100 [00:01<00:14,  6.57it/s, loss=0.007]
# test-time optim.:   7% 7/100 [00:01<00:14,  6.57it/s, loss=0.006]
# test-time optim.:   8% 8/100 [00:01<00:13,  6.61it/s, loss=0.006]
# test-time optim.:   8% 8/100 [00:01<00:13,  6.61it/s, loss=0.008]
# test-time optim.:   9% 9/100 [00:01<00:13,  6.56it/s, loss=0.008]
# test-time optim.:   9% 9/100 [00:01<00:13,  6.56it/s, loss=0.007]
# test-time optim.:  10% 10/100 [00:01<00:13,  6.56it/s, loss=0.007]
# test-time optim.:  10% 10/100 [00:01<00:13,  6.56it/s, loss=0.009]
# test-time optim.:  11% 11/100 [00:01<00:13,  6.55it/s, loss=0.009]
# test-time optim.:  11% 11/100 [00:01<00:13,  6.55it/s, loss=0.009]
# test-time optim.:  12% 12/100 [00:01<00:13,  6.54it/s, loss=0.009]
# test-time optim.:  12% 12/100 [00:01<00:13,  6.54it/s, loss=0.008]
# test-time optim.:  13% 13/100 [00:01<00:13,  6.55it/s, loss=0.008]
# ...
# setting configurations...
# loading options/base.yaml...
# loading options/nerf_blender.yaml...
# loading options/barf_blender.yaml...
# "resume_iter" not found in original opt, add? (y/n) n
# safe exiting...
#
# ============================================================
# Évaluation à l'itération: 500
# ============================================================
#
# Process ID: 15432
# [/content/barf_workspace/bundle-adjusting-NeRF/evaluate.py] (PyTorch code for evaluating NeRF/BARF)
# setting configurations...
# loading options/base.yaml...
# loading options/nerf_blender.yaml...
# loading options/barf_blender.yaml...
# "resume_iter" not found in original opt, add? (y/n) y
# * H: 400
# * W: 400
# * arch:
#    * density_activ: softplus
#    * layers_feat: [None, 256, 256, 256, 256, 256, 256, 256, 256]
#    * layers_rgb: [None, 128, 3]
#    * posenc:
#       * L_3D: 10
#       * L_view: 4
#    * skip: [4]
#    * tf_init: True
# * barf_c2f: [0.1, 0.5]
# * batch_size: None
# * camera:
#    * model: perspective
#    * ndc: False
#    * noise: 0.15
# * cpu: False
# * data:
#    * augment:
#    * bgcolor: 1
#    * center_crop: None
#    * dataset: blender
#    * image_size: [400, 400]
#    * num_workers: 4
#    * preload: True
#    * root: /content/data/nerf_synthetic
#    * scene: lego
#    * train_sub: None
#    * val_on_test: False
#    * val_sub: 4
# * device: cuda:0
# * freq:
#    * ckpt: 5000
#    * scalar: 200
#    * val: 2000
#    * vis: 1000
# * gpu: 0
# * group: barf_lego
# * load: /content/drive/MyDrive/projet_nerf_barf/checkpoints/20000.ckpt
# * loss_weight:
#    * render: 0
#    * render_fine: None
# * max_epoch: None
# * max_iter: 200000
# * model: barf
# * name: debug
# * nerf:
#    * density_noise_reg: None
#    * depth:
#       * param: metric
#       * range: [2, 6]
#    * fine_sampling: False
#    * rand_rays: 1024
#    * sample_intvs: 128
#    * sample_intvs_fine: None
#    * sample_stratified: True
#    * setbg_opaque: False
#    * view_dep: True
# * optim:
#    * algo: Adam
#    * lr: 0.0005
#    * lr_end: 0.0001
#    * lr_pose: 0.001
#    * lr_pose_end: 1e-05
#    * sched:
#       * gamma: None
#       * type: ExponentialLR
#    * sched_pose:
#       * gamma: None
#       * type: ExponentialLR
#    * test_iter: 100
#    * test_photo: True
#    * warmup_pose: None
# * output_path: output/barf_lego/debug
# * output_root: output
# * resume: False
# * resume_iter: 500
# * seed: 0
# * tb:
#    * num_images: [4, 8]
# * trimesh:
#    * chunk_size: 16384
#    * range: [-1.2, 1.2]
#    * res: 128
#    * thres: 25.0
# * visdom: False
# * yaml: barf_blender
# 2025-11-30 08:28:15.336058: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764491295.366902   15432 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764491295.376973   15432 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764491295.401162   15432 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764491295.401190   15432 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764491295.401198   15432 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764491295.401205   15432 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-30 08:28:15.407885: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/alex.pth
# loading training data...
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# number of samples: 100
# loading test data...
# number of samples: 4
# building networks...
# writing videos...
# loading weights from checkpoint /content/drive/MyDrive/projet_nerf_barf/checkpoints/20000.ckpt...
# restoring nerf...
# restoring se3_refine...
# --------------------------
# rot:      0.396
# trans:    0.01166
# --------------------------
# evaluating:   0% 0/4 [00:00<?, ?it/s]
# test-time optim.:   0% 0/100 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4317.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#
# test-time optim.:   0% 0/100 [00:00<?, ?it/s, loss=0.006]
# test-time optim.:   1% 1/100 [00:00<00:49,  1.99it/s, loss=0.006]
# test-time optim.:   1% 1/100 [00:00<00:49,  1.99it/s, loss=0.006]
# test-time optim.:   2% 2/100 [00:00<00:30,  3.24it/s, loss=0.006]
# test-time optim.:   2% 2/100 [00:00<00:30,  3.24it/s, loss=0.005]
# test-time optim.:   3% 3/100 [00:00<00:23,  4.18it/s, loss=0.005]
# test-time optim.:   3% 3/100 [00:00<00:23,  4.18it/s, loss=0.005]
# test-time optim.:   4% 4/100 [00:00<00:19,  4.98it/s, loss=0.005]
# test-time optim.:   4% 4/100 [00:01<00:19,  4.98it/s, loss=0.006]
# test-time optim.:   5% 5/100 [00:01<00:17,  5.57it/s, loss=0.006]
# test-time optim.:   5% 5/100 [00:01<00:17,  5.57it/s, loss=0.006]
# test-time optim.:   6% 6/100 [00:01<00:15,  6.00it/s, loss=0.006]
# test-time optim.:   6% 6/100 [00:01<00:15,  6.00it/s, loss=0.005]
# test-time optim.:   7% 7/100 [00:01<00:14,  6.30it/s, loss=0.005]
# test-time optim.:   7% 7/100 [00:01<00:14,  6.30it/s, loss=0.006]
# test-time optim.:   8% 8/100 [00:01<00:14,  6.52it/s, loss=0.006]
# test-time optim.:   8% 8/100 [00:01<00:14,  6.52it/s, loss=0.005]
# test-time optim.:   9% 9/100 [00:01<00:13,  6.68it/s, loss=0.005]
# test-time optim.:   9% 9/100 [00:01<00:13,  6.68it/s, loss=0.007]
# test-time optim.:  10% 10/100 [00:01<00:13,  6.78it/s, loss=0.007]
# test-time optim.:  10% 10/100 [00:01<00:13,  6.78it/s, loss=0.006]
# test-time optim.:  11% 11/100 [00:01<00:13,  6.84it/s, loss=0.006]
# test-time optim.:  11% 11/100 [00:02<00:13,  6.84it/s, loss=0.005]
# test-time optim.:  12% 12/100 [00:02<00:12,  6.90it/s, loss=0.005]
# test-time optim.:  12% 12/100 [00:02<00:12,  6.90it/s, loss=0.006]
# test-time optim.:  13% 13/100 [00:02<00:12,  6.94it/s, loss=0.006]
# test-time optim.:  13% 13/100 [00:02<00:12,  6.94it/s, loss=0.006]
# test-time optim.:  14% 14/100 [00:02<00:12,  6.99it/s, loss=0.006]
# test-time optim.:  14% 14/100 [00:02<00:12,  6.99it/s, loss=0.004]
# test-time optim.:  15% 15/100 [00:02<00:12,  7.02it/s, loss=0.004]
# test-time optim.:  15% 15/100 [00:02<00:12,  7.02it/s, loss=0.004]
# test-time optim.:  16% 16/100 [00:02<00:11,  7.03it/s, loss=0.004]
# test-time optim.:  16% 16/100 [00:02<00:11,  7.03it/s, loss=0.007]
# test-time optim.:  17% 17/100 [00:02<00:11,  6.99it/s, loss=0.007]
# test-time optim.:  17% 17/100 [00:02<00:11,  6.99it/s, loss=0.006]
# test-time optim.:  18% 18/100 [00:02<00:11,  6.97it/s, loss=0.006]
# test-time optim.:  18% 18/100 [00:03<00:11,  6.97it/s, loss=0.005]
# test-time optim.:  19% 19/100 [00:03<00:11,  6.95it/s, loss=0.005]
# test-time optim.:  19% 19/100 [00:03<00:11,  6.95it/s, loss=0.005]
# test-time optim.:  20% 20/100 [00:03<00:11,  6.95it/s, loss=0.005]
# test-time optim.:  20% 20/100 [00:03<00:11,  6.95it/s, loss=0.005]
# test-time optim.:  21% 21/100 [00:03<00:11,  6.95it/s, loss=0.005]
# test-time optim.:  21% 21/100 [00:03<00:11,  6.95it/s, loss=0.005]
# test-time optim.:  22% 22/100 [00:03<00:11,  6.92it/s, loss=0.005]
# test-time optim.:  22% 22/100 [00:03<00:11,  6.92it/s, loss=0.006]
# test-time optim.:  23% 23/100 [00:03<00:11,  6.92it/s, loss=0.006]
# test-time optim.:  23% 23/100 [00:03<00:11,  6.92it/s, loss=0.007]
# test-time optim.:  24% 24/100 [00:03<00:10,  6.96it/s, loss=0.007]
# test-time optim.:  24% 24/100 [00:03<00:10,  6.96it/s, loss=0.006]
# test-time optim.:  25% 25/100 [00:03<00:10,  6.94it/s, loss=0.006]
# test-time optim.:  25% 25/100 [00:04<00:10,  6.94it/s, loss=0.006]
# test-time optim.:  26% 26/100 [00:04<00:10,  6.95it/s, loss=0.006]
# test-time optim.:  26% 26/100 [00:04<00:10,  6.95it/s, loss=0.005]
# test-time optim.:  27% 27/100 [00:04<00:10,  6.94it/s, loss=0.005]
# test-time optim.:  27% 27/100 [00:04<00:10,  6.94it/s, loss=0.005]
# test-time optim.:  28% 28/100 [00:04<00:10,  6.94it/s, loss=0.005]
# test-time optim.:  28% 28/100 [00:04<00:10,  6.94it/s, loss=0.005]
# test-time optim.:  29% 29/100 [00:04<00:10,  6.94it/s, loss=0.005]
# test-time optim.:  29% 29/100 [00:04<00:10,  6.94it/s, loss=0.005]
# test-time optim.:  30% 30/100 [00:04<00:10,  6.92it/s, loss=0.005]
# test-time optim.:  30% 30/100 [00:04<00:10,  6.92it/s, loss=0.006]
# test-time optim.:  31% 31/100 [00:04<00:10,  6.90it/s, loss=0.006]
# test-time optim.:  31% 31/100 [00:04<00:10,  6.90it/s, loss=0.005]
# test-time optim.:  32% 32/100 [00:04<00:09,  6.91it/s, loss=0.005]
# test-time optim.:  32% 32/100 [00:05<00:09,  6.91it/s, loss=0.006]
# test-time optim.:  33% 33/100 [00:05<00:09,  6.94it/s, loss=0.006]
# test-time optim.:  33% 33/100 [00:05<00:09,  6.94it/s, loss=0.006]
# test-time optim.:  34% 34/100 [00:05<00:09,  6.97it/s, loss=0.006]
# test-time optim.:  34% 34/100 [00:05<00:09,  6.97it/s, loss=0.005]
# test-time optim.:  35% 35/100 [00:05<00:09,  7.00it/s, loss=0.005]
# test-time optim.:  35% 35/100 [00:05<00:09,  7.00it/s, loss=0.005]
# test-time optim.:  36% 36/100 [00:05<00:09,  7.01it/s, loss=0.005]
# test-time optim.:  36% 36/100 [00:05<00:09,  7.01it/s, loss=0.005]
# test-time optim.:  37% 37/100 [00:05<00:08,  7.01it/s, loss=0.005]
# test-time optim.:  37% 37/100 [00:05<00:08,  7.01it/s, loss=0.005]
# test-time optim.:  38% 38/100 [00:05<00:08,  6.96it/s, loss=0.005]
# test-time optim.:  38% 38/100 [00:05<00:08,  6.96it/s, loss=0.005]
# test-time optim.:  39% 39/100 [00:05<00:08,  6.93it/s, loss=0.005]
# test-time optim.:  39% 39/100 [00:06<00:08,  6.93it/s, loss=0.006]
# test-time optim.:  40% 40/100 [00:06<00:08,  6.89it/s, loss=0.006]
# test-time optim.:  40% 40/100 [00:06<00:08,  6.89it/s, loss=0.004]
# test-time optim.:  41% 41/100 [00:06<00:08,  6.87it/s, loss=0.004]
# test-time optim.:  41% 41/100 [00:06<00:08,  6.87it/s, loss=0.005]
# test-time optim.:  42% 42/100 [00:06<00:08,  6.89it/s, loss=0.005]
# test-time optim.:  42% 42/100 [00:06<00:08,  6.89it/s, loss=0.005]
# test-time optim.:  43% 43/100 [00:06<00:08,  6.92it/s, loss=0.005]
# test-time optim.:  43% 43/100 [00:06<00:08,  6.92it/s, loss=0.005]
# test-time optim.:  44% 44/100 [00:06<00:08,  6.90it/s, loss=0.005]
# test-time optim.:  44% 44/100 [00:06<00:08,  6.90it/s, loss=0.005]
# test-time optim.:  45% 45/100 [00:06<00:07,  6.89it/s, loss=0.005]
# test-time optim.:  45% 45/100 [00:07<00:07,  6.89it/s, loss=0.005]
# test-time optim.:  46% 46/100 [00:07<00:07,  6.88it/s, loss=0.005]
# test-time optim.:  46% 46/100 [00:07<00:07,  6.88it/s, loss=0.005]
# test-time optim.:  47% 47/100 [00:07<00:07,  6.85it/s, loss=0.005]
# test-time optim.:  47% 47/100 [00:07<00:07,  6.85it/s, loss=0.006]
# test-time optim.:  48% 48/100 [00:07<00:07,  6.89it/s, loss=0.006]
# test-time optim.:  48% 48/100 [00:07<00:07,  6.89it/s, loss=0.006]
# test-time optim.:  49% 49/100 [00:07<00:07,  6.91it/s, loss=0.006]
# test-time optim.:  49% 49/100 [00:07<00:07,  6.91it/s, loss=0.006]
# test-time optim.:  50% 50/100 [00:07<00:07,  6.91it/s, loss=0.006]
# test-time optim.:  50% 50/100 [00:07<00:07,  6.91it/s, loss=0.005]
# test-time optim.:  51% 51/100 [00:07<00:07,  6.87it/s, loss=0.005]
# test-time optim.:  51% 51/100 [00:07<00:07,  6.87it/s, loss=0.006]
# test-time optim.:  52% 52/100 [00:07<00:06,  6.88it/s, loss=0.006]
# test-time optim.:  52% 52/100 [00:08<00:06,  6.88it/s, loss=0.005]
# test-time optim.:  53% 53/100 [00:08<00:06,  6.87it/s, loss=0.005]
# test-time optim.:  53% 53/100 [00:08<00:06,  6.87it/s, loss=0.005]
# test-time optim.:  54% 54/100 [00:08<00:06,  6.84it/s, loss=0.005]
# test-time optim.:  54% 54/100 [00:08<00:06,  6.84it/s, loss=0.005]
# test-time optim.:  55% 55/100 [00:08<00:06,  6.86it/s, loss=0.005]
# test-time optim.:  55% 55/100 [00:08<00:06,  6.86it/s, loss=0.005]
# test-time optim.:  56% 56/100 [00:08<00:06,  6.86it/s, loss=0.005]
# test-time optim.:  56% 56/100 [00:08<00:06,  6.86it/s, loss=0.006]
# test-time optim.:  57% 57/100 [00:08<00:06,  6.86it/s, loss=0.006]
# test-time optim.:  57% 57/100 [00:08<00:06,  6.86it/s, loss=0.006]
# test-time optim.:  58% 58/100 [00:08<00:06,  6.81it/s, loss=0.006]
# test-time optim.:  58% 58/100 [00:08<00:06,  6.81it/s, loss=0.005]
# test-time optim.:  59% 59/100 [00:08<00:05,  6.84it/s, loss=0.005]
# test-time optim.:  59% 59/100 [00:09<00:05,  6.84it/s, loss=0.006]
# test-time optim.:  60% 60/100 [00:09<00:05,  6.83it/s, loss=0.006]
# test-time optim.:  60% 60/100 [00:09<00:05,  6.83it/s, loss=0.005]
# test-time optim.:  61% 61/100 [00:09<00:05,  6.78it/s, loss=0.005]
# test-time optim.:  61% 61/100 [00:09<00:05,  6.78it/s, loss=0.004]
# test-time optim.:  62% 62/100 [00:09<00:05,  6.76it/s, loss=0.004]
# test-time optim.:  62% 62/100 [00:09<00:05,  6.76it/s, loss=0.006]
# test-time optim.:  63% 63/100 [00:09<00:05,  6.81it/s, loss=0.006]
# test-time optim.:  63% 63/100 [00:09<00:05,  6.81it/s, loss=0.005]
# test-time optim.:  64% 64/100 [00:09<00:05,  6.83it/s, loss=0.005]
# test-time optim.:  64% 64/100 [00:09<00:05,  6.83it/s, loss=0.005]
# test-time optim.:  65% 65/100 [00:09<00:05,  6.84it/s, loss=0.005]
# test-time optim.:  65% 65/100 [00:09<00:05,  6.84it/s, loss=0.006]
# test-time optim.:  66% 66/100 [00:09<00:04,  6.87it/s, loss=0.006]
# test-time optim.:  66% 66/100 [00:10<00:04,  6.87it/s, loss=0.005]
# test-time optim.:  67% 67/100 [00:10<00:04,  6.82it/s, loss=0.005]
# test-time optim.:  67% 67/100 [00:10<00:04,  6.82it/s, loss=0.006]
# test-time optim.:  68% 68/100 [00:10<00:04,  6.85it/s, loss=0.006]
# test-time optim.:  68% 68/100 [00:10<00:04,  6.85it/s, loss=0.004]
# test-time optim.:  69% 69/100 [00:10<00:04,  6.90it/s, loss=0.004]
# test-time optim.:  69% 69/100 [00:10<00:04,  6.90it/s, loss=0.005]
# test-time optim.:  70% 70/100 [00:10<00:04,  6.89it/s, loss=0.005]
# test-time optim.:  70% 70/100 [00:10<00:04,  6.89it/s, loss=0.005]
# test-time optim.:  71% 71/100 [00:10<00:04,  6.89it/s, loss=0.005]
# test-time optim.:  71% 71/100 [00:10<00:04,  6.89it/s, loss=0.005]
# test-time optim.:  72% 72/100 [00:10<00:04,  6.89it/s, loss=0.005]
# test-time optim.:  72% 72/100 [00:10<00:04,  6.89it/s, loss=0.006]
# test-time optim.:  73% 73/100 [00:10<00:03,  6.83it/s, loss=0.006]
# test-time optim.:  73% 73/100 [00:11<00:03,  6.83it/s, loss=0.006]
# test-time optim.:  74% 74/100 [00:11<00:03,  6.83it/s, loss=0.006]

# %%
# ==========================================
# EXPÉRIMENTATION OPTIMISÉE : BARF LEGO
# ==========================================

print("="*70)
print("🧪 EXPÉRIMENTATION BARF LEGO - VERSION OPTIMISÉE V2")
print("="*70)

import os
import json
import shutil
import yaml
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from mpl_toolkits.mplot3d import Axes3D
import subprocess
import sys
import time
import threading
from datetime import datetime

# Variable de contrôle pour l'interruption
TRAINING_INTERRUPTED = False

# ==========================================
# INSTALLATION DES DÉPENDANCES
# ==========================================
print("\n[Installation] 📦 VÉRIFICATION DES DÉPENDANCES")
print("-"*70)

try:
    import ipdb
    print("✅ ipdb déjà installé")
except ImportError:
    print("⚙️ Installation de ipdb...")
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "ipdb"])
    print("✅ ipdb installé")

missing_packages = []
try:
    import tensorboard
except ImportError:
    missing_packages.append("tensorboard")

try:
    import visdom
except ImportError:
    missing_packages.append("visdom")

if missing_packages:
    print(f"⚙️ Installation de packages supplémentaires: {', '.join(missing_packages)}")
    for pkg in missing_packages:
        subprocess.run([sys.executable, "-m", "pip", "install", "-q", pkg])
    print("✅ Tous les packages installés")

# ==========================================
# CONFIGURATION GOOGLE DRIVE
# ==========================================
print("\n[Configuration] 📁 GOOGLE DRIVE")
print("-"*70)

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

DRIVE_ROOT = '/content/drive/MyDrive/projet_nerf_barf'
DRIVE_CHECKPOINTS = os.path.join(DRIVE_ROOT, 'checkpoints_v2')  # Nouveau dossier pour v2
DRIVE_RESULTS = os.path.join(DRIVE_ROOT, 'results_v2')
DRIVE_LOGS = os.path.join(DRIVE_ROOT, 'logs_v2')

os.makedirs(DRIVE_CHECKPOINTS, exist_ok=True)
os.makedirs(DRIVE_RESULTS, exist_ok=True)
os.makedirs(DRIVE_LOGS, exist_ok=True)

print(f"✅ Dossiers Google Drive créés (version optimisée v2):")
print(f"   Checkpoints : {DRIVE_CHECKPOINTS}")
print(f"   Résultats   : {DRIVE_RESULTS}")
print(f"   Logs        : {DRIVE_LOGS}")

BARF_PATH = '/content/barf_workspace/bundle-adjusting-NeRF'
os.chdir(BARF_PATH)

DATASET_ROOT = '/content/data/nerf_synthetic'
SCENE = 'lego'
SCENE_PATH = os.path.join(DATASET_ROOT, SCENE)

if not os.path.exists(SCENE_PATH):
    print(f"❌ Dataset non trouvé : {SCENE_PATH}")
    raise FileNotFoundError(f"Dataset non trouvé : {SCENE_PATH}")

print(f"✅ Dataset trouvé : {SCENE_PATH}")

# ==========================================
# FONCTIONS UTILITAIRES
# ==========================================

def save_checkpoint_to_drive(checkpoint_path, iteration=None):
    """Sauvegarde un checkpoint vers Google Drive"""
    if os.path.exists(checkpoint_path):
        if iteration:
            filename = f"{iteration}.ckpt"  # Format simple : 20000.ckpt
        else:
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            filename = f"checkpoint_latest_{timestamp}.ckpt"

        dest_path = os.path.join(DRIVE_CHECKPOINTS, filename)

        try:
            shutil.copy2(checkpoint_path, dest_path)
            print(f"✅ Checkpoint sauvegardé : {filename}")
            return dest_path
        except Exception as e:
            print(f"⚠️ Erreur lors de la sauvegarde du checkpoint : {e}")
            return None
    else:
        print(f"⚠️ Checkpoint non trouvé : {checkpoint_path}")
        return None

def create_training_log(message, log_type="INFO"):
    """Crée un log d'entraînement"""
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    log_file = os.path.join(DRIVE_LOGS, "training_log.txt")

    with open(log_file, 'a') as f:
        f.write(f"[{timestamp}] [{log_type}] {message}\n")

def monitor_checkpoints(checkpoint_dir, stop_event, checkpoint_interval=2500):
    """Thread qui surveille et sauvegarde automatiquement les checkpoints"""
    checkpoint_path = os.path.join(checkpoint_dir, 'latest.ckpt')
    last_mtime = 0
    last_saved_iteration = 0

    print(f"🔍 Surveillance des checkpoints activée (intervalle: {checkpoint_interval} it)")

    while not stop_event.is_set():
        try:
            if os.path.exists(checkpoint_path):
                current_mtime = os.path.getmtime(checkpoint_path)

                if current_mtime > last_mtime:
                    last_mtime = current_mtime

                    try:
                        import torch
                        checkpoint_data = torch.load(checkpoint_path, map_location='cpu')
                        current_iter = checkpoint_data.get('iter', 0)

                        if current_iter // checkpoint_interval > last_saved_iteration // checkpoint_interval:
                            print(f"\n💾 Sauvegarde automatique du checkpoint (iter {current_iter})...")
                            save_checkpoint_to_drive(checkpoint_path, current_iter)
                            create_training_log(f"Checkpoint auto-sauvegardé - Iteration {current_iter}", "CHECKPOINT")
                            last_saved_iteration = current_iter
                    except Exception as e:
                        print(f"⚠️ Erreur lors de la lecture du checkpoint : {e}")

        except Exception as e:
            print(f"⚠️ Erreur dans le monitoring : {e}")

        time.sleep(30)

# ==========================================
# ÉTAPE 1 : Analyse du Dataset
# ==========================================
print("\n[Étape 1/7] 📊 ANALYSE DU DATASET")
print("-"*70)

with open(os.path.join(SCENE_PATH, 'transforms_train.json'), 'r') as f:
    train_data = json.load(f)

num_train = len(train_data['frames'])
camera_angle_x = train_data.get('camera_angle_x', 0.6911)

print(f"📐 Configuration :")
print(f"   Images train : {num_train}")
print(f"   FOV caméra   : {camera_angle_x:.4f} rad")

poses_gt = np.array([np.array(f['transform_matrix']) for f in train_data['frames']])
positions_gt = poses_gt[:, :3, 3]

print(f"\n📍 Poses ground truth :")
print(f"   Étendue X : [{positions_gt[:, 0].min():.3f}, {positions_gt[:, 0].max():.3f}]")
print(f"   Étendue Y : [{positions_gt[:, 1].min():.3f}, {positions_gt[:, 1].max():.3f}]")
print(f"   Étendue Z : [{positions_gt[:, 2].min():.3f}, {positions_gt[:, 2].max():.3f}]")

create_training_log("Analyse du dataset terminée")

# ==========================================
# ÉTAPE 2 : Configuration Optimisée YAML
# ==========================================
print("\n[Étape 2/7] ⚙️ CRÉATION CONFIGURATION OPTIMISÉE")
print("-"*70)

# Créer une nouvelle configuration optimisée
yaml_path_original = 'options/barf_blender.yaml'
yaml_path_optimized = 'options/barf_blender_v2_optimized.yaml'

with open(yaml_path_original, 'r') as f:
    config_yaml = yaml.safe_load(f)

# ✅ CORRECTIONS CRITIQUES
config_yaml['barf_c2f'] = [0.1, 0.3]  # Plus progressif (au lieu de [0.1, 0.5])
config_yaml['optim']['lr'] = 0.0001  # LR plus stable (au lieu de 0.0005)
config_yaml['optim']['lr_end'] = 0.00005  # Decay plus doux
config_yaml['optim']['lr_pose'] = 0.0005  # LR pose réduit (au lieu de 0.001)
config_yaml['optim']['lr_pose_end'] = 0.00001  # Decay pose plus doux
config_yaml['visdom'] = False

with open(yaml_path_optimized, 'w') as f:
    yaml.dump(config_yaml, f, default_flow_style=False)

print("✅ Configuration optimisée créée :")
print(f"   barf_c2f : [0.1, 0.3] (plus progressif)")
print(f"   optim.lr : 0.0001 (plus stable)")
print(f"   optim.lr_pose : 0.0005 (réduit)")
print(f"   Fichier : {yaml_path_optimized}")

create_training_log("Configuration optimisée créée", "CONFIG")

# ==========================================
# ÉTAPE 3 : Configuration Entraînement
# ==========================================
print("\n[Étape 3/7] 📋 CONFIGURATION ENTRAÎNEMENT")
print("-"*70)

# ✅ PARAMÈTRES OPTIMISÉS
MAX_ITER = 50000  # Plus court pour tester (au lieu de 100k)
CHECKPOINT_FREQ = 2500  # Checkpoints plus fréquents

config = {
    'group': 'barf_lego_v2',
    'max_iter': MAX_ITER,
    'batch_size': 4096,
    'checkpoint_freq': CHECKPOINT_FREQ,
}

print(f"📊 Configuration optimisée v2 :")
print(f"   Max iterations : {MAX_ITER:,} (test rapide)")
print(f"   Batch size     : {config['batch_size']}")
print(f"   Checkpoint tous les : {CHECKPOINT_FREQ:,} itérations")
print(f"   ⏱️ Temps estimé : ~15-20 minutes sur GPU T4")

num_checkpoints = MAX_ITER // CHECKPOINT_FREQ
print(f"   💾 Checkpoints attendus : ~{num_checkpoints}")

# ==========================================
# ÉTAPE 4 : Entraînement Optimisé
# ==========================================
print("\n[Étape 4/7] 🚀 ENTRAÎNEMENT OPTIMISÉ")
print("="*70)

cmd = [
    "python", "train.py",
    "--group=barf_lego_v2",
    "--model=barf",
    "--yaml=barf_blender_v2_optimized",  # ✅ Utiliser la config optimisée
    "--data.scene=lego",
    f"--data.root={DATASET_ROOT}",
    f"--max_iter={MAX_ITER}",
    "--batch_size=4096",
    "--freq.scalar=200",
    "--freq.vis=2000",
    "--freq.val=5000",
    f"--freq.ckpt={CHECKPOINT_FREQ}",
    "--data.num_workers=2"
]

print("🔧 Lancement de l'entraînement OPTIMISÉ v2...")
print("🆕 Mode : NOUVEL entraînement avec paramètres corrigés")
print("="*70 + "\n")

stop_monitoring = threading.Event()
checkpoint_dir = 'output/barf_lego_v2/debug'
monitor_thread = threading.Thread(
    target=monitor_checkpoints,
    args=(checkpoint_dir, stop_monitoring, CHECKPOINT_FREQ),
    daemon=True
)
monitor_thread.start()

process = None

try:
    process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT,
                              text=True, bufsize=1)

    for line in process.stdout:
        print(line, end='')

    process.wait()

    stop_monitoring.set()
    monitor_thread.join(timeout=5)

    print("\n💾 Sauvegarde finale du checkpoint...")
    final_checkpoint = os.path.join(checkpoint_dir, 'latest.ckpt')
    save_checkpoint_to_drive(final_checkpoint)

    if process.returncode == 0:
        print("\n" + "="*70)
        print("✅ ENTRAÎNEMENT OPTIMISÉ TERMINÉ AVEC SUCCÈS")
        print("="*70)
        create_training_log("Entraînement optimisé v2 terminé avec succès", "SUCCESS")
    else:
        print(f"\n⚠️ Code retour : {process.returncode}")
        create_training_log(f"Entraînement terminé avec code {process.returncode}", "WARNING")

except KeyboardInterrupt:
    print("\n" + "="*70)
    print("⚠️ ENTRAÎNEMENT INTERROMPU PAR L'UTILISATEUR")
    print("="*70)
    print("💾 Sauvegarde du checkpoint en cours...")

    TRAINING_INTERRUPTED = True
    stop_monitoring.set()

    if process is not None:
        try:
            process.terminate()
            process.wait(timeout=10)
        except:
            try:
                process.kill()
            except:
                pass

    current_checkpoint = os.path.join(checkpoint_dir, 'latest.ckpt')
    if os.path.exists(current_checkpoint):
        save_checkpoint_to_drive(current_checkpoint)
        print("✅ Checkpoint d'interruption sauvegardé")
        create_training_log("Entraînement interrompu - Checkpoint sauvegardé", "INTERRUPT")
    else:
        print("⚠️ Aucun checkpoint trouvé à sauvegarder")

    print("\n💡 Pour reprendre l'entraînement, relancez ce script !")
    print("="*70)

except Exception as e:
    print(f"\n❌ Erreur : {e}")
    TRAINING_INTERRUPTED = True
    stop_monitoring.set()
    create_training_log(f"Erreur : {e}", "ERROR")

# ==========================================
# ÉTAPE 5 : Évaluation
# ==========================================
if not TRAINING_INTERRUPTED:
    print("\n[Étape 5/7] 📈 ÉVALUATION AUTOMATIQUE")
    print("-"*70)

    # Évaluer tous les checkpoints sauvegardés
    checkpoints_to_eval = [2500, 5000, 7500, 10000, 15000, 20000, 25000, 30000, 40000, 50000]

    results_summary = []

    for ckpt_iter in checkpoints_to_eval:
        ckpt_path = os.path.join(DRIVE_CHECKPOINTS, f"{ckpt_iter}.ckpt")

        if os.path.exists(ckpt_path):
            print(f"\n🧪 Évaluation checkpoint {ckpt_iter}...")

            eval_cmd = [
                "python", "evaluate.py",
                "--group=barf_lego_v2",
                "--model=barf",
                "--yaml=barf_blender_v2_optimized",
                "--data.scene=lego",
                f"--data.root={DATASET_ROOT}",
                f"--load={ckpt_path}"
            ]

            result = subprocess.run(eval_cmd, capture_output=True, text=True)

            # Extraire les métriques
            import re
            output = result.stdout + result.stderr

            psnr = ssim = lpips = "N/A"
            for line in output.split('\n'):
                if 'PSNR:' in line:
                    match = re.search(r'PSNR:\s+([\d.]+)', line)
                    if match:
                        psnr = float(match.group(1))
                if 'SSIM:' in line:
                    match = re.search(r'SSIM:\s+([\d.]+)', line)
                    if match:
                        ssim = float(match.group(1))
                if 'LPIPS:' in line:
                    match = re.search(r'LPIPS:\s+([\d.]+)', line)
                    if match:
                        lpips = float(match.group(1))

            results_summary.append({
                'iteration': ckpt_iter,
                'psnr': psnr,
                'ssim': ssim,
                'lpips': lpips
            })

            print(f"   PSNR: {psnr}, SSIM: {ssim}, LPIPS: {lpips}")

    # ==========================================
    # ÉTAPE 6 : Comparaison avec v1
    # ==========================================
    print("\n[Étape 6/7] 📊 COMPARAISON V1 vs V2")
    print("-"*70)

    print("\nRÉSULTATS COMPARATIFS :")
    print(f"{'Iteration':<12} {'PSNR':<10} {'SSIM':<10} {'LPIPS':<10}")
    print("-"*50)
    print(f"V1 (20k)     21.81      0.80       0.23       (BASELINE)")
    print("-"*50)
    for res in results_summary:
        if res['psnr'] != "N/A":
            print(f"V2 ({res['iteration']:<5})    {res['psnr']:<10.2f} {res['ssim']:<10.4f} {res['lpips']:<10.4f}")

    # Trouver le meilleur checkpoint v2
    valid_results = [r for r in results_summary if r['psnr'] != "N/A"]
    if valid_results:
        best_v2 = max(valid_results, key=lambda x: x['psnr'])
        print(f"\n🏆 Meilleur V2: Iteration {best_v2['iteration']} (PSNR: {best_v2['psnr']:.2f})")

        if best_v2['psnr'] > 21.81:
            print(f"   ✅ AMÉLIORATION de {best_v2['psnr'] - 21.81:.2f} dB par rapport à V1 !")
        else:
            print(f"   ℹ️ V1 reste meilleur (différence: {21.81 - best_v2['psnr']:.2f} dB)")

    # ==========================================
    # ÉTAPE 7 : Sauvegarde Finale
    # ==========================================
    print("\n[Étape 7/7] 💾 SAUVEGARDE FINALE")
    print("-"*70)

    comparison_file = os.path.join(DRIVE_RESULTS, "comparison_v1_v2.txt")
    with open(comparison_file, 'w') as f:
        f.write("="*70 + "\n")
        f.write("COMPARAISON V1 (BASELINE) vs V2 (OPTIMISÉ)\n")
        f.write("="*70 + "\n\n")
        f.write(f"Date : {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n\n")

        f.write("V1 BASELINE (checkpoint 20000):\n")
        f.write("  PSNR:  21.81 dB\n")
        f.write("  SSIM:  0.80\n")
        f.write("  LPIPS: 0.23\n\n")

        f.write("V2 OPTIMISÉ:\n")
        f.write("  Modifications:\n")
        f.write("    - barf_c2f: [0.1, 0.3] (plus progressif)\n")
        f.write("    - optim.lr: 0.0001 (réduit)\n")
        f.write("    - optim.lr_pose: 0.0005 (réduit)\n\n")

        f.write(f"{'Iteration':<12} {'PSNR':<10} {'SSIM':<10} {'LPIPS':<10}\n")
        f.write("-"*50 + "\n")
        for res in results_summary:
            if res['psnr'] != "N/A":
                f.write(f"{res['iteration']:<12} {res['psnr']:<10.2f} {res['ssim']:<10.4f} {res['lpips']:<10.4f}\n")

        if valid_results:
            f.write(f"\nMEILLEUR V2: Iteration {best_v2['iteration']} (PSNR: {best_v2['psnr']:.2f})\n")

    print(f"✅ Rapport de comparaison créé : comparison_v1_v2.txt")

    print("\n" + "="*70)
    print("🎉 EXPÉRIMENTATION OPTIMISÉE TERMINÉE")
    print("="*70)
    print(f"\n📁 FICHIERS SAUVEGARDÉS :")
    print(f"   Checkpoints V2 : {DRIVE_CHECKPOINTS}")
    print(f"   Résultats V2   : {DRIVE_RESULTS}")
    print(f"   Logs V2        : {DRIVE_LOGS}")
    print("\n💡 Consultez comparison_v1_v2.txt pour voir les améliorations !")
    print("="*70)

    create_training_log("Expérimentation optimisée v2 terminée", "COMPLETE")
# Out:
# Streaming output truncated to the last 5000 lines.
# training:  20%|██        | 10055/50000 [48:20<3:07:17,  3.55it/s, it=10055, loss=0.010]
# training:  20%|██        | 10055/50000 [48:20<3:07:17,  3.55it/s, it=10056, loss=0.006]
# training:  20%|██        | 10056/50000 [48:20<3:07:24,  3.55it/s, it=10056, loss=0.006]
# training:  20%|██        | 10056/50000 [48:20<3:07:24,  3.55it/s, it=10057, loss=0.008]
# training:  20%|██        | 10057/50000 [48:20<3:07:40,  3.55it/s, it=10057, loss=0.008]
# training:  20%|██        | 10057/50000 [48:21<3:07:40,  3.55it/s, it=10058, loss=0.008]
# training:  20%|██        | 10058/50000 [48:21<3:07:47,  3.54it/s, it=10058, loss=0.008]
# training:  20%|██        | 10058/50000 [48:21<3:07:47,  3.54it/s, it=10059, loss=0.006]
# training:  20%|██        | 10059/50000 [48:21<3:07:55,  3.54it/s, it=10059, loss=0.006]
# training:  20%|██        | 10059/50000 [48:21<3:07:55,  3.54it/s, it=10060, loss=0.006]
# training:  20%|██        | 10060/50000 [48:21<3:07:27,  3.55it/s, it=10060, loss=0.006]
# training:  20%|██        | 10060/50000 [48:21<3:07:27,  3.55it/s, it=10061, loss=0.007]
# training:  20%|██        | 10061/50000 [48:21<3:07:05,  3.56it/s, it=10061, loss=0.007]
# training:  20%|██        | 10061/50000 [48:22<3:07:05,  3.56it/s, it=10062, loss=0.008]
# training:  20%|██        | 10062/50000 [48:22<3:07:13,  3.56it/s, it=10062, loss=0.008]
# training:  20%|██        | 10062/50000 [48:22<3:07:13,  3.56it/s, it=10063, loss=0.006]
# training:  20%|██        | 10063/50000 [48:22<3:07:27,  3.55it/s, it=10063, loss=0.006]
# training:  20%|██        | 10063/50000 [48:22<3:07:27,  3.55it/s, it=10064, loss=0.006]
# training:  20%|██        | 10064/50000 [48:22<3:07:10,  3.56it/s, it=10064, loss=0.006]
# training:  20%|██        | 10064/50000 [48:23<3:07:10,  3.56it/s, it=10065, loss=0.016]
# training:  20%|██        | 10065/50000 [48:23<3:07:53,  3.54it/s, it=10065, loss=0.016]
# training:  20%|██        | 10065/50000 [48:23<3:07:53,  3.54it/s, it=10066, loss=0.012]
# training:  20%|██        | 10066/50000 [48:23<3:08:01,  3.54it/s, it=10066, loss=0.012]
# training:  20%|██        | 10066/50000 [48:23<3:08:01,  3.54it/s, it=10067, loss=0.009]
# training:  20%|██        | 10067/50000 [48:23<3:08:08,  3.54it/s, it=10067, loss=0.009]
# training:  20%|██        | 10067/50000 [48:23<3:08:08,  3.54it/s, it=10068, loss=0.004]
# training:  20%|██        | 10068/50000 [48:23<3:08:02,  3.54it/s, it=10068, loss=0.004]
# training:  20%|██        | 10068/50000 [48:24<3:08:02,  3.54it/s, it=10069, loss=0.009]
# training:  20%|██        | 10069/50000 [48:24<3:08:09,  3.54it/s, it=10069, loss=0.009]
# training:  20%|██        | 10069/50000 [48:24<3:08:09,  3.54it/s, it=10070, loss=0.009]
# training:  20%|██        | 10070/50000 [48:24<3:08:21,  3.53it/s, it=10070, loss=0.009]
# training:  20%|██        | 10070/50000 [48:24<3:08:21,  3.53it/s, it=10071, loss=0.009]
# training:  20%|██        | 10071/50000 [48:24<3:08:28,  3.53it/s, it=10071, loss=0.009]
# training:  20%|██        | 10071/50000 [48:25<3:08:28,  3.53it/s, it=10072, loss=0.003]
# training:  20%|██        | 10072/50000 [48:25<3:08:28,  3.53it/s, it=10072, loss=0.003]
# training:  20%|██        | 10072/50000 [48:25<3:08:28,  3.53it/s, it=10073, loss=0.006]
# training:  20%|██        | 10073/50000 [48:25<3:08:45,  3.53it/s, it=10073, loss=0.006]
# training:  20%|██        | 10073/50000 [48:25<3:08:45,  3.53it/s, it=10074, loss=0.004]
# training:  20%|██        | 10074/50000 [48:25<3:08:37,  3.53it/s, it=10074, loss=0.004]
# training:  20%|██        | 10074/50000 [48:25<3:08:37,  3.53it/s, it=10075, loss=0.007]
# training:  20%|██        | 10075/50000 [48:25<3:08:39,  3.53it/s, it=10075, loss=0.007]
# training:  20%|██        | 10075/50000 [48:26<3:08:39,  3.53it/s, it=10076, loss=0.004]
# training:  20%|██        | 10076/50000 [48:26<3:08:07,  3.54it/s, it=10076, loss=0.004]
# training:  20%|██        | 10076/50000 [48:26<3:08:07,  3.54it/s, it=10077, loss=0.012]
# training:  20%|██        | 10077/50000 [48:26<3:08:02,  3.54it/s, it=10077, loss=0.012]
# training:  20%|██        | 10077/50000 [48:26<3:08:02,  3.54it/s, it=10078, loss=0.012]
# training:  20%|██        | 10078/50000 [48:26<3:07:37,  3.55it/s, it=10078, loss=0.012]
# training:  20%|██        | 10078/50000 [48:27<3:07:37,  3.55it/s, it=10079, loss=0.005]
# training:  20%|██        | 10079/50000 [48:27<3:07:10,  3.55it/s, it=10079, loss=0.005]
# training:  20%|██        | 10079/50000 [48:27<3:07:10,  3.55it/s, it=10080, loss=0.004]
# training:  20%|██        | 10080/50000 [48:27<3:07:08,  3.56it/s, it=10080, loss=0.004]
# training:  20%|██        | 10080/50000 [48:27<3:07:08,  3.56it/s, it=10081, loss=0.004]
# training:  20%|██        | 10081/50000 [48:27<3:06:59,  3.56it/s, it=10081, loss=0.004]
# training:  20%|██        | 10081/50000 [48:27<3:06:59,  3.56it/s, it=10082, loss=0.014]
# training:  20%|██        | 10082/50000 [48:27<3:06:53,  3.56it/s, it=10082, loss=0.014]
# training:  20%|██        | 10082/50000 [48:28<3:06:53,  3.56it/s, it=10083, loss=0.008]
# training:  20%|██        | 10083/50000 [48:28<3:07:08,  3.56it/s, it=10083, loss=0.008]
# training:  20%|██        | 10083/50000 [48:28<3:07:08,  3.56it/s, it=10084, loss=0.003]
# training:  20%|██        | 10084/50000 [48:28<3:07:12,  3.55it/s, it=10084, loss=0.003]
# training:  20%|██        | 10084/50000 [48:28<3:07:12,  3.55it/s, it=10085, loss=0.007]
# training:  20%|██        | 10085/50000 [48:28<3:07:32,  3.55it/s, it=10085, loss=0.007]
# training:  20%|██        | 10085/50000 [48:29<3:07:32,  3.55it/s, it=10086, loss=0.001]
# training:  20%|██        | 10086/50000 [48:29<3:07:09,  3.55it/s, it=10086, loss=0.001]
# training:  20%|██        | 10086/50000 [48:29<3:07:09,  3.55it/s, it=10087, loss=0.010]
# training:  20%|██        | 10087/50000 [48:29<3:06:39,  3.56it/s, it=10087, loss=0.010]
# training:  20%|██        | 10087/50000 [48:29<3:06:39,  3.56it/s, it=10088, loss=0.011]
# training:  20%|██        | 10088/50000 [48:29<3:06:37,  3.56it/s, it=10088, loss=0.011]
# training:  20%|██        | 10088/50000 [48:29<3:06:37,  3.56it/s, it=10089, loss=0.005]
# training:  20%|██        | 10089/50000 [48:29<3:06:56,  3.56it/s, it=10089, loss=0.005]
# training:  20%|██        | 10089/50000 [48:30<3:06:56,  3.56it/s, it=10090, loss=0.006]
# training:  20%|██        | 10090/50000 [48:30<3:06:52,  3.56it/s, it=10090, loss=0.006]
# training:  20%|██        | 10090/50000 [48:30<3:06:52,  3.56it/s, it=10091, loss=0.009]
# training:  20%|██        | 10091/50000 [48:30<3:06:58,  3.56it/s, it=10091, loss=0.009]
# training:  20%|██        | 10091/50000 [48:30<3:06:58,  3.56it/s, it=10092, loss=0.009]
# training:  20%|██        | 10092/50000 [48:30<3:06:59,  3.56it/s, it=10092, loss=0.009]
# training:  20%|██        | 10092/50000 [48:30<3:06:59,  3.56it/s, it=10093, loss=0.003]
# training:  20%|██        | 10093/50000 [48:30<3:07:16,  3.55it/s, it=10093, loss=0.003]
# training:  20%|██        | 10093/50000 [48:31<3:07:16,  3.55it/s, it=10094, loss=0.010]
# training:  20%|██        | 10094/50000 [48:31<3:07:02,  3.56it/s, it=10094, loss=0.010]
# training:  20%|██        | 10094/50000 [48:31<3:07:02,  3.56it/s, it=10095, loss=0.008]
# training:  20%|██        | 10095/50000 [48:31<3:06:41,  3.56it/s, it=10095, loss=0.008]
# training:  20%|██        | 10095/50000 [48:31<3:06:41,  3.56it/s, it=10096, loss=0.006]
# training:  20%|██        | 10096/50000 [48:31<3:06:32,  3.57it/s, it=10096, loss=0.006]
# training:  20%|██        | 10096/50000 [48:32<3:06:32,  3.57it/s, it=10097, loss=0.011]
# training:  20%|██        | 10097/50000 [48:32<3:06:15,  3.57it/s, it=10097, loss=0.011]
# training:  20%|██        | 10097/50000 [48:32<3:06:15,  3.57it/s, it=10098, loss=0.011]
# training:  20%|██        | 10098/50000 [48:32<3:06:32,  3.56it/s, it=10098, loss=0.011]
# training:  20%|██        | 10098/50000 [48:32<3:06:32,  3.56it/s, it=10099, loss=0.013]
# training:  20%|██        | 10099/50000 [48:32<3:06:46,  3.56it/s, it=10099, loss=0.013]
# training:  20%|██        | 10099/50000 [48:32<3:06:46,  3.56it/s, it=10100, loss=0.005]
# training:  20%|██        | 10100/50000 [48:32<3:07:10,  3.55it/s, it=10100, loss=0.005]
# training:  20%|██        | 10100/50000 [48:33<3:07:10,  3.55it/s, it=10101, loss=0.005]
# training:  20%|██        | 10101/50000 [48:33<3:07:24,  3.55it/s, it=10101, loss=0.005]
# training:  20%|██        | 10101/50000 [48:33<3:07:24,  3.55it/s, it=10102, loss=0.006]
# training:  20%|██        | 10102/50000 [48:33<3:06:57,  3.56it/s, it=10102, loss=0.006]
# training:  20%|██        | 10102/50000 [48:33<3:06:57,  3.56it/s, it=10103, loss=0.011]
# training:  20%|██        | 10103/50000 [48:33<3:06:31,  3.57it/s, it=10103, loss=0.011]
# training:  20%|██        | 10103/50000 [48:34<3:06:31,  3.57it/s, it=10104, loss=0.012]
# training:  20%|██        | 10104/50000 [48:34<3:06:41,  3.56it/s, it=10104, loss=0.012]
# training:  20%|██        | 10104/50000 [48:34<3:06:41,  3.56it/s, it=10105, loss=0.007]
# training:  20%|██        | 10105/50000 [48:34<3:06:33,  3.56it/s, it=10105, loss=0.007]
# training:  20%|██        | 10105/50000 [48:34<3:06:33,  3.56it/s, it=10106, loss=0.007]
# training:  20%|██        | 10106/50000 [48:34<3:06:35,  3.56it/s, it=10106, loss=0.007]
# training:  20%|██        | 10106/50000 [48:34<3:06:35,  3.56it/s, it=10107, loss=0.006]
# training:  20%|██        | 10107/50000 [48:34<3:06:39,  3.56it/s, it=10107, loss=0.006]
# training:  20%|██        | 10107/50000 [48:35<3:06:39,  3.56it/s, it=10108, loss=0.003]
# training:  20%|██        | 10108/50000 [48:35<3:06:41,  3.56it/s, it=10108, loss=0.003]
# training:  20%|██        | 10108/50000 [48:35<3:06:41,  3.56it/s, it=10109, loss=0.009]
# training:  20%|██        | 10109/50000 [48:35<3:06:31,  3.56it/s, it=10109, loss=0.009]
# training:  20%|██        | 10109/50000 [48:35<3:06:31,  3.56it/s, it=10110, loss=0.015]
# training:  20%|██        | 10110/50000 [48:35<3:06:28,  3.57it/s, it=10110, loss=0.015]
# training:  20%|██        | 10110/50000 [48:36<3:06:28,  3.57it/s, it=10111, loss=0.007]
# training:  20%|██        | 10111/50000 [48:36<3:06:45,  3.56it/s, it=10111, loss=0.007]
# training:  20%|██        | 10111/50000 [48:36<3:06:45,  3.56it/s, it=10112, loss=0.008]
# training:  20%|██        | 10112/50000 [48:36<3:07:14,  3.55it/s, it=10112, loss=0.008]
# training:  20%|██        | 10112/50000 [48:36<3:07:14,  3.55it/s, it=10113, loss=0.005]
# training:  20%|██        | 10113/50000 [48:36<3:07:09,  3.55it/s, it=10113, loss=0.005]
# training:  20%|██        | 10113/50000 [48:36<3:07:09,  3.55it/s, it=10114, loss=0.008]
# training:  20%|██        | 10114/50000 [48:36<3:07:10,  3.55it/s, it=10114, loss=0.008]
# training:  20%|██        | 10114/50000 [48:37<3:07:10,  3.55it/s, it=10115, loss=0.009]
# training:  20%|██        | 10115/50000 [48:37<3:07:19,  3.55it/s, it=10115, loss=0.009]
# training:  20%|██        | 10115/50000 [48:37<3:07:19,  3.55it/s, it=10116, loss=0.007]
# training:  20%|██        | 10116/50000 [48:37<3:07:52,  3.54it/s, it=10116, loss=0.007]
# training:  20%|██        | 10116/50000 [48:37<3:07:52,  3.54it/s, it=10117, loss=0.016]
# training:  20%|██        | 10117/50000 [48:37<3:08:08,  3.53it/s, it=10117, loss=0.016]
# training:  20%|██        | 10117/50000 [48:38<3:08:08,  3.53it/s, it=10118, loss=0.006]
# training:  20%|██        | 10118/50000 [48:38<3:07:51,  3.54it/s, it=10118, loss=0.006]
# training:  20%|██        | 10118/50000 [48:38<3:07:51,  3.54it/s, it=10119, loss=0.008]
# training:  20%|██        | 10119/50000 [48:38<3:08:22,  3.53it/s, it=10119, loss=0.008]
# training:  20%|██        | 10119/50000 [48:38<3:08:22,  3.53it/s, it=10120, loss=0.006]
# training:  20%|██        | 10120/50000 [48:38<3:08:25,  3.53it/s, it=10120, loss=0.006]
# training:  20%|██        | 10120/50000 [48:38<3:08:25,  3.53it/s, it=10121, loss=0.007]
# training:  20%|██        | 10121/50000 [48:38<3:08:25,  3.53it/s, it=10121, loss=0.007]
# training:  20%|██        | 10121/50000 [48:39<3:08:25,  3.53it/s, it=10122, loss=0.010]
# training:  20%|██        | 10122/50000 [48:39<3:08:21,  3.53it/s, it=10122, loss=0.010]
# training:  20%|██        | 10122/50000 [48:39<3:08:21,  3.53it/s, it=10123, loss=0.005]
# training:  20%|██        | 10123/50000 [48:39<3:07:45,  3.54it/s, it=10123, loss=0.005]
# training:  20%|██        | 10123/50000 [48:39<3:07:45,  3.54it/s, it=10124, loss=0.006]
# training:  20%|██        | 10124/50000 [48:39<3:07:52,  3.54it/s, it=10124, loss=0.006]
# training:  20%|██        | 10124/50000 [48:40<3:07:52,  3.54it/s, it=10125, loss=0.007]
# training:  20%|██        | 10125/50000 [48:40<3:08:05,  3.53it/s, it=10125, loss=0.007]
# training:  20%|██        | 10125/50000 [48:40<3:08:05,  3.53it/s, it=10126, loss=0.011]
# training:  20%|██        | 10126/50000 [48:40<3:08:07,  3.53it/s, it=10126, loss=0.011]
# training:  20%|██        | 10126/50000 [48:40<3:08:07,  3.53it/s, it=10127, loss=0.009]
# training:  20%|██        | 10127/50000 [48:40<3:08:16,  3.53it/s, it=10127, loss=0.009]
# training:  20%|██        | 10127/50000 [48:40<3:08:16,  3.53it/s, it=10128, loss=0.003]
# training:  20%|██        | 10128/50000 [48:40<3:07:42,  3.54it/s, it=10128, loss=0.003]
# training:  20%|██        | 10128/50000 [48:41<3:07:42,  3.54it/s, it=10129, loss=0.016]
# training:  20%|██        | 10129/50000 [48:41<3:07:19,  3.55it/s, it=10129, loss=0.016]
# training:  20%|██        | 10129/50000 [48:41<3:07:19,  3.55it/s, it=10130, loss=0.004]
# training:  20%|██        | 10130/50000 [48:41<3:06:54,  3.56it/s, it=10130, loss=0.004]
# training:  20%|██        | 10130/50000 [48:41<3:06:54,  3.56it/s, it=10131, loss=0.016]
# training:  20%|██        | 10131/50000 [48:41<3:06:58,  3.55it/s, it=10131, loss=0.016]
# training:  20%|██        | 10131/50000 [48:41<3:06:58,  3.55it/s, it=10132, loss=0.009]
# training:  20%|██        | 10132/50000 [48:41<3:06:46,  3.56it/s, it=10132, loss=0.009]
# training:  20%|██        | 10132/50000 [48:42<3:06:46,  3.56it/s, it=10133, loss=0.006]
# training:  20%|██        | 10133/50000 [48:42<3:06:32,  3.56it/s, it=10133, loss=0.006]
# training:  20%|██        | 10133/50000 [48:42<3:06:32,  3.56it/s, it=10134, loss=0.006]
# training:  20%|██        | 10134/50000 [48:42<3:06:48,  3.56it/s, it=10134, loss=0.006]
# training:  20%|██        | 10134/50000 [48:42<3:06:48,  3.56it/s, it=10135, loss=0.004]
# training:  20%|██        | 10135/50000 [48:42<3:07:08,  3.55it/s, it=10135, loss=0.004]
# training:  20%|██        | 10135/50000 [48:43<3:07:08,  3.55it/s, it=10136, loss=0.007]
# training:  20%|██        | 10136/50000 [48:43<3:06:38,  3.56it/s, it=10136, loss=0.007]
# training:  20%|██        | 10136/50000 [48:43<3:06:38,  3.56it/s, it=10137, loss=0.005]
# training:  20%|██        | 10137/50000 [48:43<3:06:19,  3.57it/s, it=10137, loss=0.005]
# training:  20%|██        | 10137/50000 [48:43<3:06:19,  3.57it/s, it=10138, loss=0.007]
# training:  20%|██        | 10138/50000 [48:43<3:06:21,  3.57it/s, it=10138, loss=0.007]
# training:  20%|██        | 10138/50000 [48:43<3:06:21,  3.57it/s, it=10139, loss=0.009]
# training:  20%|██        | 10139/50000 [48:43<3:06:31,  3.56it/s, it=10139, loss=0.009]
# training:  20%|██        | 10139/50000 [48:44<3:06:31,  3.56it/s, it=10140, loss=0.008]
# training:  20%|██        | 10140/50000 [48:44<3:06:29,  3.56it/s, it=10140, loss=0.008]
# training:  20%|██        | 10140/50000 [48:44<3:06:29,  3.56it/s, it=10141, loss=0.004]
# training:  20%|██        | 10141/50000 [48:44<3:06:34,  3.56it/s, it=10141, loss=0.004]
# training:  20%|██        | 10141/50000 [48:44<3:06:34,  3.56it/s, it=10142, loss=0.007]
# training:  20%|██        | 10142/50000 [48:44<3:06:28,  3.56it/s, it=10142, loss=0.007]
# training:  20%|██        | 10142/50000 [48:45<3:06:28,  3.56it/s, it=10143, loss=0.006]
# training:  20%|██        | 10143/50000 [48:45<3:06:37,  3.56it/s, it=10143, loss=0.006]
# training:  20%|██        | 10143/50000 [48:45<3:06:37,  3.56it/s, it=10144, loss=0.004]
# training:  20%|██        | 10144/50000 [48:45<3:06:19,  3.57it/s, it=10144, loss=0.004]
# training:  20%|██        | 10144/50000 [48:45<3:06:19,  3.57it/s, it=10145, loss=0.008]
# training:  20%|██        | 10145/50000 [48:45<3:06:26,  3.56it/s, it=10145, loss=0.008]
# training:  20%|██        | 10145/50000 [48:45<3:06:26,  3.56it/s, it=10146, loss=0.003]
# training:  20%|██        | 10146/50000 [48:45<3:06:04,  3.57it/s, it=10146, loss=0.003]
# training:  20%|██        | 10146/50000 [48:46<3:06:04,  3.57it/s, it=10147, loss=0.014]
# training:  20%|██        | 10147/50000 [48:46<3:06:13,  3.57it/s, it=10147, loss=0.014]
# training:  20%|██        | 10147/50000 [48:46<3:06:13,  3.57it/s, it=10148, loss=0.009]
# training:  20%|██        | 10148/50000 [48:46<3:06:52,  3.55it/s, it=10148, loss=0.009]
# training:  20%|██        | 10148/50000 [48:46<3:06:52,  3.55it/s, it=10149, loss=0.006]
# training:  20%|██        | 10149/50000 [48:46<3:06:59,  3.55it/s, it=10149, loss=0.006]
# training:  20%|██        | 10149/50000 [48:47<3:06:59,  3.55it/s, it=10150, loss=0.006]
# training:  20%|██        | 10150/50000 [48:47<3:06:40,  3.56it/s, it=10150, loss=0.006]
# training:  20%|██        | 10150/50000 [48:47<3:06:40,  3.56it/s, it=10151, loss=0.002]
# training:  20%|██        | 10151/50000 [48:47<3:06:19,  3.56it/s, it=10151, loss=0.002]
# training:  20%|██        | 10151/50000 [48:47<3:06:19,  3.56it/s, it=10152, loss=0.008]
# training:  20%|██        | 10152/50000 [48:47<3:06:25,  3.56it/s, it=10152, loss=0.008]
# training:  20%|██        | 10152/50000 [48:47<3:06:25,  3.56it/s, it=10153, loss=0.012]
# training:  20%|██        | 10153/50000 [48:47<3:06:34,  3.56it/s, it=10153, loss=0.012]
# training:  20%|██        | 10153/50000 [48:48<3:06:34,  3.56it/s, it=10154, loss=0.014]
# training:  20%|██        | 10154/50000 [48:48<3:06:31,  3.56it/s, it=10154, loss=0.014]
# training:  20%|██        | 10154/50000 [48:48<3:06:31,  3.56it/s, it=10155, loss=0.005]
# training:  20%|██        | 10155/50000 [48:48<3:06:35,  3.56it/s, it=10155, loss=0.005]
# training:  20%|██        | 10155/50000 [48:48<3:06:35,  3.56it/s, it=10156, loss=0.011]
# training:  20%|██        | 10156/50000 [48:48<3:06:17,  3.56it/s, it=10156, loss=0.011]
# training:  20%|██        | 10156/50000 [48:48<3:06:17,  3.56it/s, it=10157, loss=0.010]
# training:  20%|██        | 10157/50000 [48:48<3:05:56,  3.57it/s, it=10157, loss=0.010]
# training:  20%|██        | 10157/50000 [48:49<3:05:56,  3.57it/s, it=10158, loss=0.004]
# training:  20%|██        | 10158/50000 [48:49<3:06:19,  3.56it/s, it=10158, loss=0.004]
# training:  20%|██        | 10158/50000 [48:49<3:06:19,  3.56it/s, it=10159, loss=0.005]
# training:  20%|██        | 10159/50000 [48:49<3:06:34,  3.56it/s, it=10159, loss=0.005]
# training:  20%|██        | 10159/50000 [48:49<3:06:34,  3.56it/s, it=10160, loss=0.012]
# training:  20%|██        | 10160/50000 [48:49<3:06:57,  3.55it/s, it=10160, loss=0.012]
# training:  20%|██        | 10160/50000 [48:50<3:06:57,  3.55it/s, it=10161, loss=0.007]
# training:  20%|██        | 10161/50000 [48:50<3:07:16,  3.55it/s, it=10161, loss=0.007]
# training:  20%|██        | 10161/50000 [48:50<3:07:16,  3.55it/s, it=10162, loss=0.006]
# training:  20%|██        | 10162/50000 [48:50<3:07:08,  3.55it/s, it=10162, loss=0.006]
# training:  20%|██        | 10162/50000 [48:50<3:07:08,  3.55it/s, it=10163, loss=0.006]
# training:  20%|██        | 10163/50000 [48:50<3:07:13,  3.55it/s, it=10163, loss=0.006]
# training:  20%|██        | 10163/50000 [48:50<3:07:13,  3.55it/s, it=10164, loss=0.006]
# training:  20%|██        | 10164/50000 [48:50<3:07:12,  3.55it/s, it=10164, loss=0.006]
# training:  20%|██        | 10164/50000 [48:51<3:07:12,  3.55it/s, it=10165, loss=0.013]
# training:  20%|██        | 10165/50000 [48:51<3:07:29,  3.54it/s, it=10165, loss=0.013]
# training:  20%|██        | 10165/50000 [48:51<3:07:29,  3.54it/s, it=10166, loss=0.010]
# training:  20%|██        | 10166/50000 [48:51<3:07:48,  3.53it/s, it=10166, loss=0.010]
# training:  20%|██        | 10166/50000 [48:51<3:07:48,  3.53it/s, it=10167, loss=0.007]
# training:  20%|██        | 10167/50000 [48:51<3:07:52,  3.53it/s, it=10167, loss=0.007]
# training:  20%|██        | 10167/50000 [48:52<3:07:52,  3.53it/s, it=10168, loss=0.006]
# training:  20%|██        | 10168/50000 [48:52<3:07:51,  3.53it/s, it=10168, loss=0.006]
# training:  20%|██        | 10168/50000 [48:52<3:07:51,  3.53it/s, it=10169, loss=0.011]
# training:  20%|██        | 10169/50000 [48:52<3:07:23,  3.54it/s, it=10169, loss=0.011]
# training:  20%|██        | 10169/50000 [48:52<3:07:23,  3.54it/s, it=10170, loss=0.010]
# training:  20%|██        | 10170/50000 [48:52<3:07:11,  3.55it/s, it=10170, loss=0.010]
# training:  20%|██        | 10170/50000 [48:52<3:07:11,  3.55it/s, it=10171, loss=0.005]
# training:  20%|██        | 10171/50000 [48:52<3:07:07,  3.55it/s, it=10171, loss=0.005]
# training:  20%|██        | 10171/50000 [48:53<3:07:07,  3.55it/s, it=10172, loss=0.010]
# training:  20%|██        | 10172/50000 [48:53<3:06:50,  3.55it/s, it=10172, loss=0.010]
# training:  20%|██        | 10172/50000 [48:53<3:06:50,  3.55it/s, it=10173, loss=0.007]
# training:  20%|██        | 10173/50000 [48:53<3:06:38,  3.56it/s, it=10173, loss=0.007]
# training:  20%|██        | 10173/50000 [48:53<3:06:38,  3.56it/s, it=10174, loss=0.003]
# training:  20%|██        | 10174/50000 [48:53<3:06:14,  3.56it/s, it=10174, loss=0.003]
# training:  20%|██        | 10174/50000 [48:54<3:06:14,  3.56it/s, it=10175, loss=0.010]
# training:  20%|██        | 10175/50000 [48:54<3:06:06,  3.57it/s, it=10175, loss=0.010]
# training:  20%|██        | 10175/50000 [48:54<3:06:06,  3.57it/s, it=10176, loss=0.012]
# training:  20%|██        | 10176/50000 [48:54<3:06:34,  3.56it/s, it=10176, loss=0.012]
# training:  20%|██        | 10176/50000 [48:54<3:06:34,  3.56it/s, it=10177, loss=0.009]
# training:  20%|██        | 10177/50000 [48:54<3:06:32,  3.56it/s, it=10177, loss=0.009]
# training:  20%|██        | 10177/50000 [48:54<3:06:32,  3.56it/s, it=10178, loss=0.006]
# training:  20%|██        | 10178/50000 [48:54<3:06:12,  3.56it/s, it=10178, loss=0.006]
# training:  20%|██        | 10178/50000 [48:55<3:06:12,  3.56it/s, it=10179, loss=0.006]
# training:  20%|██        | 10179/50000 [48:55<3:06:08,  3.57it/s, it=10179, loss=0.006]
# training:  20%|██        | 10179/50000 [48:55<3:06:08,  3.57it/s, it=10180, loss=0.006]
# training:  20%|██        | 10180/50000 [48:55<3:06:17,  3.56it/s, it=10180, loss=0.006]
# training:  20%|██        | 10180/50000 [48:55<3:06:17,  3.56it/s, it=10181, loss=0.002]
# training:  20%|██        | 10181/50000 [48:55<3:06:00,  3.57it/s, it=10181, loss=0.002]
# training:  20%|██        | 10181/50000 [48:56<3:06:00,  3.57it/s, it=10182, loss=0.010]
# training:  20%|██        | 10182/50000 [48:56<3:06:08,  3.57it/s, it=10182, loss=0.010]
# training:  20%|██        | 10182/50000 [48:56<3:06:08,  3.57it/s, it=10183, loss=0.005]
# training:  20%|██        | 10183/50000 [48:56<3:06:24,  3.56it/s, it=10183, loss=0.005]
# training:  20%|██        | 10183/50000 [48:56<3:06:24,  3.56it/s, it=10184, loss=0.011]
# training:  20%|██        | 10184/50000 [48:56<3:05:53,  3.57it/s, it=10184, loss=0.011]
# training:  20%|██        | 10184/50000 [48:56<3:05:53,  3.57it/s, it=10185, loss=0.009]
# training:  20%|██        | 10185/50000 [48:56<3:05:47,  3.57it/s, it=10185, loss=0.009]
# training:  20%|██        | 10185/50000 [48:57<3:05:47,  3.57it/s, it=10186, loss=0.012]
# training:  20%|██        | 10186/50000 [48:57<3:05:50,  3.57it/s, it=10186, loss=0.012]
# training:  20%|██        | 10186/50000 [48:57<3:05:50,  3.57it/s, it=10187, loss=0.008]
# training:  20%|██        | 10187/50000 [48:57<3:05:50,  3.57it/s, it=10187, loss=0.008]
# training:  20%|██        | 10187/50000 [48:57<3:05:50,  3.57it/s, it=10188, loss=0.004]
# training:  20%|██        | 10188/50000 [48:57<3:06:04,  3.57it/s, it=10188, loss=0.004]
# training:  20%|██        | 10188/50000 [48:57<3:06:04,  3.57it/s, it=10189, loss=0.009]
# training:  20%|██        | 10189/50000 [48:57<3:06:17,  3.56it/s, it=10189, loss=0.009]
# training:  20%|██        | 10189/50000 [48:58<3:06:17,  3.56it/s, it=10190, loss=0.007]
# training:  20%|██        | 10190/50000 [48:58<3:06:00,  3.57it/s, it=10190, loss=0.007]
# training:  20%|██        | 10190/50000 [48:58<3:06:00,  3.57it/s, it=10191, loss=0.007]
# training:  20%|██        | 10191/50000 [48:58<3:05:46,  3.57it/s, it=10191, loss=0.007]
# training:  20%|██        | 10191/50000 [48:58<3:05:46,  3.57it/s, it=10192, loss=0.006]
# training:  20%|██        | 10192/50000 [48:58<3:05:44,  3.57it/s, it=10192, loss=0.006]
# training:  20%|██        | 10192/50000 [48:59<3:05:44,  3.57it/s, it=10193, loss=0.005]
# training:  20%|██        | 10193/50000 [48:59<3:05:59,  3.57it/s, it=10193, loss=0.005]
# training:  20%|██        | 10193/50000 [48:59<3:05:59,  3.57it/s, it=10194, loss=0.010]
# training:  20%|██        | 10194/50000 [48:59<3:06:10,  3.56it/s, it=10194, loss=0.010]
# training:  20%|██        | 10194/50000 [48:59<3:06:10,  3.56it/s, it=10195, loss=0.009]
# training:  20%|██        | 10195/50000 [48:59<3:05:44,  3.57it/s, it=10195, loss=0.009]
# training:  20%|██        | 10195/50000 [48:59<3:05:44,  3.57it/s, it=10196, loss=0.005]
# training:  20%|██        | 10196/50000 [48:59<3:05:53,  3.57it/s, it=10196, loss=0.005]
# training:  20%|██        | 10196/50000 [49:00<3:05:53,  3.57it/s, it=10197, loss=0.010]
# training:  20%|██        | 10197/50000 [49:00<3:06:10,  3.56it/s, it=10197, loss=0.010]
# training:  20%|██        | 10197/50000 [49:00<3:06:10,  3.56it/s, it=10198, loss=0.003]
# training:  20%|██        | 10198/50000 [49:00<3:05:58,  3.57it/s, it=10198, loss=0.003]
# training:  20%|██        | 10198/50000 [49:00<3:05:58,  3.57it/s, it=10199, loss=0.004]
# training:  20%|██        | 10199/50000 [49:00<3:05:58,  3.57it/s, it=10199, loss=0.004]
# training:  20%|██        | 10199/50000 [49:01<3:05:58,  3.57it/s, it=10200, loss=0.010]
# training:  20%|██        | 10200/50000 [49:01<3:09:55,  3.49it/s, it=10200, loss=0.010]
# training:  20%|██        | 10200/50000 [49:01<3:09:55,  3.49it/s, it=10201, loss=0.010]
# training:  20%|██        | 10201/50000 [49:01<3:08:32,  3.52it/s, it=10201, loss=0.010]
# training:  20%|██        | 10201/50000 [49:01<3:08:32,  3.52it/s, it=10202, loss=0.006]
# training:  20%|██        | 10202/50000 [49:01<3:07:56,  3.53it/s, it=10202, loss=0.006]
# training:  20%|██        | 10202/50000 [49:01<3:07:56,  3.53it/s, it=10203, loss=0.003]
# training:  20%|██        | 10203/50000 [49:01<3:07:05,  3.55it/s, it=10203, loss=0.003]
# training:  20%|██        | 10203/50000 [49:02<3:07:05,  3.55it/s, it=10204, loss=0.006]
# training:  20%|██        | 10204/50000 [49:02<3:06:42,  3.55it/s, it=10204, loss=0.006]
# training:  20%|██        | 10204/50000 [49:02<3:06:42,  3.55it/s, it=10205, loss=0.006]
# training:  20%|██        | 10205/50000 [49:02<3:07:02,  3.55it/s, it=10205, loss=0.006]
# training:  20%|██        | 10205/50000 [49:02<3:07:02,  3.55it/s, it=10206, loss=0.008]
# training:  20%|██        | 10206/50000 [49:02<3:07:30,  3.54it/s, it=10206, loss=0.008]
# training:  20%|██        | 10206/50000 [49:03<3:07:30,  3.54it/s, it=10207, loss=0.005]
# training:  20%|██        | 10207/50000 [49:03<3:07:50,  3.53it/s, it=10207, loss=0.005]
# training:  20%|██        | 10207/50000 [49:03<3:07:50,  3.53it/s, it=10208, loss=0.009]
# training:  20%|██        | 10208/50000 [49:03<3:07:53,  3.53it/s, it=10208, loss=0.009]
# training:  20%|██        | 10208/50000 [49:03<3:07:53,  3.53it/s, it=10209, loss=0.012]
# training:  20%|██        | 10209/50000 [49:03<3:08:05,  3.53it/s, it=10209, loss=0.012]
# training:  20%|██        | 10209/50000 [49:03<3:08:05,  3.53it/s, it=10210, loss=0.008]
# training:  20%|██        | 10210/50000 [49:03<3:07:59,  3.53it/s, it=10210, loss=0.008]
# training:  20%|██        | 10210/50000 [49:04<3:07:59,  3.53it/s, it=10211, loss=0.006]
# training:  20%|██        | 10211/50000 [49:04<3:08:16,  3.52it/s, it=10211, loss=0.006]
# training:  20%|██        | 10211/50000 [49:04<3:08:16,  3.52it/s, it=10212, loss=0.010]
# training:  20%|██        | 10212/50000 [49:04<3:08:17,  3.52it/s, it=10212, loss=0.010]
# training:  20%|██        | 10212/50000 [49:04<3:08:17,  3.52it/s, it=10213, loss=0.008]
# training:  20%|██        | 10213/50000 [49:04<3:08:27,  3.52it/s, it=10213, loss=0.008]
# training:  20%|██        | 10213/50000 [49:05<3:08:27,  3.52it/s, it=10214, loss=0.006]
# training:  20%|██        | 10214/50000 [49:05<3:08:09,  3.52it/s, it=10214, loss=0.006]
# training:  20%|██        | 10214/50000 [49:05<3:08:09,  3.52it/s, it=10215, loss=0.013]
# training:  20%|██        | 10215/50000 [49:05<3:08:02,  3.53it/s, it=10215, loss=0.013]
# training:  20%|██        | 10215/50000 [49:05<3:08:02,  3.53it/s, it=10216, loss=0.004]
# training:  20%|██        | 10216/50000 [49:05<3:07:31,  3.54it/s, it=10216, loss=0.004]
# training:  20%|██        | 10216/50000 [49:05<3:07:31,  3.54it/s, it=10217, loss=0.010]
# training:  20%|██        | 10217/50000 [49:05<3:06:57,  3.55it/s, it=10217, loss=0.010]
# training:  20%|██        | 10217/50000 [49:06<3:06:57,  3.55it/s, it=10218, loss=0.008]
# training:  20%|██        | 10218/50000 [49:06<3:06:26,  3.56it/s, it=10218, loss=0.008]
# training:  20%|██        | 10218/50000 [49:06<3:06:26,  3.56it/s, it=10219, loss=0.006]
# training:  20%|██        | 10219/50000 [49:06<3:06:14,  3.56it/s, it=10219, loss=0.006]
# training:  20%|██        | 10219/50000 [49:06<3:06:14,  3.56it/s, it=10220, loss=0.003]
# training:  20%|██        | 10220/50000 [49:06<3:06:02,  3.56it/s, it=10220, loss=0.003]
# training:  20%|██        | 10220/50000 [49:07<3:06:02,  3.56it/s, it=10221, loss=0.017]
# training:  20%|██        | 10221/50000 [49:07<3:06:13,  3.56it/s, it=10221, loss=0.017]
# training:  20%|██        | 10221/50000 [49:07<3:06:13,  3.56it/s, it=10222, loss=0.007]
# training:  20%|██        | 10222/50000 [49:07<3:06:02,  3.56it/s, it=10222, loss=0.007]
# training:  20%|██        | 10222/50000 [49:07<3:06:02,  3.56it/s, it=10223, loss=0.007]
# training:  20%|██        | 10223/50000 [49:07<3:05:46,  3.57it/s, it=10223, loss=0.007]
# training:  20%|██        | 10223/50000 [49:07<3:05:46,  3.57it/s, it=10224, loss=0.009]
# training:  20%|██        | 10224/50000 [49:07<3:06:07,  3.56it/s, it=10224, loss=0.009]
# training:  20%|██        | 10224/50000 [49:08<3:06:07,  3.56it/s, it=10225, loss=0.011]
# training:  20%|██        | 10225/50000 [49:08<3:05:59,  3.56it/s, it=10225, loss=0.011]
# training:  20%|██        | 10225/50000 [49:08<3:05:59,  3.56it/s, it=10226, loss=0.008]
# training:  20%|██        | 10226/50000 [49:08<3:05:51,  3.57it/s, it=10226, loss=0.008]
# training:  20%|██        | 10226/50000 [49:08<3:05:51,  3.57it/s, it=10227, loss=0.010]
# training:  20%|██        | 10227/50000 [49:08<3:05:49,  3.57it/s, it=10227, loss=0.010]
# training:  20%|██        | 10227/50000 [49:08<3:05:49,  3.57it/s, it=10228, loss=0.005]
# training:  20%|██        | 10228/50000 [49:08<3:06:03,  3.56it/s, it=10228, loss=0.005]
# training:  20%|██        | 10228/50000 [49:09<3:06:03,  3.56it/s, it=10229, loss=0.005]
# training:  20%|██        | 10229/50000 [49:09<3:06:04,  3.56it/s, it=10229, loss=0.005]
# training:  20%|██        | 10229/50000 [49:09<3:06:04,  3.56it/s, it=10230, loss=0.007]
# training:  20%|██        | 10230/50000 [49:09<3:06:05,  3.56it/s, it=10230, loss=0.007]
# training:  20%|██        | 10230/50000 [49:09<3:06:05,  3.56it/s, it=10231, loss=0.018]
# training:  20%|██        | 10231/50000 [49:09<3:05:52,  3.57it/s, it=10231, loss=0.018]
# training:  20%|██        | 10231/50000 [49:10<3:05:52,  3.57it/s, it=10232, loss=0.005]
# training:  20%|██        | 10232/50000 [49:10<3:05:53,  3.57it/s, it=10232, loss=0.005]
# training:  20%|██        | 10232/50000 [49:10<3:05:53,  3.57it/s, it=10233, loss=0.007]
# training:  20%|██        | 10233/50000 [49:10<3:06:39,  3.55it/s, it=10233, loss=0.007]
# training:  20%|██        | 10233/50000 [49:10<3:06:39,  3.55it/s, it=10234, loss=0.003]
# training:  20%|██        | 10234/50000 [49:10<3:06:32,  3.55it/s, it=10234, loss=0.003]
# training:  20%|██        | 10234/50000 [49:10<3:06:32,  3.55it/s, it=10235, loss=0.009]
# training:  20%|██        | 10235/50000 [49:10<3:05:57,  3.56it/s, it=10235, loss=0.009]
# training:  20%|██        | 10235/50000 [49:11<3:05:57,  3.56it/s, it=10236, loss=0.007]
# training:  20%|██        | 10236/50000 [49:11<3:05:53,  3.57it/s, it=10236, loss=0.007]
# training:  20%|██        | 10236/50000 [49:11<3:05:53,  3.57it/s, it=10237, loss=0.009]
# training:  20%|██        | 10237/50000 [49:11<3:06:29,  3.55it/s, it=10237, loss=0.009]
# training:  20%|██        | 10237/50000 [49:11<3:06:29,  3.55it/s, it=10238, loss=0.006]
# training:  20%|██        | 10238/50000 [49:11<3:06:25,  3.55it/s, it=10238, loss=0.006]
# training:  20%|██        | 10238/50000 [49:12<3:06:25,  3.55it/s, it=10239, loss=0.008]
# training:  20%|██        | 10239/50000 [49:12<3:06:16,  3.56it/s, it=10239, loss=0.008]
# training:  20%|██        | 10239/50000 [49:12<3:06:16,  3.56it/s, it=10240, loss=0.010]
# training:  20%|██        | 10240/50000 [49:12<3:06:21,  3.56it/s, it=10240, loss=0.010]
# training:  20%|██        | 10240/50000 [49:12<3:06:21,  3.56it/s, it=10241, loss=0.008]
# training:  20%|██        | 10241/50000 [49:12<3:06:16,  3.56it/s, it=10241, loss=0.008]
# training:  20%|██        | 10241/50000 [49:12<3:06:16,  3.56it/s, it=10242, loss=0.009]
# training:  20%|██        | 10242/50000 [49:12<3:06:04,  3.56it/s, it=10242, loss=0.009]
# training:  20%|██        | 10242/50000 [49:13<3:06:04,  3.56it/s, it=10243, loss=0.007]
# training:  20%|██        | 10243/50000 [49:13<3:06:01,  3.56it/s, it=10243, loss=0.007]
# training:  20%|██        | 10243/50000 [49:13<3:06:01,  3.56it/s, it=10244, loss=0.007]
# training:  20%|██        | 10244/50000 [49:13<3:05:57,  3.56it/s, it=10244, loss=0.007]
# training:  20%|██        | 10244/50000 [49:13<3:05:57,  3.56it/s, it=10245, loss=0.011]
# training:  20%|██        | 10245/50000 [49:13<3:06:11,  3.56it/s, it=10245, loss=0.011]
# training:  20%|██        | 10245/50000 [49:14<3:06:11,  3.56it/s, it=10246, loss=0.013]
# training:  20%|██        | 10246/50000 [49:14<3:06:26,  3.55it/s, it=10246, loss=0.013]
# training:  20%|██        | 10246/50000 [49:14<3:06:26,  3.55it/s, it=10247, loss=0.009]
# training:  20%|██        | 10247/50000 [49:14<3:06:23,  3.55it/s, it=10247, loss=0.009]
# training:  20%|██        | 10247/50000 [49:14<3:06:23,  3.55it/s, it=10248, loss=0.010]
# training:  20%|██        | 10248/50000 [49:14<3:06:44,  3.55it/s, it=10248, loss=0.010]
# training:  20%|██        | 10248/50000 [49:14<3:06:44,  3.55it/s, it=10249, loss=0.009]
# training:  20%|██        | 10249/50000 [49:14<3:06:18,  3.56it/s, it=10249, loss=0.009]
# training:  20%|██        | 10249/50000 [49:15<3:06:18,  3.56it/s, it=10250, loss=0.010]
# training:  20%|██        | 10250/50000 [49:15<3:06:15,  3.56it/s, it=10250, loss=0.010]
# training:  20%|██        | 10250/50000 [49:15<3:06:15,  3.56it/s, it=10251, loss=0.012]
# training:  21%|██        | 10251/50000 [49:15<3:06:55,  3.54it/s, it=10251, loss=0.012]
# training:  21%|██        | 10251/50000 [49:15<3:06:55,  3.54it/s, it=10252, loss=0.007]
# training:  21%|██        | 10252/50000 [49:15<3:07:10,  3.54it/s, it=10252, loss=0.007]
# training:  21%|██        | 10252/50000 [49:16<3:07:10,  3.54it/s, it=10253, loss=0.008]
# training:  21%|██        | 10253/50000 [49:16<3:07:14,  3.54it/s, it=10253, loss=0.008]
# training:  21%|██        | 10253/50000 [49:16<3:07:14,  3.54it/s, it=10254, loss=0.002]
# training:  21%|██        | 10254/50000 [49:16<3:07:22,  3.54it/s, it=10254, loss=0.002]
# training:  21%|██        | 10254/50000 [49:16<3:07:22,  3.54it/s, it=10255, loss=0.005]
# training:  21%|██        | 10255/50000 [49:16<3:07:14,  3.54it/s, it=10255, loss=0.005]
# training:  21%|██        | 10255/50000 [49:16<3:07:14,  3.54it/s, it=10256, loss=0.009]
# training:  21%|██        | 10256/50000 [49:16<3:07:09,  3.54it/s, it=10256, loss=0.009]
# training:  21%|██        | 10256/50000 [49:17<3:07:09,  3.54it/s, it=10257, loss=0.009]
# training:  21%|██        | 10257/50000 [49:17<3:07:03,  3.54it/s, it=10257, loss=0.009]
# training:  21%|██        | 10257/50000 [49:17<3:07:03,  3.54it/s, it=10258, loss=0.004]
# training:  21%|██        | 10258/50000 [49:17<3:07:13,  3.54it/s, it=10258, loss=0.004]
# training:  21%|██        | 10258/50000 [49:17<3:07:13,  3.54it/s, it=10259, loss=0.006]
# training:  21%|██        | 10259/50000 [49:17<3:07:17,  3.54it/s, it=10259, loss=0.006]
# training:  21%|██        | 10259/50000 [49:17<3:07:17,  3.54it/s, it=10260, loss=0.006]
# training:  21%|██        | 10260/50000 [49:17<3:07:18,  3.54it/s, it=10260, loss=0.006]
# training:  21%|██        | 10260/50000 [49:18<3:07:18,  3.54it/s, it=10261, loss=0.007]
# training:  21%|██        | 10261/50000 [49:18<3:07:40,  3.53it/s, it=10261, loss=0.007]
# training:  21%|██        | 10261/50000 [49:18<3:07:40,  3.53it/s, it=10262, loss=0.005]
# training:  21%|██        | 10262/50000 [49:18<3:07:15,  3.54it/s, it=10262, loss=0.005]
# training:  21%|██        | 10262/50000 [49:18<3:07:15,  3.54it/s, it=10263, loss=0.003]
# training:  21%|██        | 10263/50000 [49:18<3:07:04,  3.54it/s, it=10263, loss=0.003]
# training:  21%|██        | 10263/50000 [49:19<3:07:04,  3.54it/s, it=10264, loss=0.006]
# training:  21%|██        | 10264/50000 [49:19<3:06:41,  3.55it/s, it=10264, loss=0.006]
# training:  21%|██        | 10264/50000 [49:19<3:06:41,  3.55it/s, it=10265, loss=0.010]
# training:  21%|██        | 10265/50000 [49:19<3:07:11,  3.54it/s, it=10265, loss=0.010]
# training:  21%|██        | 10265/50000 [49:19<3:07:11,  3.54it/s, it=10266, loss=0.010]
# training:  21%|██        | 10266/50000 [49:19<3:06:59,  3.54it/s, it=10266, loss=0.010]
# training:  21%|██        | 10266/50000 [49:19<3:06:59,  3.54it/s, it=10267, loss=0.007]
# training:  21%|██        | 10267/50000 [49:19<3:06:31,  3.55it/s, it=10267, loss=0.007]
# training:  21%|██        | 10267/50000 [49:20<3:06:31,  3.55it/s, it=10268, loss=0.008]
# training:  21%|██        | 10268/50000 [49:20<3:06:30,  3.55it/s, it=10268, loss=0.008]
# training:  21%|██        | 10268/50000 [49:20<3:06:30,  3.55it/s, it=10269, loss=0.003]
# training:  21%|██        | 10269/50000 [49:20<3:06:26,  3.55it/s, it=10269, loss=0.003]
# training:  21%|██        | 10269/50000 [49:20<3:06:26,  3.55it/s, it=10270, loss=0.008]
# training:  21%|██        | 10270/50000 [49:20<3:06:13,  3.56it/s, it=10270, loss=0.008]
# training:  21%|██        | 10270/50000 [49:21<3:06:13,  3.56it/s, it=10271, loss=0.009]
# training:  21%|██        | 10271/50000 [49:21<3:06:22,  3.55it/s, it=10271, loss=0.009]
# training:  21%|██        | 10271/50000 [49:21<3:06:22,  3.55it/s, it=10272, loss=0.006]
# training:  21%|██        | 10272/50000 [49:21<3:06:21,  3.55it/s, it=10272, loss=0.006]
# training:  21%|██        | 10272/50000 [49:21<3:06:21,  3.55it/s, it=10273, loss=0.005]
# training:  21%|██        | 10273/50000 [49:21<3:07:25,  3.53it/s, it=10273, loss=0.005]
# training:  21%|██        | 10273/50000 [49:21<3:07:25,  3.53it/s, it=10274, loss=0.006]
# training:  21%|██        | 10274/50000 [49:21<3:07:11,  3.54it/s, it=10274, loss=0.006]
# training:  21%|██        | 10274/50000 [49:22<3:07:11,  3.54it/s, it=10275, loss=0.015]
# training:  21%|██        | 10275/50000 [49:22<3:07:25,  3.53it/s, it=10275, loss=0.015]
# training:  21%|██        | 10275/50000 [49:22<3:07:25,  3.53it/s, it=10276, loss=0.007]
# training:  21%|██        | 10276/50000 [49:22<3:07:28,  3.53it/s, it=10276, loss=0.007]
# training:  21%|██        | 10276/50000 [49:22<3:07:28,  3.53it/s, it=10277, loss=0.005]
# training:  21%|██        | 10277/50000 [49:22<3:07:19,  3.53it/s, it=10277, loss=0.005]
# training:  21%|██        | 10277/50000 [49:23<3:07:19,  3.53it/s, it=10278, loss=0.011]
# training:  21%|██        | 10278/50000 [49:23<3:07:14,  3.54it/s, it=10278, loss=0.011]
# training:  21%|██        | 10278/50000 [49:23<3:07:14,  3.54it/s, it=10279, loss=0.009]
# training:  21%|██        | 10279/50000 [49:23<3:07:28,  3.53it/s, it=10279, loss=0.009]
# training:  21%|██        | 10279/50000 [49:23<3:07:28,  3.53it/s, it=10280, loss=0.010]
# training:  21%|██        | 10280/50000 [49:23<3:07:27,  3.53it/s, it=10280, loss=0.010]
# training:  21%|██        | 10280/50000 [49:23<3:07:27,  3.53it/s, it=10281, loss=0.009]
# training:  21%|██        | 10281/50000 [49:23<3:07:30,  3.53it/s, it=10281, loss=0.009]
# training:  21%|██        | 10281/50000 [49:24<3:07:30,  3.53it/s, it=10282, loss=0.004]
# training:  21%|██        | 10282/50000 [49:24<3:07:50,  3.52it/s, it=10282, loss=0.004]
# training:  21%|██        | 10282/50000 [49:24<3:07:50,  3.52it/s, it=10283, loss=0.005]
# training:  21%|██        | 10283/50000 [49:24<3:07:33,  3.53it/s, it=10283, loss=0.005]
# training:  21%|██        | 10283/50000 [49:24<3:07:33,  3.53it/s, it=10284, loss=0.005]
# training:  21%|██        | 10284/50000 [49:24<3:07:15,  3.54it/s, it=10284, loss=0.005]
# training:  21%|██        | 10284/50000 [49:25<3:07:15,  3.54it/s, it=10285, loss=0.015]
# training:  21%|██        | 10285/50000 [49:25<3:07:16,  3.53it/s, it=10285, loss=0.015]
# training:  21%|██        | 10285/50000 [49:25<3:07:16,  3.53it/s, it=10286, loss=0.014]
# training:  21%|██        | 10286/50000 [49:25<3:07:15,  3.53it/s, it=10286, loss=0.014]
# training:  21%|██        | 10286/50000 [49:25<3:07:15,  3.53it/s, it=10287, loss=0.009]
# training:  21%|██        | 10287/50000 [49:25<3:06:53,  3.54it/s, it=10287, loss=0.009]
# training:  21%|██        | 10287/50000 [49:25<3:06:53,  3.54it/s, it=10288, loss=0.012]
# training:  21%|██        | 10288/50000 [49:25<3:06:24,  3.55it/s, it=10288, loss=0.012]
# training:  21%|██        | 10288/50000 [49:26<3:06:24,  3.55it/s, it=10289, loss=0.008]
# training:  21%|██        | 10289/50000 [49:26<3:06:12,  3.55it/s, it=10289, loss=0.008]
# training:  21%|██        | 10289/50000 [49:26<3:06:12,  3.55it/s, it=10290, loss=0.011]
# training:  21%|██        | 10290/50000 [49:26<3:06:15,  3.55it/s, it=10290, loss=0.011]
# training:  21%|██        | 10290/50000 [49:26<3:06:15,  3.55it/s, it=10291, loss=0.001]
# training:  21%|██        | 10291/50000 [49:26<3:06:06,  3.56it/s, it=10291, loss=0.001]
# training:  21%|██        | 10291/50000 [49:27<3:06:06,  3.56it/s, it=10292, loss=0.004]
# training:  21%|██        | 10292/50000 [49:27<3:06:02,  3.56it/s, it=10292, loss=0.004]
# training:  21%|██        | 10292/50000 [49:27<3:06:02,  3.56it/s, it=10293, loss=0.009]
# training:  21%|██        | 10293/50000 [49:27<3:06:09,  3.56it/s, it=10293, loss=0.009]
# training:  21%|██        | 10293/50000 [49:27<3:06:09,  3.56it/s, it=10294, loss=0.007]
# training:  21%|██        | 10294/50000 [49:27<3:06:32,  3.55it/s, it=10294, loss=0.007]
# training:  21%|██        | 10294/50000 [49:27<3:06:32,  3.55it/s, it=10295, loss=0.008]
# training:  21%|██        | 10295/50000 [49:27<3:06:41,  3.54it/s, it=10295, loss=0.008]
# training:  21%|██        | 10295/50000 [49:28<3:06:41,  3.54it/s, it=10296, loss=0.006]
# training:  21%|██        | 10296/50000 [49:28<3:06:23,  3.55it/s, it=10296, loss=0.006]
# training:  21%|██        | 10296/50000 [49:28<3:06:23,  3.55it/s, it=10297, loss=0.011]
# training:  21%|██        | 10297/50000 [49:28<3:06:05,  3.56it/s, it=10297, loss=0.011]
# training:  21%|██        | 10297/50000 [49:28<3:06:05,  3.56it/s, it=10298, loss=0.012]
# training:  21%|██        | 10298/50000 [49:28<3:06:16,  3.55it/s, it=10298, loss=0.012]
# training:  21%|██        | 10298/50000 [49:29<3:06:16,  3.55it/s, it=10299, loss=0.008]
# training:  21%|██        | 10299/50000 [49:29<3:06:40,  3.54it/s, it=10299, loss=0.008]
# training:  21%|██        | 10299/50000 [49:29<3:06:40,  3.54it/s, it=10300, loss=0.003]
# training:  21%|██        | 10300/50000 [49:29<3:06:40,  3.54it/s, it=10300, loss=0.003]
# training:  21%|██        | 10300/50000 [49:29<3:06:40,  3.54it/s, it=10301, loss=0.012]
# training:  21%|██        | 10301/50000 [49:29<3:06:52,  3.54it/s, it=10301, loss=0.012]
# training:  21%|██        | 10301/50000 [49:29<3:06:52,  3.54it/s, it=10302, loss=0.009]
# training:  21%|██        | 10302/50000 [49:29<3:07:07,  3.54it/s, it=10302, loss=0.009]
# training:  21%|██        | 10302/50000 [49:30<3:07:07,  3.54it/s, it=10303, loss=0.003]
# training:  21%|██        | 10303/50000 [49:30<3:07:19,  3.53it/s, it=10303, loss=0.003]
# training:  21%|██        | 10303/50000 [49:30<3:07:19,  3.53it/s, it=10304, loss=0.009]
# training:  21%|██        | 10304/50000 [49:30<3:07:12,  3.53it/s, it=10304, loss=0.009]
# training:  21%|██        | 10304/50000 [49:30<3:07:12,  3.53it/s, it=10305, loss=0.002]
# training:  21%|██        | 10305/50000 [49:30<3:07:34,  3.53it/s, it=10305, loss=0.002]
# training:  21%|██        | 10305/50000 [49:30<3:07:34,  3.53it/s, it=10306, loss=0.006]
# training:  21%|██        | 10306/50000 [49:30<3:07:55,  3.52it/s, it=10306, loss=0.006]
# training:  21%|██        | 10306/50000 [49:31<3:07:55,  3.52it/s, it=10307, loss=0.006]
# training:  21%|██        | 10307/50000 [49:31<3:08:09,  3.52it/s, it=10307, loss=0.006]
# training:  21%|██        | 10307/50000 [49:31<3:08:09,  3.52it/s, it=10308, loss=0.007]
# training:  21%|██        | 10308/50000 [49:31<3:08:05,  3.52it/s, it=10308, loss=0.007]
# training:  21%|██        | 10308/50000 [49:31<3:08:05,  3.52it/s, it=10309, loss=0.009]
# training:  21%|██        | 10309/50000 [49:31<3:07:30,  3.53it/s, it=10309, loss=0.009]
# training:  21%|██        | 10309/50000 [49:32<3:07:30,  3.53it/s, it=10310, loss=0.009]
# training:  21%|██        | 10310/50000 [49:32<3:07:02,  3.54it/s, it=10310, loss=0.009]
# training:  21%|██        | 10310/50000 [49:32<3:07:02,  3.54it/s, it=10311, loss=0.009]
# training:  21%|██        | 10311/50000 [49:32<3:06:29,  3.55it/s, it=10311, loss=0.009]
# training:  21%|██        | 10311/50000 [49:32<3:06:29,  3.55it/s, it=10312, loss=0.011]
# training:  21%|██        | 10312/50000 [49:32<3:06:26,  3.55it/s, it=10312, loss=0.011]
# training:  21%|██        | 10312/50000 [49:32<3:06:26,  3.55it/s, it=10313, loss=0.004]
# training:  21%|██        | 10313/50000 [49:32<3:06:27,  3.55it/s, it=10313, loss=0.004]
# training:  21%|██        | 10313/50000 [49:33<3:06:27,  3.55it/s, it=10314, loss=0.006]
# training:  21%|██        | 10314/50000 [49:33<3:06:31,  3.55it/s, it=10314, loss=0.006]
# training:  21%|██        | 10314/50000 [49:33<3:06:31,  3.55it/s, it=10315, loss=0.004]
# training:  21%|██        | 10315/50000 [49:33<3:06:29,  3.55it/s, it=10315, loss=0.004]
# training:  21%|██        | 10315/50000 [49:33<3:06:29,  3.55it/s, it=10316, loss=0.010]
# training:  21%|██        | 10316/50000 [49:33<3:06:29,  3.55it/s, it=10316, loss=0.010]
# training:  21%|██        | 10316/50000 [49:34<3:06:29,  3.55it/s, it=10317, loss=0.007]
# training:  21%|██        | 10317/50000 [49:34<3:06:19,  3.55it/s, it=10317, loss=0.007]
# training:  21%|██        | 10317/50000 [49:34<3:06:19,  3.55it/s, it=10318, loss=0.007]
# training:  21%|██        | 10318/50000 [49:34<3:05:47,  3.56it/s, it=10318, loss=0.007]
# training:  21%|██        | 10318/50000 [49:34<3:05:47,  3.56it/s, it=10319, loss=0.010]
# training:  21%|██        | 10319/50000 [49:34<3:05:55,  3.56it/s, it=10319, loss=0.010]
# training:  21%|██        | 10319/50000 [49:34<3:05:55,  3.56it/s, it=10320, loss=0.006]
# training:  21%|██        | 10320/50000 [49:34<3:06:01,  3.56it/s, it=10320, loss=0.006]
# training:  21%|██        | 10320/50000 [49:35<3:06:01,  3.56it/s, it=10321, loss=0.005]
# training:  21%|██        | 10321/50000 [49:35<3:06:09,  3.55it/s, it=10321, loss=0.005]
# training:  21%|██        | 10321/50000 [49:35<3:06:09,  3.55it/s, it=10322, loss=0.008]
# training:  21%|██        | 10322/50000 [49:35<3:06:02,  3.55it/s, it=10322, loss=0.008]
# training:  21%|██        | 10322/50000 [49:35<3:06:02,  3.55it/s, it=10323, loss=0.007]
# training:  21%|██        | 10323/50000 [49:35<3:05:52,  3.56it/s, it=10323, loss=0.007]
# training:  21%|██        | 10323/50000 [49:36<3:05:52,  3.56it/s, it=10324, loss=0.007]
# training:  21%|██        | 10324/50000 [49:36<3:06:19,  3.55it/s, it=10324, loss=0.007]
# training:  21%|██        | 10324/50000 [49:36<3:06:19,  3.55it/s, it=10325, loss=0.009]
# training:  21%|██        | 10325/50000 [49:36<3:06:20,  3.55it/s, it=10325, loss=0.009]
# training:  21%|██        | 10325/50000 [49:36<3:06:20,  3.55it/s, it=10326, loss=0.010]
# training:  21%|██        | 10326/50000 [49:36<3:06:40,  3.54it/s, it=10326, loss=0.010]
# training:  21%|██        | 10326/50000 [49:36<3:06:40,  3.54it/s, it=10327, loss=0.005]
# ...
# training:  25%|██▍       | 12465/50000 [59:41<2:55:58,  3.55it/s, it=12465, loss=0.009]
# training:  25%|██▍       | 12465/50000 [59:42<2:55:58,  3.55it/s, it=12466, loss=0.006]
# training:  25%|██▍       | 12466/50000 [59:42<2:55:57,  3.56it/s, it=12466, loss=0.006]
# training:  25%|██▍       | 12466/50000 [59:42<2:55:57,  3.56it/s, it=12467, loss=0.006]
# training:  25%|██▍       | 12467/50000 [59:42<2:56:06,  3.55it/s, it=12467, loss=0.006]
# training:  25%|██▍       | 12467/50000 [59:42<2:56:06,  3.55it/s, it=12468, loss=0.006]
# training:  25%|██▍       | 12468/50000 [59:42<2:56:19,  3.55it/s, it=12468, loss=0.006]
# training:  25%|██▍       | 12468/50000 [59:43<2:56:19,  3.55it/s, it=12469, loss=0.004]
# training:  25%|██▍       | 12469/50000 [59:43<2:56:24,  3.55it/s, it=12469, loss=0.004]
# training:  25%|██▍       | 12469/50000 [59:43<2:56:24,  3.55it/s, it=12470, loss=0.010]
# training:  25%|██▍       | 12470/50000 [59:43<2:56:19,  3.55it/s, it=12470, loss=0.010]
# training:  25%|██▍       | 12470/50000 [59:43<2:56:19,  3.55it/s, it=12471, loss=0.003]
# training:  25%|██▍       | 12471/50000 [59:43<2:55:53,  3.56it/s, it=12471, loss=0.003]
# training:  25%|██▍       | 12471/50000 [59:43<2:55:53,  3.56it/s, it=12472, loss=0.011]
# training:  25%|██▍       | 12472/50000 [59:43<2:55:55,  3.56it/s, it=12472, loss=0.011]
# training:  25%|██▍       | 12472/50000 [59:44<2:55:55,  3.56it/s, it=12473, loss=0.006]
# training:  25%|██▍       | 12473/50000 [59:44<2:55:51,  3.56it/s, it=12473, loss=0.006]
# training:  25%|██▍       | 12473/50000 [59:44<2:55:51,  3.56it/s, it=12474, loss=0.013]
# training:  25%|██▍       | 12474/50000 [59:44<2:55:48,  3.56it/s, it=12474, loss=0.013]
# training:  25%|██▍       | 12474/50000 [59:44<2:55:48,  3.56it/s, it=12475, loss=0.005]
# training:  25%|██▍       | 12475/50000 [59:44<2:55:52,  3.56it/s, it=12475, loss=0.005]
# training:  25%|██▍       | 12475/50000 [59:45<2:55:52,  3.56it/s, it=12476, loss=0.010]
# training:  25%|██▍       | 12476/50000 [59:45<2:56:05,  3.55it/s, it=12476, loss=0.010]
# training:  25%|██▍       | 12476/50000 [59:45<2:56:05,  3.55it/s, it=12477, loss=0.008]
# training:  25%|██▍       | 12477/50000 [59:45<2:56:19,  3.55it/s, it=12477, loss=0.008]
# training:  25%|██▍       | 12477/50000 [59:45<2:56:19,  3.55it/s, it=12478, loss=0.007]
# training:  25%|██▍       | 12478/50000 [59:45<2:56:45,  3.54it/s, it=12478, loss=0.007]
# training:  25%|██▍       | 12478/50000 [59:45<2:56:45,  3.54it/s, it=12479, loss=0.007]
# training:  25%|██▍       | 12479/50000 [59:45<2:56:49,  3.54it/s, it=12479, loss=0.007]
# training:  25%|██▍       | 12479/50000 [59:46<2:56:49,  3.54it/s, it=12480, loss=0.012]
# training:  25%|██▍       | 12480/50000 [59:46<2:56:58,  3.53it/s, it=12480, loss=0.012]
# training:  25%|██▍       | 12480/50000 [59:46<2:56:58,  3.53it/s, it=12481, loss=0.009]
# training:  25%|██▍       | 12481/50000 [59:46<2:56:54,  3.53it/s, it=12481, loss=0.009]
# training:  25%|██▍       | 12481/50000 [59:46<2:56:54,  3.53it/s, it=12482, loss=0.011]
# training:  25%|██▍       | 12482/50000 [59:46<2:57:19,  3.53it/s, it=12482, loss=0.011]
# training:  25%|██▍       | 12482/50000 [59:47<2:57:19,  3.53it/s, it=12483, loss=0.016]
# training:  25%|██▍       | 12483/50000 [59:47<2:57:34,  3.52it/s, it=12483, loss=0.016]
# training:  25%|██▍       | 12483/50000 [59:47<2:57:34,  3.52it/s, it=12484, loss=0.008]
# training:  25%|██▍       | 12484/50000 [59:47<2:57:10,  3.53it/s, it=12484, loss=0.008]
# training:  25%|██▍       | 12484/50000 [59:47<2:57:10,  3.53it/s, it=12485, loss=0.002]
# training:  25%|██▍       | 12485/50000 [59:47<2:56:59,  3.53it/s, it=12485, loss=0.002]
# training:  25%|██▍       | 12485/50000 [59:47<2:56:59,  3.53it/s, it=12486, loss=0.008]
# training:  25%|██▍       | 12486/50000 [59:47<2:57:09,  3.53it/s, it=12486, loss=0.008]
# training:  25%|██▍       | 12486/50000 [59:48<2:57:09,  3.53it/s, it=12487, loss=0.007]
# training:  25%|██▍       | 12487/50000 [59:48<2:57:20,  3.53it/s, it=12487, loss=0.007]
# training:  25%|██▍       | 12487/50000 [59:48<2:57:20,  3.53it/s, it=12488, loss=0.008]
# training:  25%|██▍       | 12488/50000 [59:48<2:57:25,  3.52it/s, it=12488, loss=0.008]
# training:  25%|██▍       | 12488/50000 [59:48<2:57:25,  3.52it/s, it=12489, loss=0.009]
# training:  25%|██▍       | 12489/50000 [59:48<2:57:04,  3.53it/s, it=12489, loss=0.009]
# training:  25%|██▍       | 12489/50000 [59:49<2:57:04,  3.53it/s, it=12490, loss=0.010]
# training:  25%|██▍       | 12490/50000 [59:49<2:56:54,  3.53it/s, it=12490, loss=0.010]
# training:  25%|██▍       | 12490/50000 [59:49<2:56:54,  3.53it/s, it=12491, loss=0.006]
# training:  25%|██▍       | 12491/50000 [59:49<2:56:57,  3.53it/s, it=12491, loss=0.006]
# training:  25%|██▍       | 12491/50000 [59:49<2:56:57,  3.53it/s, it=12492, loss=0.015]
# training:  25%|██▍       | 12492/50000 [59:49<2:56:57,  3.53it/s, it=12492, loss=0.015]
# training:  25%|██▍       | 12492/50000 [59:49<2:56:57,  3.53it/s, it=12493, loss=0.014]
# training:  25%|██▍       | 12493/50000 [59:49<2:56:32,  3.54it/s, it=12493, loss=0.014]
# training:  25%|██▍       | 12493/50000 [59:50<2:56:32,  3.54it/s, it=12494, loss=0.009]
# training:  25%|██▍       | 12494/50000 [59:50<2:55:59,  3.55it/s, it=12494, loss=0.009]
# training:  25%|██▍       | 12494/50000 [59:50<2:55:59,  3.55it/s, it=12495, loss=0.008]
# training:  25%|██▍       | 12495/50000 [59:50<2:55:58,  3.55it/s, it=12495, loss=0.008]
# training:  25%|██▍       | 12495/50000 [59:50<2:55:58,  3.55it/s, it=12496, loss=0.007]
# training:  25%|██▍       | 12496/50000 [59:50<2:56:07,  3.55it/s, it=12496, loss=0.007]
# training:  25%|██▍       | 12496/50000 [59:51<2:56:07,  3.55it/s, it=12497, loss=0.009]
# training:  25%|██▍       | 12497/50000 [59:51<2:56:18,  3.55it/s, it=12497, loss=0.009]
# training:  25%|██▍       | 12497/50000 [59:51<2:56:18,  3.55it/s, it=12498, loss=0.003]
# training:  25%|██▍       | 12498/50000 [59:51<2:56:12,  3.55it/s, it=12498, loss=0.003]
# training:  25%|██▍       | 12498/50000 [59:51<2:56:12,  3.55it/s, it=12499, loss=0.003]
# training:  25%|██▍       | 12499/50000 [59:51<2:55:52,  3.55it/s, it=12499, loss=0.003]
# training:  25%|██▍       | 12499/50000 [59:51<2:55:52,  3.55it/s, it=12500, loss=0.005]
# training:  25%|██▌       | 12500/50000 [59:51<2:59:40,  3.48it/s, it=12500, loss=0.005]
# training:  25%|██▌       | 12500/50000 [59:52<2:59:40,  3.48it/s, it=12501, loss=0.011]
# training:  25%|██▌       | 12501/50000 [59:52<2:58:36,  3.50it/s, it=12501, loss=0.011]
# training:  25%|██▌       | 12501/50000 [59:52<2:58:36,  3.50it/s, it=12502, loss=0.004]
# training:  25%|██▌       | 12502/50000 [59:52<2:57:43,  3.52it/s, it=12502, loss=0.004]
# training:  25%|██▌       | 12502/50000 [59:52<2:57:43,  3.52it/s, it=12503, loss=0.008]
# training:  25%|██▌       | 12503/50000 [59:52<2:56:46,  3.54it/s, it=12503, loss=0.008]
# training:  25%|██▌       | 12503/50000 [59:53<2:56:46,  3.54it/s, it=12504, loss=0.008]
# training:  25%|██▌       | 12504/50000 [59:53<2:56:31,  3.54it/s, it=12504, loss=0.008]
# training:  25%|██▌       | 12504/50000 [59:53<2:56:31,  3.54it/s, it=12505, loss=0.012]
# training:  25%|██▌       | 12505/50000 [59:53<2:56:23,  3.54it/s, it=12505, loss=0.012]
# training:  25%|██▌       | 12505/50000 [59:53<2:56:23,  3.54it/s, it=12506, loss=0.016]
# training:  25%|██▌       | 12506/50000 [59:53<2:56:14,  3.55it/s, it=12506, loss=0.016]
# training:  25%|██▌       | 12506/50000 [59:53<2:56:14,  3.55it/s, it=12507, loss=0.009]
# training:  25%|██▌       | 12507/50000 [59:53<2:55:53,  3.55it/s, it=12507, loss=0.009]
# training:  25%|██▌       | 12507/50000 [59:54<2:55:53,  3.55it/s, it=12508, loss=0.016]
# training:  25%|██▌       | 12508/50000 [59:54<2:55:53,  3.55it/s, it=12508, loss=0.016]
# training:  25%|██▌       | 12508/50000 [59:54<2:55:53,  3.55it/s, it=12509, loss=0.006]
# training:  25%|██▌       | 12509/50000 [59:54<2:55:58,  3.55it/s, it=12509, loss=0.006]
# training:  25%|██▌       | 12509/50000 [59:54<2:55:58,  3.55it/s, it=12510, loss=0.006]
# training:  25%|██▌       | 12510/50000 [59:54<2:56:20,  3.54it/s, it=12510, loss=0.006]
# training:  25%|██▌       | 12510/50000 [59:54<2:56:20,  3.54it/s, it=12511, loss=0.012]
# training:  25%|██▌       | 12511/50000 [59:54<2:56:27,  3.54it/s, it=12511, loss=0.012]
# training:  25%|██▌       | 12511/50000 [59:55<2:56:27,  3.54it/s, it=12512, loss=0.005]
# training:  25%|██▌       | 12512/50000 [59:55<2:56:21,  3.54it/s, it=12512, loss=0.005]
# training:  25%|██▌       | 12512/50000 [59:55<2:56:21,  3.54it/s, it=12513, loss=0.008]
# training:  25%|██▌       | 12513/50000 [59:55<2:56:06,  3.55it/s, it=12513, loss=0.008]
# training:  25%|██▌       | 12513/50000 [59:55<2:56:06,  3.55it/s, it=12514, loss=0.010]
# training:  25%|██▌       | 12514/50000 [59:55<2:55:42,  3.56it/s, it=12514, loss=0.010]
# training:  25%|██▌       | 12514/50000 [59:56<2:55:42,  3.56it/s, it=12515, loss=0.007]
# training:  25%|██▌       | 12515/50000 [59:56<2:55:44,  3.55it/s, it=12515, loss=0.007]
# training:  25%|██▌       | 12515/50000 [59:56<2:55:44,  3.55it/s, it=12516, loss=0.009]
# training:  25%|██▌       | 12516/50000 [59:56<2:55:45,  3.55it/s, it=12516, loss=0.009]
# training:  25%|██▌       | 12516/50000 [59:56<2:55:45,  3.55it/s, it=12517, loss=0.009]
# training:  25%|██▌       | 12517/50000 [59:56<2:55:32,  3.56it/s, it=12517, loss=0.009]
# training:  25%|██▌       | 12517/50000 [59:56<2:55:32,  3.56it/s, it=12518, loss=0.009]
# training:  25%|██▌       | 12518/50000 [59:56<2:55:37,  3.56it/s, it=12518, loss=0.009]
# training:  25%|██▌       | 12518/50000 [59:57<2:55:37,  3.56it/s, it=12519, loss=0.003]
# training:  25%|██▌       | 12519/50000 [59:57<2:55:50,  3.55it/s, it=12519, loss=0.003]
# training:  25%|██▌       | 12519/50000 [59:57<2:55:50,  3.55it/s, it=12520, loss=0.004]
# training:  25%|██▌       | 12520/50000 [59:57<2:56:05,  3.55it/s, it=12520, loss=0.004]
# training:  25%|██▌       | 12520/50000 [59:57<2:56:05,  3.55it/s, it=12521, loss=0.002]
# training:  25%|██▌       | 12521/50000 [59:57<2:56:23,  3.54it/s, it=12521, loss=0.002]
# training:  25%|██▌       | 12521/50000 [59:58<2:56:23,  3.54it/s, it=12522, loss=0.008]
# training:  25%|██▌       | 12522/50000 [59:58<2:56:40,  3.54it/s, it=12522, loss=0.008]
# training:  25%|██▌       | 12522/50000 [59:58<2:56:40,  3.54it/s, it=12523, loss=0.013]
# training:  25%|██▌       | 12523/50000 [59:58<2:56:33,  3.54it/s, it=12523, loss=0.013]
# training:  25%|██▌       | 12523/50000 [59:58<2:56:33,  3.54it/s, it=12524, loss=0.009]
# training:  25%|██▌       | 12524/50000 [59:58<2:56:42,  3.53it/s, it=12524, loss=0.009]
# training:  25%|██▌       | 12524/50000 [59:58<2:56:42,  3.53it/s, it=12525, loss=0.006]
# training:  25%|██▌       | 12525/50000 [59:58<2:57:01,  3.53it/s, it=12525, loss=0.006]
# training:  25%|██▌       | 12525/50000 [59:59<2:57:01,  3.53it/s, it=12526, loss=0.007]
# training:  25%|██▌       | 12526/50000 [59:59<2:56:52,  3.53it/s, it=12526, loss=0.007]
# training:  25%|██▌       | 12526/50000 [59:59<2:56:52,  3.53it/s, it=12527, loss=0.005]
# training:  25%|██▌       | 12527/50000 [59:59<2:57:00,  3.53it/s, it=12527, loss=0.005]
# training:  25%|██▌       | 12527/50000 [59:59<2:57:00,  3.53it/s, it=12528, loss=0.005]
# training:  25%|██▌       | 12528/50000 [59:59<2:56:54,  3.53it/s, it=12528, loss=0.005]
# training:  25%|██▌       | 12528/50000 [1:00:00<2:56:54,  3.53it/s, it=12529, loss=0.004]
# training:  25%|██▌       | 12529/50000 [1:00:00<2:56:58,  3.53it/s, it=12529, loss=0.004]
# training:  25%|██▌       | 12529/50000 [1:00:00<2:56:58,  3.53it/s, it=12530, loss=0.010]
# training:  25%|██▌       | 12530/50000 [1:00:00<2:56:54,  3.53it/s, it=12530, loss=0.010]
# training:  25%|██▌       | 12530/50000 [1:00:00<2:56:54,  3.53it/s, it=12531, loss=0.006]
# training:  25%|██▌       | 12531/50000 [1:00:00<2:57:02,  3.53it/s, it=12531, loss=0.006]
# training:  25%|██▌       | 12531/50000 [1:00:00<2:57:02,  3.53it/s, it=12532, loss=0.015]
# training:  25%|██▌       | 12532/50000 [1:00:00<2:57:26,  3.52it/s, it=12532, loss=0.015]
# training:  25%|██▌       | 12532/50000 [1:00:01<2:57:26,  3.52it/s, it=12533, loss=0.004]
# training:  25%|██▌       | 12533/50000 [1:00:01<2:57:19,  3.52it/s, it=12533, loss=0.004]
# training:  25%|██▌       | 12533/50000 [1:00:01<2:57:19,  3.52it/s, it=12534, loss=0.003]
# training:  25%|██▌       | 12534/50000 [1:00:01<2:57:26,  3.52it/s, it=12534, loss=0.003]
# training:  25%|██▌       | 12534/50000 [1:00:01<2:57:26,  3.52it/s, it=12535, loss=0.011]
# training:  25%|██▌       | 12535/50000 [1:00:01<2:57:15,  3.52it/s, it=12535, loss=0.011]
# training:  25%|██▌       | 12535/50000 [1:00:02<2:57:15,  3.52it/s, it=12536, loss=0.016]
# training:  25%|██▌       | 12536/50000 [1:00:02<2:56:42,  3.53it/s, it=12536, loss=0.016]
# training:  25%|██▌       | 12536/50000 [1:00:02<2:56:42,  3.53it/s, it=12537, loss=0.005]
# training:  25%|██▌       | 12537/50000 [1:00:02<2:56:36,  3.54it/s, it=12537, loss=0.005]
# training:  25%|██▌       | 12537/50000 [1:00:02<2:56:36,  3.54it/s, it=12538, loss=0.007]
# training:  25%|██▌       | 12538/50000 [1:00:02<2:56:41,  3.53it/s, it=12538, loss=0.007]
# training:  25%|██▌       | 12538/50000 [1:00:02<2:56:41,  3.53it/s, it=12539, loss=0.011]
# training:  25%|██▌       | 12539/50000 [1:00:02<2:56:34,  3.54it/s, it=12539, loss=0.011]
# training:  25%|██▌       | 12539/50000 [1:00:03<2:56:34,  3.54it/s, it=12540, loss=0.002]
# training:  25%|██▌       | 12540/50000 [1:00:03<2:56:47,  3.53it/s, it=12540, loss=0.002]
# training:  25%|██▌       | 12540/50000 [1:00:03<2:56:47,  3.53it/s, it=12541, loss=0.006]
# training:  25%|██▌       | 12541/50000 [1:00:03<2:56:51,  3.53it/s, it=12541, loss=0.006]
# training:  25%|██▌       | 12541/50000 [1:00:03<2:56:51,  3.53it/s, it=12542, loss=0.005]
# training:  25%|██▌       | 12542/50000 [1:00:03<2:57:03,  3.53it/s, it=12542, loss=0.005]
# training:  25%|██▌       | 12542/50000 [1:00:04<2:57:03,  3.53it/s, it=12543, loss=0.010]
# training:  25%|██▌       | 12543/50000 [1:00:04<2:56:56,  3.53it/s, it=12543, loss=0.010]
# training:  25%|██▌       | 12543/50000 [1:00:04<2:56:56,  3.53it/s, it=12544, loss=0.007]
# training:  25%|██▌       | 12544/50000 [1:00:04<2:56:39,  3.53it/s, it=12544, loss=0.007]
# training:  25%|██▌       | 12544/50000 [1:00:04<2:56:39,  3.53it/s, it=12545, loss=0.004]
# training:  25%|██▌       | 12545/50000 [1:00:04<2:56:05,  3.54it/s, it=12545, loss=0.004]
# training:  25%|██▌       | 12545/50000 [1:00:04<2:56:05,  3.54it/s, it=12546, loss=0.011]
# training:  25%|██▌       | 12546/50000 [1:00:04<2:55:42,  3.55it/s, it=12546, loss=0.011]
# training:  25%|██▌       | 12546/50000 [1:00:05<2:55:42,  3.55it/s, it=12547, loss=0.009]
# training:  25%|██▌       | 12547/50000 [1:00:05<2:55:37,  3.55it/s, it=12547, loss=0.009]
# training:  25%|██▌       | 12547/50000 [1:00:05<2:55:37,  3.55it/s, it=12548, loss=0.003]
# training:  25%|██▌       | 12548/50000 [1:00:05<2:55:48,  3.55it/s, it=12548, loss=0.003]
# training:  25%|██▌       | 12548/50000 [1:00:05<2:55:48,  3.55it/s, it=12549, loss=0.013]
# training:  25%|██▌       | 12549/50000 [1:00:05<2:55:32,  3.56it/s, it=12549, loss=0.013]
# training:  25%|██▌       | 12549/50000 [1:00:06<2:55:32,  3.56it/s, it=12550, loss=0.013]
# training:  25%|██▌       | 12550/50000 [1:00:06<2:55:29,  3.56it/s, it=12550, loss=0.013]
# training:  25%|██▌       | 12550/50000 [1:00:06<2:55:29,  3.56it/s, it=12551, loss=0.008]
# training:  25%|██▌       | 12551/50000 [1:00:06<2:55:39,  3.55it/s, it=12551, loss=0.008]
# training:  25%|██▌       | 12551/50000 [1:00:06<2:55:39,  3.55it/s, it=12552, loss=0.005]
# training:  25%|██▌       | 12552/50000 [1:00:06<2:56:01,  3.55it/s, it=12552, loss=0.005]
# training:  25%|██▌       | 12552/50000 [1:00:06<2:56:01,  3.55it/s, it=12553, loss=0.006]
# training:  25%|██▌       | 12553/50000 [1:00:06<2:56:16,  3.54it/s, it=12553, loss=0.006]
# training:  25%|██▌       | 12553/50000 [1:00:07<2:56:16,  3.54it/s, it=12554, loss=0.004]
# training:  25%|██▌       | 12554/50000 [1:00:07<2:56:18,  3.54it/s, it=12554, loss=0.004]
# training:  25%|██▌       | 12554/50000 [1:00:07<2:56:18,  3.54it/s, it=12555, loss=0.004]

# %% [markdown]
# farah diri hada direct

# %%
"""
==========================================
BARF LEGO - ENTRAÎNEMENT ROBUSTE V3
Version optimisée : 20k iterations
Sauvegardes automatiques sécurisées
==========================================
"""

import os
import json
import shutil
import yaml
import numpy as np
import subprocess
import sys
import time
import threading
from datetime import datetime

print("="*70)
print("🚀 BARF LEGO - ENTRAÎNEMENT ROBUSTE V3")
print("="*70)

# ==========================================
# ÉTAPE 1 : Configuration Google Drive
# ==========================================
print("\n[1/6] 📁 CONFIGURATION GOOGLE DRIVE")
print("-"*70)

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

DRIVE_ROOT = '/content/drive/MyDrive/projet_nerf_barf'
DRIVE_CHECKPOINTS = os.path.join(DRIVE_ROOT, 'checkpoints_v3_robust')
DRIVE_RESULTS = os.path.join(DRIVE_ROOT, 'results_v3')
DRIVE_LOGS = os.path.join(DRIVE_ROOT, 'logs_v3')

for folder in [DRIVE_CHECKPOINTS, DRIVE_RESULTS, DRIVE_LOGS]:
    os.makedirs(folder, exist_ok=True)

print(f"✅ Dossiers créés :")
print(f"   {DRIVE_CHECKPOINTS}")
print(f"   {DRIVE_RESULTS}")
print(f"   {DRIVE_LOGS}")

# ==========================================
# ÉTAPE 2 : Vérification de l'environnement
# ==========================================
print("\n[2/6] 🔧 VÉRIFICATION ENVIRONNEMENT")
print("-"*70)

BARF_PATH = '/content/barf_workspace/bundle-adjusting-NeRF'
DATASET_ROOT = '/content/data/nerf_synthetic'
SCENE_PATH = os.path.join(DATASET_ROOT, 'lego')

# Vérifier BARF
if not os.path.exists(BARF_PATH):
    print(f"❌ BARF non trouvé : {BARF_PATH}")
    print("💡 Exécutez d'abord le script d'installation BARF !")
    sys.exit(1)

os.chdir(BARF_PATH)
print(f"✅ BARF trouvé : {BARF_PATH}")

# Vérifier dataset
if not os.path.exists(SCENE_PATH):
    print(f"❌ Dataset non trouvé : {SCENE_PATH}")
    print("💡 Exécutez d'abord le script de téléchargement du dataset !")
    sys.exit(1)

print(f"✅ Dataset trouvé : {SCENE_PATH}")

# Analyser le dataset
with open(os.path.join(SCENE_PATH, 'transforms_train.json'), 'r') as f:
    train_data = json.load(f)

num_train = len(train_data['frames'])
print(f"✅ {num_train} images d'entraînement")

# ==========================================
# ÉTAPE 3 : Configuration Optimisée
# ==========================================
print("\n[3/6] ⚙️ CONFIGURATION OPTIMISÉE")
print("-"*70)

# Charger et modifier la config YAML
yaml_original = 'options/barf_blender.yaml'
yaml_optimized = 'options/barf_blender_v3_robust.yaml'

with open(yaml_original, 'r') as f:
    config = yaml.safe_load(f)

# ✅ PARAMÈTRES OPTIMISÉS
config['barf_c2f'] = [0.1, 0.3]        # Plus progressif
config['optim']['lr'] = 0.0001         # LR stable
config['optim']['lr_end'] = 0.00005    # Decay doux
config['optim']['lr_pose'] = 0.0005    # LR pose réduit
config['optim']['lr_pose_end'] = 0.00001
config['visdom'] = False

with open(yaml_optimized, 'w') as f:
    yaml.dump(config, f, default_flow_style=False)

print("✅ Configuration optimisée créée :")
print("   barf_c2f: [0.1, 0.3] (progressif)")
print("   lr: 0.0001 (stable)")
print("   lr_pose: 0.0005 (réduit)")

# ==========================================
# PARAMÈTRES D'ENTRAÎNEMENT
# ==========================================
MAX_ITER = 20000        # 20k iterations ()
CHECKPOINT_FREQ = 2000  # Checkpoint tous les 2k
GROUP_NAME = 'barf_lego_v3_robust'

print(f"\n📊 Paramètres d'entraînement :")
print(f"   Iterations    : {MAX_ITER:,}")
print(f"   Checkpoints   : tous les {CHECKPOINT_FREQ:,} it")
print(f"   ⏱️ Temps estimé :  sur T4")
print(f"   💾 Checkpoints attendus : {MAX_ITER // CHECKPOINT_FREQ}")

# ==========================================
# ÉTAPE 4 : Système de Sauvegarde Robuste
# ==========================================
print("\n[4/6] 💾 SYSTÈME DE SAUVEGARDE ROBUSTE")
print("-"*70)

def log_message(msg, level="INFO"):
    """Enregistre un message dans les logs"""
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    log_file = os.path.join(DRIVE_LOGS, "training.log")
    with open(log_file, 'a') as f:
        f.write(f"[{timestamp}] [{level}] {msg}\n")
    print(f"📝 [{level}] {msg}")

def save_checkpoint_immediately(ckpt_path, iteration):
    """Sauvegarde immédiate d'un checkpoint"""
    if not os.path.exists(ckpt_path):
        return False

    try:
        dest = os.path.join(DRIVE_CHECKPOINTS, f"{iteration}.ckpt")
        shutil.copy2(ckpt_path, dest)
        size_mb = os.path.getsize(dest) / (1024**2)
        log_message(f"Checkpoint {iteration} sauvegardé ({size_mb:.1f} MB)", "SAVE")
        return True
    except Exception as e:
        log_message(f"Erreur sauvegarde {iteration}: {e}", "ERROR")
        return False

class CheckpointMonitor:
    """Moniteur de checkpoints avec sauvegarde immédiate"""

    def __init__(self, checkpoint_dir, checkpoint_freq):
        self.checkpoint_dir = checkpoint_dir
        self.checkpoint_freq = checkpoint_freq
        self.last_saved = 0
        self.stop_event = threading.Event()
        self.thread = None

    def start(self):
        """Démarre le monitoring"""
        self.thread = threading.Thread(target=self._monitor, daemon=True)
        self.thread.start()
        log_message("Monitoring des checkpoints démarré", "START")

    def _monitor(self):
        """Boucle de monitoring"""
        checkpoint_path = os.path.join(self.checkpoint_dir, 'latest.ckpt')

        while not self.stop_event.is_set():
            try:
                if os.path.exists(checkpoint_path):
                    # Lire l'iteration actuelle
                    import torch
                    data = torch.load(checkpoint_path, map_location='cpu')
                    current_iter = data.get('iter', 0)

                    # Sauvegarder si c'est un multiple de checkpoint_freq
                    if (current_iter > self.last_saved and
                        current_iter % self.checkpoint_freq == 0):

                        if save_checkpoint_immediately(checkpoint_path, current_iter):
                            self.last_saved = current_iter

            except Exception as e:
                pass  # Ignorer les erreurs temporaires

            time.sleep(5)  # Vérifier toutes les 5 secondes

    def stop(self):
        """Arrête le monitoring"""
        self.stop_event.set()
        if self.thread:
            self.thread.join(timeout=10)
        log_message("Monitoring arrêté", "STOP")

print("✅ Système de sauvegarde robuste activé")
print("   - Sauvegarde immédiate tous les 2000 iterations")
print("   - Vérification toutes les 5 secondes")
print("   - Logs détaillés dans Google Drive")

# ==========================================
# ÉTAPE 5 : Entraînement
# ==========================================
print("\n[5/6] 🚀 LANCEMENT ENTRAÎNEMENT")
print("="*70)

# Construire la commande
cmd = [
    "python", "train.py",
    f"--group={GROUP_NAME}",
    "--model=barf",
    "--yaml=barf_blender_v3_robust",
    "--data.scene=lego",
    f"--data.root={DATASET_ROOT}",
    f"--max_iter={MAX_ITER}",
    "--batch_size=4096",
    "--freq.scalar=200",
    "--freq.vis=2000",
    "--freq.val=5000",
    f"--freq.ckpt={CHECKPOINT_FREQ}",
    "--data.num_workers=2"
]

log_message(f"Début entraînement - {MAX_ITER} iterations", "START")
print(f"🎯 Groupe : {GROUP_NAME}")
print(f"📁 Output : output/{GROUP_NAME}/debug")
print("="*70 + "\n")

# Démarrer le monitoring
checkpoint_dir = f'output/{GROUP_NAME}/debug'
monitor = CheckpointMonitor(checkpoint_dir, CHECKPOINT_FREQ)
monitor.start()

process = None
training_success = False

try:
    # Lancer l'entraînement
    process = subprocess.Popen(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        bufsize=1
    )

    # Afficher la sortie en temps réel
    for line in process.stdout:
        print(line, end='')

    process.wait()
    training_success = (process.returncode == 0)

    # Arrêter le monitoring
    monitor.stop()

    # Sauvegarde finale
    final_ckpt = os.path.join(checkpoint_dir, 'latest.ckpt')
    if os.path.exists(final_ckpt):
        save_checkpoint_immediately(final_ckpt, MAX_ITER)

    if training_success:
        print("\n" + "="*70)
        print("✅ ENTRAÎNEMENT TERMINÉ AVEC SUCCÈS")
        print("="*70)
        log_message("Entraînement terminé avec succès", "SUCCESS")
    else:
        print(f"\n⚠️ Entraînement terminé avec code {process.returncode}")
        log_message(f"Code retour: {process.returncode}", "WARNING")

except KeyboardInterrupt:
    print("\n" + "="*70)
    print("⚠️ INTERRUPTION DÉTECTÉE")
    print("="*70)

    monitor.stop()

    if process:
        try:
            process.terminate()
            process.wait(timeout=10)
        except:
            process.kill()

    # Sauvegarder le checkpoint d'interruption
    interrupt_ckpt = os.path.join(checkpoint_dir, 'latest.ckpt')
    if os.path.exists(interrupt_ckpt):
        try:
            import torch
            data = torch.load(interrupt_ckpt, map_location='cpu')
            current_iter = data.get('iter', 'unknown')

            dest = os.path.join(DRIVE_CHECKPOINTS, f"interrupt_{current_iter}.ckpt")
            shutil.copy2(interrupt_ckpt, dest)
            print(f"✅ Checkpoint d'interruption sauvegardé (iter {current_iter})")
            log_message(f"Interruption à l'iteration {current_iter}", "INTERRUPT")
        except Exception as e:
            print(f"⚠️ Erreur sauvegarde interruption : {e}")

    print("\n💡 Pour reprendre : rechargez ce script")
    print("="*70)
    sys.exit(0)

except Exception as e:
    print(f"\n❌ ERREUR : {e}")
    monitor.stop()
    log_message(f"Erreur fatale: {e}", "ERROR")
    sys.exit(1)

# ==========================================
# ÉTAPE 6 : Évaluation & Résultats
# ==========================================
if training_success:
    print("\n[6/6] 📊 ÉVALUATION & RÉSULTATS")
    print("-"*70)

    # Lister les checkpoints disponibles
    checkpoints_saved = sorted([
        f for f in os.listdir(DRIVE_CHECKPOINTS)
        if f.endswith('.ckpt') and not f.startswith('interrupt')
    ])

    print(f"\n✅ Checkpoints sauvegardés ({len(checkpoints_saved)}) :")
    for ckpt in checkpoints_saved:
        print(f"   - {ckpt}")

    # Évaluer le dernier checkpoint
    if checkpoints_saved:
        last_ckpt = checkpoints_saved[-1]
        ckpt_path = os.path.join(DRIVE_CHECKPOINTS, last_ckpt)

        print(f"\n🧪 Évaluation du checkpoint final : {last_ckpt}")

        eval_cmd = [
            "python", "evaluate.py",
            f"--group={GROUP_NAME}",
            "--model=barf",
            "--yaml=barf_blender_v3_robust",
            "--data.scene=lego",
            f"--data.root={DATASET_ROOT}",
            f"--load={ckpt_path}"
        ]

        result = subprocess.run(eval_cmd, capture_output=True, text=True)

        # Extraire les métriques
        import re
        output = result.stdout + result.stderr

        metrics = {}
        for line in output.split('\n'):
            if 'PSNR:' in line:
                match = re.search(r'PSNR:\s+([\d.]+)', line)
                if match:
                    metrics['PSNR'] = float(match.group(1))
            if 'SSIM:' in line:
                match = re.search(r'SSIM:\s+([\d.]+)', line)
                if match:
                    metrics['SSIM'] = float(match.group(1))
            if 'LPIPS:' in line:
                match = re.search(r'LPIPS:\s+([\d.]+)', line)
                if match:
                    metrics['LPIPS'] = float(match.group(1))

        print(f"\n📈 RÉSULTATS FINAUX :")
        print("-"*50)
        if metrics:
            print(f"PSNR  : {metrics.get('PSNR', 'N/A'):.2f} dB")
            print(f"SSIM  : {metrics.get('SSIM', 'N/A'):.4f}")
            print(f"LPIPS : {metrics.get('LPIPS', 'N/A'):.4f}")

            # Comparaison avec baseline
            baseline_psnr = 21.81
            if 'PSNR' in metrics:
                diff = metrics['PSNR'] - baseline_psnr
                if diff > 0:
                    print(f"\n🎉 AMÉLIORATION : +{diff:.2f} dB vs baseline V1 !")
                else:
                    print(f"\nℹ️ Baseline V1 meilleure : {abs(diff):.2f} dB")
        else:
            print("⚠️ Métriques non disponibles")

        # Sauvegarder le rapport
        report_path = os.path.join(DRIVE_RESULTS, "report_v3_robust.txt")
        with open(report_path, 'w') as f:
            f.write("="*70 + "\n")
            f.write("RAPPORT D'ENTRAÎNEMENT BARF V3 ROBUST\n")
            f.write("="*70 + "\n\n")
            f.write(f"Date : {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
            f.write(f"Iterations : {MAX_ITER}\n")
            f.write(f"Checkpoints : {len(checkpoints_saved)}\n\n")

            if metrics:
                f.write("RÉSULTATS FINAUX :\n")
                f.write(f"  PSNR  : {metrics.get('PSNR', 'N/A'):.2f} dB\n")
                f.write(f"  SSIM  : {metrics.get('SSIM', 'N/A'):.4f}\n")
                f.write(f"  LPIPS : {metrics.get('LPIPS', 'N/A'):.4f}\n\n")

            f.write("CHECKPOINTS SAUVEGARDÉS :\n")
            for ckpt in checkpoints_saved:
                f.write(f"  - {ckpt}\n")

        print(f"\n✅ Rapport sauvegardé : report_v3_robust.txt")

# ==========================================
# RÉSUMÉ FINAL
# ==========================================
print("\n" + "="*70)
print("🎉 EXPÉRIMENTATION TERMINÉE")
print("="*70)
print(f"\n📁 FICHIERS DANS GOOGLE DRIVE :")
print(f"   Checkpoints : {DRIVE_CHECKPOINTS}")
print(f"   Résultats   : {DRIVE_RESULTS}")
print(f"   Logs        : {DRIVE_LOGS}")
print("\n💡 Consultez les fichiers pour voir les résultats détaillés !")
print("="*70)

# %%
import os
import subprocess
import re
from datetime import datetime

print("="*70)
print("🚀 BARF - FIX DIMENSIONS")
print("="*70)

BARF_PATH = '/content/barf_workspace/bundle-adjusting-NeRF'
nerf_path = os.path.join(BARF_PATH, 'model', 'nerf.py')

print("\n🔧 Correction dimensions tenseur...")

with open(nerf_path, 'r') as f:
    lines = f.readlines()

# Trouver et corriger la ligne SSIM
for i, line in enumerate(lines):
    if 'ssim = pytorch_ssim' in line and 'rgb_map' in line:
        indent = ' ' * (len(line) - len(line.lstrip()))
        # rgb_map est déjà [B,H,W,C], on doit juste permuter en [B,C,H,W]
        new_line = indent + 'ssim = pytorch_ssim(rgb_map.permute(0,3,1,2), var.image.permute(0,3,1,2)).item()\n'
        lines[i] = new_line
        print(f"✅ Ligne {i+1}: dimensions corrigées (pas d'unsqueeze)")
        break

with open(nerf_path, 'w') as f:
    f.writelines(lines)

# ==========================================
# CONFIG
# ==========================================
DATASET_ROOT = '/content/data/nerf_synthetic'
CHECKPOINTS_PATH = '/content/drive/MyDrive/projet_nerf_barf/checkpoints_v3_robust'
RESULTS_PATH = '/content/drive/MyDrive/projet_nerf_barf/results_v3'

yaml_path = os.path.join(BARF_PATH, 'options', 'barf_blender_eval.yaml')
yaml_orig = os.path.join(BARF_PATH, 'options', 'barf_blender.yaml')

with open(yaml_orig, 'r') as f:
    yaml = f.read()
yaml = re.sub(r'visdom:\s*(false|False)', 'visdom:\n  cam_depth: 0.5', yaml)
with open(yaml_path, 'w') as f:
    f.write(yaml)

ckpts = sorted([f for f in os.listdir(CHECKPOINTS_PATH) if f.endswith('.ckpt')])
ckpt_path = os.path.join(CHECKPOINTS_PATH, ckpts[-1])

print(f"🧪 Checkpoint: {ckpts[-1]}")
print("🎯 Évaluation...\n")

# ==========================================
# ÉVALUATION
# ==========================================
cmd = [
    "python", os.path.join(BARF_PATH, "evaluate.py"),
    "--group=barf_final",
    "--model=barf",
    "--yaml=barf_blender_eval",
    "--data.scene=lego",
    f"--data.root={DATASET_ROOT}",
    f"--load={ckpt_path}"
]

result = subprocess.run(cmd, capture_output=True, text=True, cwd=BARF_PATH)
output = result.stdout + result.stderr
lines = output.split('\n')

print("===== OUTPUT (dernières lignes) =====")
for line in lines[-40:]:
    if line.strip():
        print(line)
print("======================================\n")

# ==========================================
# EXTRACTION
# ==========================================
metrics = {}
for line in lines:
    for metric in ['PSNR', 'SSIM', 'LPIPS']:
        m = re.search(rf'{metric}[:\s=]+([\d.]+)', line, re.IGNORECASE)
        if m and metric not in metrics:
            metrics[metric] = float(m.group(1))

# ==========================================
# RÉSULTATS
# ==========================================
print("="*70)
print("📊 RÉSULTATS FINAUX")
print("="*70)

if metrics:
    print(f"\n  PSNR  : {metrics['PSNR']:.2f} dB")
    print(f"  SSIM  : {metrics['SSIM']:.4f}")
    print(f"  LPIPS : {metrics['LPIPS']:.4f}\n")

    if metrics['PSNR'] > 30:
        print("🌟 EXCELLENTE qualité")
    elif metrics['PSNR'] > 25:
        print("✅ BONNE qualité")
    else:
        print("⚠️ MOYENNE")
else:
    print("\n❌ Pas de métriques extraites")
    if "Traceback" in output:
        print("\nErreur:")
        for line in lines[-8:]:
            if line.strip():
                print(f"  {line}")

# Rapport
report = os.path.join(RESULTS_PATH, f"final_{datetime.now().strftime('%Y%m%d_%H%M%S')}.txt")
with open(report, 'w') as f:
    f.write(f"BARF EVALUATION\n{'='*70}\n\n")
    if metrics:
        for k, v in metrics.items():
            f.write(f"{k}: {v:.4f}\n")
    f.write(f"\n{'='*70}\n{output}")

print(f"\n💾 {report}")
print("="*70)
# Out:
# ======================================================================
# 🚀 BARF - FIX DIMENSIONS
# ======================================================================
#
# 🔧 Correction dimensions tenseur...
# ✅ Ligne 130: dimensions corrigées (pas d'unsqueeze)
# 🧪 Checkpoint: 8000.ckpt
# 🎯 Évaluation...
#
# ===== OUTPUT (dernières lignes) =====
# test-time optim.:  91%|█████████ | 91/100 [00:14<00:01,  6.15it/s, loss=0.012]
# test-time optim.:  92%|█████████▏| 92/100 [00:14<00:01,  6.17it/s, loss=0.012]
# test-time optim.:  92%|█████████▏| 92/100 [00:15<00:01,  6.17it/s, loss=0.012]
# test-time optim.:  93%|█████████▎| 93/100 [00:15<00:01,  6.18it/s, loss=0.012]
# test-time optim.:  93%|█████████▎| 93/100 [00:15<00:01,  6.18it/s, loss=0.011]
# test-time optim.:  94%|█████████▍| 94/100 [00:15<00:00,  6.17it/s, loss=0.011]
# test-time optim.:  94%|█████████▍| 94/100 [00:15<00:00,  6.17it/s, loss=0.013]
# test-time optim.:  95%|█████████▌| 95/100 [00:15<00:00,  6.17it/s, loss=0.013]
# test-time optim.:  95%|█████████▌| 95/100 [00:15<00:00,  6.17it/s, loss=0.014]
# test-time optim.:  96%|█████████▌| 96/100 [00:15<00:00,  6.13it/s, loss=0.014]
# test-time optim.:  96%|█████████▌| 96/100 [00:15<00:00,  6.13it/s, loss=0.012]
# test-time optim.:  97%|█████████▋| 97/100 [00:15<00:00,  6.16it/s, loss=0.012]
# test-time optim.:  97%|█████████▋| 97/100 [00:15<00:00,  6.16it/s, loss=0.012]
# test-time optim.:  98%|█████████▊| 98/100 [00:15<00:00,  6.17it/s, loss=0.012]
# test-time optim.:  98%|█████████▊| 98/100 [00:16<00:00,  6.17it/s, loss=0.014]
# test-time optim.:  99%|█████████▉| 99/100 [00:16<00:00,  6.18it/s, loss=0.014]
# test-time optim.:  99%|█████████▉| 99/100 [00:16<00:00,  6.18it/s, loss=0.013]
# test-time optim.: 100%|██████████| 100/100 [00:16<00:00,  6.18it/s, loss=0.013]
#
# evaluating: 100%|██████████| 4/4 [01:44<00:00, 26.03s/it]
# ======================================
#
# ======================================================================
# 📊 RÉSULTATS FINAUX
# ======================================================================
#
#   PSNR  : 19.54 dB
#   SSIM  : 0.9400
#   LPIPS : 0.3600
#
# ⚠️ MOYENNE
#
# 💾 /content/drive/MyDrive/projet_nerf_barf/results_v3/final_20251130_162735.txt
# ======================================================================

# %%
import os
import subprocess
import re
from datetime import datetime
import pandas as pd

print("="*70)
print("🚀 BARF - ÉVALUATION DE TOUS LES CHECKPOINTS")
print("="*70)

BARF_PATH = '/content/barf_workspace/bundle-adjusting-NeRF'
nerf_path = os.path.join(BARF_PATH, 'model', 'nerf.py')

# ==========================================
# FIX SSIM (une seule fois)
# ==========================================
print("\n🔧 Vérification SSIM...")

with open(nerf_path, 'r') as f:
    lines = f.readlines()

for i, line in enumerate(lines):
    if 'ssim = pytorch_ssim' in line and 'rgb_map' in line:
        if 'unsqueeze' in line:
            indent = ' ' * (len(line) - len(line.lstrip()))
            new_line = indent + 'ssim = pytorch_ssim(rgb_map.permute(0,3,1,2), var.image.permute(0,3,1,2)).item()\n'
            lines[i] = new_line
            with open(nerf_path, 'w') as f:
                f.writelines(lines)
            print("✅ SSIM corrigée")
        else:
            print("✅ SSIM déjà correcte")
        break

# ==========================================
# CONFIG
# ==========================================
DATASET_ROOT = '/content/data/nerf_synthetic'
CHECKPOINTS_PATH = '/content/drive/MyDrive/projet_nerf_barf/checkpoints_v3_robust'
RESULTS_PATH = '/content/drive/MyDrive/projet_nerf_barf/results_v3'

os.makedirs(RESULTS_PATH, exist_ok=True)

# YAML
yaml_path = os.path.join(BARF_PATH, 'options', 'barf_blender_eval.yaml')
yaml_orig = os.path.join(BARF_PATH, 'options', 'barf_blender.yaml')

with open(yaml_orig, 'r') as f:
    yaml = f.read()
yaml = re.sub(r'visdom:\s*(false|False)', 'visdom:\n  cam_depth: 0.5', yaml)
with open(yaml_path, 'w') as f:
    f.write(yaml)

# ==========================================
# LISTE DES CHECKPOINTS
# ==========================================
ckpts = sorted([f for f in os.listdir(CHECKPOINTS_PATH) if f.endswith('.ckpt')])

print(f"\n📂 {len(ckpts)} checkpoints trouvés:")
for c in ckpts:
    print(f"   • {c}")

# ==========================================
# ÉVALUATION DE TOUS LES CHECKPOINTS
# ==========================================
all_results = []

print("\n" + "="*70)
print("🎯 DÉBUT DES ÉVALUATIONS")
print("="*70 + "\n")

for idx, ckpt in enumerate(ckpts, 1):
    ckpt_path = os.path.join(CHECKPOINTS_PATH, ckpt)
    iteration = ckpt.replace('.ckpt', '')

    print(f"[{idx}/{len(ckpts)}] Évaluation de {ckpt}...")

    cmd = [
        "python", os.path.join(BARF_PATH, "evaluate.py"),
        f"--group=barf_eval_{iteration}",
        "--model=barf",
        "--yaml=barf_blender_eval",
        "--data.scene=lego",
        f"--data.root={DATASET_ROOT}",
        f"--load={ckpt_path}"
    ]

    result = subprocess.run(cmd, capture_output=True, text=True, cwd=BARF_PATH)
    output = result.stdout + result.stderr
    lines = output.split('\n')

    # Extraction métriques
    metrics = {'checkpoint': ckpt, 'iteration': iteration}

    for line in lines:
        for metric in ['PSNR', 'SSIM', 'LPIPS']:
            m = re.search(rf'{metric}[:\s=]+([\d.]+)', line, re.IGNORECASE)
            if m and metric not in metrics:
                metrics[metric] = float(m.group(1))

    # Vérifier si évaluation a réussi
    if 'PSNR' in metrics:
        print(f"   ✅ PSNR: {metrics['PSNR']:.2f} dB | SSIM: {metrics.get('SSIM', 0):.4f} | LPIPS: {metrics.get('LPIPS', 0):.4f}")
        all_results.append(metrics)
    else:
        print(f"   ❌ Échec - vérifiez le rapport")
        metrics['PSNR'] = None
        metrics['SSIM'] = None
        metrics['LPIPS'] = None
        all_results.append(metrics)

    print()

# ==========================================
# RÉSUMÉ GLOBAL
# ==========================================
print("="*70)
print("📊 RÉSUMÉ GLOBAL")
print("="*70)

if all_results:
    df = pd.DataFrame(all_results)

    print("\n" + "="*70)
    print(f"{'Checkpoint':<15} {'PSNR (dB)':<12} {'SSIM':<10} {'LPIPS':<10}")
    print("-"*70)

    for _, row in df.iterrows():
        psnr = f"{row['PSNR']:.2f}" if pd.notna(row['PSNR']) else "N/A"
        ssim = f"{row['SSIM']:.4f}" if pd.notna(row['SSIM']) else "N/A"
        lpips = f"{row['LPIPS']:.4f}" if pd.notna(row['LPIPS']) else "N/A"
        print(f"{row['checkpoint']:<15} {psnr:<12} {ssim:<10} {lpips:<10}")

    # Statistiques
    valid_results = df[df['PSNR'].notna()]

    if len(valid_results) > 0:
        print("\n" + "="*70)
        print("📈 STATISTIQUES")
        print("-"*70)
        print(f"Checkpoints évalués : {len(valid_results)}/{len(ckpts)}")
        print(f"\nMeilleur PSNR       : {valid_results['PSNR'].max():.2f} dB ({valid_results.loc[valid_results['PSNR'].idxmax(), 'checkpoint']})")
        print(f"Meilleur SSIM       : {valid_results['SSIM'].max():.4f} ({valid_results.loc[valid_results['SSIM'].idxmax(), 'checkpoint']})")
        print(f"Meilleur LPIPS      : {valid_results['LPIPS'].min():.4f} ({valid_results.loc[valid_results['LPIPS'].idxmin(), 'checkpoint']})")
        print(f"\nMoyenne PSNR        : {valid_results['PSNR'].mean():.2f} dB")
        print(f"Moyenne SSIM        : {valid_results['SSIM'].mean():.4f}")
        print(f"Moyenne LPIPS       : {valid_results['LPIPS'].mean():.4f}")

    # Sauvegarder CSV
    csv_path = os.path.join(RESULTS_PATH, f"all_checkpoints_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv")
    df.to_csv(csv_path, index=False)
    print(f"\n💾 CSV sauvegardé: {csv_path}")

    # Graphique évolution (texte ASCII)
    if len(valid_results) > 1:
        print("\n" + "="*70)
        print("📈 ÉVOLUTION DU PSNR")
        print("-"*70)

        psnr_values = valid_results['PSNR'].values
        min_psnr = psnr_values.min()
        max_psnr = psnr_values.max()

        for _, row in valid_results.iterrows():
            psnr = row['PSNR']
            # Normaliser entre 0 et 50 caractères
            if max_psnr > min_psnr:
                bar_len = int(((psnr - min_psnr) / (max_psnr - min_psnr)) * 50)
            else:
                bar_len = 25
            bar = '█' * bar_len
            print(f"{row['checkpoint']:<15} {bar} {psnr:.2f} dB")

else:
    print("\n❌ Aucun résultat obtenu")

# Rapport détaillé
report_path = os.path.join(RESULTS_PATH, f"rapport_complet_{datetime.now().strftime('%Y%m%d_%H%M%S')}.txt")
with open(report_path, 'w') as f:
    f.write("="*70 + "\n")
    f.write("RAPPORT D'ÉVALUATION COMPLÈTE - TOUS LES CHECKPOINTS\n")
    f.write("="*70 + "\n\n")
    f.write(f"Date: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
    f.write(f"Nombre de checkpoints: {len(ckpts)}\n\n")

    if all_results:
        f.write("RÉSULTATS:\n")
        f.write("-"*70 + "\n")
        for r in all_results:
            f.write(f"\nCheckpoint: {r['checkpoint']}\n")
            f.write(f"  PSNR  : {r.get('PSNR', 'N/A')}\n")
            f.write(f"  SSIM  : {r.get('SSIM', 'N/A')}\n")
            f.write(f"  LPIPS : {r.get('LPIPS', 'N/A')}\n")

print(f"\n💾 Rapport détaillé: {report_path}")

print("\n" + "="*70)
print("✅ ÉVALUATION COMPLÈTE TERMINÉE")
print("="*70)
# Out:
# ======================================================================
# 🚀 BARF - ÉVALUATION DE TOUS LES CHECKPOINTS
# ======================================================================
#
# 🔧 Vérification SSIM...
# ✅ SSIM déjà correcte
#
# 📂 9 checkpoints trouvés:
#    • 10000.ckpt
#    • 12000.ckpt
#    • 14000.ckpt
#    • 16000.ckpt
#    • 18000.ckpt
#    • 2000.ckpt
#    • 4000.ckpt
#    • 6000.ckpt
#    • 8000.ckpt
#
# ======================================================================
# 🎯 DÉBUT DES ÉVALUATIONS
# ======================================================================
#
# [1/9] Évaluation de 10000.ckpt...
#    ✅ PSNR: 19.89 dB | SSIM: 0.9500 | LPIPS: 0.3400
#
# [2/9] Évaluation de 12000.ckpt...
#    ✅ PSNR: 20.22 dB | SSIM: 0.9500 | LPIPS: 0.3100
#
# [3/9] Évaluation de 14000.ckpt...
#    ✅ PSNR: 20.36 dB | SSIM: 0.9500 | LPIPS: 0.2800
#
# [4/9] Évaluation de 16000.ckpt...
#    ✅ PSNR: 20.69 dB | SSIM: 0.9600 | LPIPS: 0.2700
#
# [5/9] Évaluation de 18000.ckpt...
#    ✅ PSNR: 21.16 dB | SSIM: 0.9600 | LPIPS: 0.2700
#
# [6/9] Évaluation de 2000.ckpt...
#    ✅ PSNR: 17.83 dB | SSIM: 0.9300 | LPIPS: 0.4300
#
# [7/9] Évaluation de 4000.ckpt...
#    ✅ PSNR: 16.31 dB | SSIM: 0.9100 | LPIPS: 0.4400
#
# [8/9] Évaluation de 6000.ckpt...
#    ✅ PSNR: 17.69 dB | SSIM: 0.9200 | LPIPS: 0.3900
#
# [9/9] Évaluation de 8000.ckpt...
#    ✅ PSNR: 19.54 dB | SSIM: 0.9400 | LPIPS: 0.3600
#
# ======================================================================
# 📊 RÉSUMÉ GLOBAL
# ======================================================================
#
# ======================================================================
# Checkpoint      PSNR (dB)    SSIM       LPIPS
# ----------------------------------------------------------------------
# 10000.ckpt      19.89        0.9500     0.3400
# 12000.ckpt      20.22        0.9500     0.3100
# 14000.ckpt      20.36        0.9500     0.2800
# 16000.ckpt      20.69        0.9600     0.2700
# 18000.ckpt      21.16        0.9600     0.2700
# 2000.ckpt       17.83        0.9300     0.4300
# 4000.ckpt       16.31        0.9100     0.4400
# 6000.ckpt       17.69        0.9200     0.3900
# 8000.ckpt       19.54        0.9400     0.3600
#
# ======================================================================
# 📈 STATISTIQUES
# ----------------------------------------------------------------------
# Checkpoints évalués : 9/9
#
# Meilleur PSNR       : 21.16 dB (18000.ckpt)
# Meilleur SSIM       : 0.9600 (16000.ckpt)
# Meilleur LPIPS      : 0.2700 (16000.ckpt)
#
# Moyenne PSNR        : 19.30 dB
# Moyenne SSIM        : 0.9411
# Moyenne LPIPS       : 0.3433
#
# 💾 CSV sauvegardé: /content/drive/MyDrive/projet_nerf_barf/results_v3/all_checkpoints_20251130_164927.csv
#
# ======================================================================
# 📈 ÉVOLUTION DU PSNR
# ----------------------------------------------------------------------
# 10000.ckpt      ████████████████████████████████████ 19.89 dB
# 12000.ckpt      ████████████████████████████████████████ 20.22 dB
# 14000.ckpt      █████████████████████████████████████████ 20.36 dB
# 16000.ckpt      █████████████████████████████████████████████ 20.69 dB
# 18000.ckpt      ██████████████████████████████████████████████████ 21.16 dB
# 2000.ckpt       ███████████████ 17.83 dB
# 4000.ckpt        16.31 dB
# 6000.ckpt       ██████████████ 17.69 dB
# 8000.ckpt       █████████████████████████████████ 19.54 dB
#
# 💾 Rapport détaillé: /content/drive/MyDrive/projet_nerf_barf/results_v3/rapport_complet_20251130_164927.txt
#
# ======================================================================
# ✅ ÉVALUATION COMPLÈTE TERMINÉE
# ======================================================================

# %%
# !ls /content/barf_workspace/bundle-adjusting-NeRF/options
# Out:
# barf_blender.yaml  base.yaml		   nerf_llff_repr.yaml
# barf_iphone.yaml   nerf_blender_repr.yaml  nerf_llff.yaml
# barf_llff.yaml	   nerf_blender.yaml	   planar.yaml

# %%
# !pip install ipdb
# Out:
# Collecting ipdb
#   Downloading ipdb-0.13.13-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: ipython>=7.31.1 in /usr/local/lib/python3.12/dist-packages (from ipdb) (7.34.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipdb) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=7.31.1->ipdb)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.31.1->ipdb) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.31.1->ipdb) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.31.1->ipdb) (0.2.14)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /packages/0c/4c/b075da0092003d9a55cf2ecc1cae9384a1ca4f650d51b00fc59875fe76f6/ipdb-0.13.13-py3-none-any.whl
# Downloading ipdb-0.13.13-py3-none-any.whl (12 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 50.0 MB/s eta 0:00:00
# Installing collected packages: jedi, ipdb
# Successfully installed ipdb-0.13.13 jedi-0.19.2

# %%
# !pip install visdom
# Out:
# Collecting visdom
#   Downloading visdom-0.2.4.tar.gz (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 22.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.8 in /usr/local/lib/python3.12/dist-packages (from visdom) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from visdom) (1.16.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from visdom) (2.32.4)
# Requirement already satisfied: tornado in /usr/local/lib/python3.12/dist-packages (from visdom) (6.5.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from visdom) (1.17.0)
# Requirement already satisfied: jsonpatch in /usr/local/lib/python3.12/dist-packages (from visdom) (1.33)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.12/dist-packages (from visdom) (1.9.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from visdom) (3.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from visdom) (11.3.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch->visdom) (3.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->visdom) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->visdom) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->visdom) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->visdom) (2025.11.12)
# Building wheels for collected packages: visdom
#   Building wheel for visdom (setup.py) ... done
#   Created wheel for visdom: filename=visdom-0.2.4-py3-none-any.whl size=1408195 sha256=ba8b5357530c9f789d9e29e588369f596d7b503cafb963f0f353a13a137c4ade
#   Stored in directory: /root/.cache/pip/wheels/37/6c/38/64eeaa310e325aacda723e6df1f79ab5e9f31ba195264e04a8
# Successfully built visdom
# Installing collected packages: visdom
# Successfully installed visdom-0.2.4
